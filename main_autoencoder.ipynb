# %% [markdown]
# ## 0. Imports and Setup

# %%
import numpy as np
import pandas as pd
import random
import json # Used to save the plot history of every model
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Configure Jupyter Notebook
pd.set_option('display.max_columns', None) # Display max columns without limitation 
pd.set_option('display.max_rows', 500) # Display max rows of 500
pd.set_option('display.expand_frame_repr', False)

# %%
# Datapreprocessing
DEBUG = 0 # Enable debug to validate pre-processing steps
LOG_NUNIQUE = 50 # Applay Log when umber of unique values > LOG_NUNIQUE; Default = 50
KEEP_MOST_USED_OBJECTS = 5 # Keep the most used objects per column; Default = 5 -> 3 * 5 Columns kept 

# Training and Evaluation
TRAIN_DATA_FROM_SCRATCH = False

# %% [markdown]
# ## 1. EDA

# %%
df_train = pd.read_csv('./data/UNSW_NB15_training-set.csv')
df_test = pd.read_csv('./data/UNSW_NB15_testing-set.csv')
df_old = df_train.copy()

# %%
df_train = pd.concat([df_train, df_test])

# %%
df_train.shape
# Out:
# (257673, 45)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 257673 entries, 0 to 82331
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 257673 non-null  int64
#  1   dur                257673 non-null  float64
#  2   proto              257673 non-null  object
#  3   service            257673 non-null  object
#  4   state              257673 non-null  object
#  5   spkts              257673 non-null  int64
#  6   dpkts              257673 non-null  int64
#  7   sbytes             257673 non-null  int64
#  8   dbytes             257673 non-null  int64
#  9   rate               257673 non-null  float64
#  10  sttl               257673 non-null  int64
#  11  dttl               257673 non-null  int64
#  12  sload              257673 non-null  float64
#  13  dload              257673 non-null  float64
#  14  sloss              257673 non-null  int64
#  15  dloss              257673 non-null  int64
#  16  sinpkt             257673 non-null  float64
#  17  dinpkt             257673 non-null  float64
#  18  sjit               257673 non-null  float64
#  19  djit               257673 non-null  float64
#  20  swin               257673 non-null  int64
#  21  stcpb              257673 non-null  int64
#  22  dtcpb              257673 non-null  int64
#  23  dwin               257673 non-null  int64
#  24  tcprtt             257673 non-null  float64
#  25  synack             257673 non-null  float64
#  26  ackdat             257673 non-null  float64
#  27  smean              257673 non-null  int64
#  28  dmean              257673 non-null  int64
#  29  trans_depth        257673 non-null  int64
#  30  response_body_len  257673 non-null  int64
#  31  ct_srv_src         257673 non-null  int64
#  32  ct_state_ttl       257673 non-null  int64
#  33  ct_dst_ltm         257673 non-null  int64
#  34  ct_src_dport_ltm   257673 non-null  int64
#  35  ct_dst_sport_ltm   257673 non-null  int64
#  36  ct_dst_src_ltm     257673 non-null  int64
#  37  is_ftp_login       257673 non-null  int64
#  38  ct_ftp_cmd         257673 non-null  int64
#  39  ct_flw_http_mthd   257673 non-null  int64
#  40  ct_src_ltm         257673 non-null  int64
#  41  ct_srv_dst         257673 non-null  int64
#  42  is_sm_ips_ports    257673 non-null  int64
#  43  attack_cat         257673 non-null  object
#  44  label              257673 non-null  int64
# dtypes: float64(11), int64(30), object(4)
# memory usage: 90.4+ MB

# %%
df_train.head(10)
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes       rate  sttl  dttl         sload          dload  sloss  dloss      sinpkt      dinpkt          sjit          djit  swin       stcpb       dtcpb  dwin    tcprtt    synack    ackdat  smean  dmean  trans_depth  response_body_len  ct_srv_src  ct_state_ttl  ct_dst_ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_
0.000000       0.000000  0.000000e+00  0.000000e+00       0.000000       0.000000       0.000000       0.000000      73.000000      44.000000       0.000000       0.000000e+00       5.000000       1.000000       2.000000          1.000000          1.000000        3.000000       0.000000       0.000000          0.000000       3.000000       4.000000         0.000000        NaN       1.000000
# 75%     110923.000000       0.685777     NaN     NaN     NaN      12.000000      10.000000  1.362000e+03  1.064000e+03  1.250000e+05     254.000000     252.000000  8.000000e+07  2.210538e+04       3.000000       2.000000      58.094727      56.438859  2.787367e+03     119.712937     255.000000  2.007375e+09  1.992752e+09     255.000000       0.082082       0.036842       0.044665     100.000000      89.000000       0.000000       0.000000e+00      12.000000       2.000000       6.000000          4.000000          3.000000        8.000000       0.000000       0.000000          0.000000       8.000000      11.000000         0.000000        NaN       1.000000
# max     175341.000000      59.999989     NaN     NaN     NaN   10646.000000   11018.000000  1.435577e+07  1.465753e+07  1.000000e+06     255.000000     254.000000  5.988000e+09  2.242273e+07    5319.000000    5507.000000   84371.496000   57739.240000  1.483831e+06  463199.240100     255.000000  4.294959e+09  4.294882e+09     255.000000       3.821465       3.226788       2.928778    1504.000000    1500.000000     172.000000       6.558056e+06      63.000000       6.000000      59.000000         59.000000         46.000000       65.000000       4.000000       4.000000         30.000000      60.000000      62.000000         1.000000        NaN       1.000000

# %%
# Overview of all the unique features withihn the dataset
mixed_types = df_train.apply(lambda x: any(isinstance(val, str) for val in x))

for column, is_mixed_type in mixed_types.items():
    if is_mixed_type:
        mixed_values = df_train.loc[df_train[column].apply(lambda x: isinstance(x, str)), column].unique()
        print(f"Column '{column}' contains mixed types: {mixed_values}")
# Out:
# Column 'proto' contains mixed types: ['tcp' 'udp' 'arp' 'ospf' 'icmp' 'igmp' 'rtp' 'ddp' 'ipv6-frag' 'cftp'
#  'wsn' 'pvp' 'wb-expak' 'mtp' 'pri-enc' 'sat-mon' 'cphb' 'sun-nd' 'iso-ip'
#  'xtp' 'il' 'unas' 'mfe-nsp' '3pc' 'ipv6-route' 'idrp' 'bna' 'swipe'
#  'kryptolan' 'cpnx' 'rsvp' 'wb-mon' 'vmtp' 'ib' 'dgp' 'eigrp' 'ax.25'
#  'gmtp' 'pnni' 'sep' 'pgm' 'idpr-cmtp' 'zero' 'rvd' 'mobile' 'narp' 'fc'
#  'pipe' 'ipcomp' 'ipv6-no' 'sat-expak' 'ipv6-opts' 'snp' 'ipcv'
#  'br-sat-mon' 'ttp' 'tcf' 'nsfnet-igp' 'sprite-rpc' 'aes-sp3-d' 'sccopmce'
#  'sctp' 'qnx' 'scps' 'etherip' 'aris' 'pim' 'compaq-peer' 'vrrp' 'iatp'
#  'stp' 'l2tp' 'srp' 'sm' 'isis' 'smp' 'fire' 'ptp' 'crtp' 'sps'
#  'merit-inp' 'idpr' 'skip' 'any' 'larp' 'ipip' 'micp' 'encap' 'ifmp'
#  'tp++' 'a/n' 'ipv6' 'i-nlsp' 'ipx-n-ip' 'sdrp' 'tlsp' 'gre' 'mhrp' 'ddx'
#  'ippc' 'visa' 'secure-vmtp' 'uti' 'vines' 'crudp' 'iplt' 'ggp' 'ip'
#  'ipnip' 'st2' 'argus' 'bbn-rcc' 'egp' 'emcon' 'igp' 'nvp' 'pup' 'xnet'
#  'chaos' 'mux' 'dcn' 'hmp' 'prm' 'trunk-1' 'xns-idp' 'leaf-1' 'leaf-2'
#  'rdp' 'irtp' 'iso-tp4' 'netblt' 'trunk-2' 'cbt']
# Column 'service' contains mixed types: ['-' 'ftp' 'smtp' 'snmp' 'http' 'ftp-data' 'dns' 'ssh' 'radius' 'pop3'
#  'dhcp' 'ssl' 'irc']
# Column 'state' contains mixed types: ['FIN' 'INT' 'CON' 'ECO' 'REQ' 'RST' 'PAR' 'URN' 'no' 'ACC' 'CLO']
# Column 'attack_cat' contains mixed types: ['Normal' 'Backdoor' 'Analysis' 'Fuzzers' 'Shellcode' 'Reconnaissance'
#  'Exploits' 'DoS' 'Worms' 'Generic']

# %%
sns.histplot(x = df_train.label)
# Out:
# <Axes: xlabel='label', ylabel='Count'>

# %% [markdown]
# ## 2. Pre-processing

# %%
list_drop = ['id','attack_cat']
df_train.drop(list_drop, axis=1, inplace=True)
#df_test.drop(list_drop, axis=1, inplace=True)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 257673 entries, 0 to 82331
# Data columns (total 43 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dur                257673 non-null  float64
#  1   proto              257673 non-null  object
#  2   service            257673 non-null  object
#  3   state              257673 non-null  object
#  4   spkts              257673 non-null  int64
#  5   dpkts              257673 non-null  int64
#  6   sbytes             257673 non-null  int64
#  7   dbytes             257673 non-null  int64
#  8   rate               257673 non-null  float64
#  9   sttl               257673 non-null  int64
#  10  dttl               257673 non-null  int64
#  11  sload              257673 non-null  float64
#  12  dload              257673 non-null  float64
#  13  sloss              257673 non-null  int64
#  14  dloss              257673 non-null  int64
#  15  sinpkt             257673 non-null  float64
#  16  dinpkt             257673 non-null  float64
#  17  sjit               257673 non-null  float64
#  18  djit               257673 non-null  float64
#  19  swin               257673 non-null  int64
#  20  stcpb              257673 non-null  int64
#  21  dtcpb              257673 non-null  int64
#  22  dwin               257673 non-null  int64
#  23  tcprtt             257673 non-null  float64
#  24  synack             257673 non-null  float64
#  25  ackdat             257673 non-null  float64
#  26  smean              257673 non-null  int64
#  27  dmean              257673 non-null  int64
#  28  trans_depth        257673 non-null  int64
#  29  response_body_len  257673 non-null  int64
#  30  ct_srv_src         257673 non-null  int64
#  31  ct_state_ttl       257673 non-null  int64
#  32  ct_dst_ltm         257673 non-null  int64
#  33  ct_src_dport_ltm   257673 non-null  int64
#  34  ct_dst_sport_ltm   257673 non-null  int64
#  35  ct_dst_src_ltm     257673 non-null  int64
#  36  is_ftp_login       257673 non-null  int64
#  37  ct_ftp_cmd         257673 non-null  int64
#  38  ct_flw_http_mthd   257673 non-null  int64
#  39  ct_src_ltm         257673 non-null  int64
#  40  ct_srv_dst         257673 non-null  int64
#  41  is_sm_ips_ports    257673 non-null  int64
#  42  label              257673 non-null  int64
# dtypes: float64(11), int64(29), object(3)
# memory usage: 86.5+ MB

# %% [markdown]
# ### 2.1 Nummeric feature analysis

# %%
df_numeric_train = df_train.select_dtypes(include=[np.number])
#df_nummeric_test = df_test.select_dtypes(include=[np.number])
df_numeric_train.describe(include='all')
# Out:
#                  dur          spkts          dpkts        sbytes        dbytes          rate           sttl           dttl         sload         dload          sloss          dloss         sinpkt         dinpkt          sjit           djit           swin         stcpb         dtcpb           dwin         tcprtt         synack         ackdat          smean          dmean    trans_depth  response_body_len     ct_srv_src   ct_state_ttl     ct_dst_ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_lt
# max        59.999989   10646.000000   11018.000000  1.435577e+07  1.465753e+07  1.000000e+06     255.000000     254.000000  5.988000e+09  2.242273e+07    5319.000000    5507.000000   84371.496000   57739.240000  1.483831e+06  463199.240100     255.000000  4.294959e+09  4.294882e+09     255.000000       3.821465       3.226788       2.928778    1504.000000    1500.000000     172.000000       6.558056e+06      63.000000       6.000000      59.000000         59.000000         46.000000       65.000000       4.000000       4.000000         30.000000      60.000000      62.000000         1.000000       1.000000

# %%
def clamp_extreme_values(df, debug=False):
    """
    Clamp extreme values in a DataFrame.

    Parameters:
    - df (pd.DataFrame): Input DataFrame.
    - debug (bool): If True, print debug information.

    Returns:
    - pd.DataFrame: DataFrame with extreme values clamped.
    """
    df_numeric = df.select_dtypes(include=[np.number])
    for feature in df_numeric.columns:
        if debug:
            print("Column:", feature)
            print('Max value = ' + str(df_numeric[feature].max()))
            print('(Q2) Median = ' + str(df_numeric[feature].median()))
            print('(Q3) 75th percentile = ' + str(df_numeric[feature].quantile(0.95)))
            print("Max > 10 * Median =", df_numeric[feature].max() > 10 * df_numeric[feature].median())
            print('----------------------------------------------------')

        if df_numeric[feature].max() > 10 * df_numeric[feature].median() and df_numeric[feature].max() > 10:
            df[feature] = np.where(df[feature] < df[feature].quantile(0.95), df[feature], df[feature].quantile(0.95))

    return df

# %%
def apply_log_scaling(df, log_nunique=50, debug=False):
    """
    Apply log-scaling to selected numeric features in a DataFrame.

    Parameters:
    - df (pd.DataFrame): Input DataFrame.
    - log_nunique (int): Threshold for the number of unique values.
    - debug (bool): If True, print debug information.

    Returns:
    - pd.DataFrame: DataFrame with log-scaled features.
    """

    df_numeric = df.select_dtypes(include=[np.number])

    for feature in df_numeric.columns:
        if debug:
            print("Column:", feature)
            print('Unique elements = ' + str(df_numeric[feature].nunique()))
            print("Unique elements > {log} = {values}".format(log=log_nunique, values=df_numeric[feature].nunique() > log_nunique))
            print('----------------------------------------------------')

        if df_numeric[feature].nunique() > log_nunique:
            if df_numeric[feature].min() == 0:
                df[feature] = np.log(df[feature] + 1)
            else:
                df[feature] = np.log(df[feature])

    return df

# %%
def keep_most_used_objects(df, keep_threshold=5, debug=False):
    """
    Keep only the most used objects in categorical features of a DataFrame.

    Parameters:
    - df (pd.DataFrame): Input DataFrame.
    - keep_threshold (int): Threshold for the number of unique values to keep.
    - debug (bool): If True, print debug information.

    Returns:
    - pd.DataFrame: DataFrame with selected categorical features.
    """

    df_cat = df.select_dtypes(exclude=[np.number])

    for feature in df_cat.columns:
        if debug:
            print(feature)
            print('nunique = ' + str(df_cat[feature].nunique()))
            print(df_cat[feature].nunique() >= keep_threshold)
            print(sum(df[feature].isin(df[feature].value_counts().head().index)))
            print('----------------------------------------------------')

        if df_cat[feature].nunique() >= keep_threshold:
            most_used_values = df[feature].value_counts().head().index
            df[feature] = np.where(df[feature].isin(most_used_values), df[feature], '-')

    return df

# %%
df_clamped_train = clamp_extreme_values(df_train, DEBUG)
#df_clamped_test = clamp_extreme_values(df_test, DEBUG)

# %%
df_log_train = apply_log_scaling(df_clamped_train, LOG_NUNIQUE, DEBUG)
#df_log_test = apply_log_scaling(df_clamped_test, LOG_NUNIQUE, DEBUG)

# %% [markdown]
# ### 2.2 Object feature analysis

# %%
df_cat_train = df_log_train.select_dtypes(exclude=[np.number])
#df_cat_test = df_log_test.select_dtypes(exclude=[np.number])

df_cat_train.describe(include='all')
# Out:
#          proto service   state
# count   257673  257673  257673
# unique     133      13      11
# top        tcp       -     FIN
# freq    123041  141321  117164

# %%
df_train = keep_most_used_objects(df_log_train, KEEP_MOST_USED_OBJECTS, DEBUG)
#df_test = keep_most_used_objects(df_log_test, KEEP_MOST_USED_OBJECTS, DEBUG)

# %%
df_cat_train = df_train.select_dtypes(exclude=[np.number])
#df_cat_test = df_test.select_dtypes(exclude=[np.number])
df_cat_train.describe(include='all')
# Out:
#          proto service   state
# count   257673  257673  257673
# unique       6       5       6
# top        tcp       -     FIN
# freq    123041  149701  117164

# %%
df_train[['proto', 'service', 'state']].value_counts()
# Out:
# proto  service   state
# tcp    -         FIN      77905
# udp    dns       INT      57692
# tcp    http      FIN      26972
# udp    -         INT      18607
# -      -         INT      18551
# unas   -         INT      15599
# udp    dns       CON      10675
# tcp    smtp      FIN       6844
#        ftp-data  FIN       5383
# udp    -         CON       5382
# arp    -         INT       3695
# tcp    -         CON       3170
#                  REQ       2511
# ospf   -         INT       2294
#                  REQ        977
# -      -         CON        649
# udp    dns       REQ        234
# arp    -         CON        151
# udp    -         REQ        111
# tcp    -         RST         80
#        smtp      CON         64
#        dns       FIN         60
#        http      CON         36
# -      -         -           15
# tcp    ftp-data  CON          7
#        -         -            4
#        http      RST          3
#        smtp      RST          1
#        ftp-data  -            1
# Name: count, dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 257673 entries, 0 to 82331
# Data columns (total 43 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dur                257673 non-null  float64
#  1   proto              257673 non-null  object
#  2   service            257673 non-null  object
#  3   state              257673 non-null  object
#  4   spkts              257673 non-null  float64
#  5   dpkts              257673 non-null  float64
#  6   sbytes             257673 non-null  float64
#  7   dbytes             257673 non-null  float64
#  8   rate               257673 non-null  float64
#  9   sttl               257673 non-null  int64
#  10  dttl               257673 non-null  int64
#  11  sload              257673 non-null  float64
#  12  dload              257673 non-null  float64
#  13  sloss              257673 non-null  float64
#  14  dloss              257673 non-null  float64
#  15  sinpkt             257673 non-null  float64
#  16  dinpkt             257673 non-null  float64
#  17  sjit               257673 non-null  float64
#  18  djit               257673 non-null  float64
#  19  swin               257673 non-null  float64
#  20  stcpb              257673 non-null  float64
#  21  dtcpb              257673 non-null  float64
#  22  dwin               257673 non-null  float64
#  23  tcprtt             257673 non-null  float64
#  24  synack             257673 non-null  float64
#  25  ackdat             257673 non-null  float64
#  26  smean              257673 non-null  float64
#  27  dmean              257673 non-null  float64
#  28  trans_depth        257673 non-null  float64
#  29  response_body_len  257673 non-null  float64
#  30  ct_srv_src         257673 non-null  float64
#  31  ct_state_ttl       257673 non-null  int64
#  32  ct_dst_ltm         257673 non-null  float64
#  33  ct_src_dport_ltm   257673 non-null  float64
#  34  ct_dst_sport_ltm   257673 non-null  float64
#  35  ct_dst_src_ltm     257673 non-null  float64
#  36  is_ftp_login       257673 non-null  int64
#  37  ct_ftp_cmd         257673 non-null  int64
#  38  ct_flw_http_mthd   257673 non-null  float64
#  39  ct_src_ltm         257673 non-null  float64
#  40  ct_srv_dst         257673 non-null  float64
#  41  is_sm_ips_ports    257673 non-null  int64
#  42  label              257673 non-null  int64
# dtypes: float64(33), int64(7), object(3)
# memory usage: 86.5+ MB

# %%
df_numeric_train = df_train.select_dtypes(include=[np.number])
#df_numeric_test = df_test.select_dtypes(include=[np.number])
df_numeric_train.describe(include='all')
# Out:
#                  dur          spkts          dpkts         sbytes         dbytes           rate           sttl           dttl          sload          dload          sloss          dloss         sinpkt         dinpkt           sjit           djit           swin          stcpb          dtcpb           dwin         tcprtt         synack         ackdat          smean          dmean    trans_depth  response_body_len     ct_srv_src   ct_state_ttl     ct_dst_ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm   is_ftp_login     ct_ftp_cmd  ct_flw_http_mthd     ct_src_ltm     ct_srv_dst  is_sm_ips_ports          label
# count  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000  257673.000000      257673.000000  257673.000000  257673.000000  257673.000000     257673.000000     257673.000000   257673.000000  257673.000000  257673.000000     257673.000000  257673.000000  257673.000000    257673.000000  257673.000000
# mean        0.279701       1.752784       1.367635       6.230272       3.823273       7.719155     180.000931      84.754957      13.782463       5.649463       2.180974       2.956693       1.799721       1.596932       3.564474       2.252746     121.753661       9.906846       9.903646     119.254629       0.041886       0.022283       0.021281       4.486114       2.533020       0.098660           0.327130       9.114517       1.324978       5.658528          4.861627          3.879448        8.051511       0.012819       0.012850          0.098652       6.382822       8.857366         0.014274       0.639077
# std         0.404365       1.196432       1.435571       1.474944       3.798091       4.116677     102.488268     112.762131       4.582378       5.659006       3.265256       6.008834       2.091078       2.045817       3.856609       2.719011     127.367443      10.588147      10.586260     127.230477       0.075568       0.044684       0.040134       0.673732       2.479525       0.298205           1.234621      10.058965       0.992300       6.866560          6.864614          5.367192       10.333915       0.116091       0.116421          0.298195       7.084512      10.116552         0.118618       0.480269
# min         0.000000       0.000000       0.000000       3.178054       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       3.178054       0.000000       0.000000           0.000000       1.000000       0.000000       1.000000          1.000000          1.000000        1.000000       0.000000       0.000000          0.000000       1.000000       1.000000         0.000000       0.000000
# 25%         0.000008       0.693147       0.000000       4.736198       0.000000       3.459129      62.000000       0.000000       9.418898       0.000000       0.000000       0.000000       0.007968       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       4.043051       0.000000       0.000000           0.000000       2.000000       1.000000       1.000000          1.000000          1.000000        1.000000       0.000000       0.000000          0.000000       2.000000       2.000000         0.000000       0.000000
# 50%         0.004276       1.386294       1.098612       6.269096       5.187386       7.991817     254.000000      29.000000      13.519720       7.466480       0.000000       0.000000       0.323312       0.006976       0.514999       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       0.000000       4.290459       3.806662       0.000000           0.000000       5.000000       1.000000       2.000000          1.000000          1.000000        3.000000       0.000000       0.000000          0.000000       3.000000       4.000000         0.000000       1.000000
# 75%         0.522227       2.484907       2.397895       7.216709       6.970730      11.736077     254.000000     252.000000      18.197537      10.003622       3.000000       2.000000       4.079142       4.050721       7.933212       4.793415     255.000000      21.420094      21.412782     255.000000       0.078887       0.036180       0.043696       4.605170       4.499810       0.000000           0.000000      12.000000       2.000000       6.000000          4.000000          3.000000        8.000000       0.000000       0.000000          0.000000       8.000000      11.000000         0.000000       1.000000
# max         1.338000       4.127134       4.143135       9.507032      10.405626      12.716901     255.000000     254.000000      19.401510      15.193128      12.000000      24.000000       5.436469       5.099135       9.162146       7.929434     255.000000      22.067684      22.065875     255.000000       1.573078       1.441442       1.368328       6.458338       6.646910       1.000000           5.075174      34.000000       6.000000      25.000000         25.000000         17.000000       34.000000       4.000000       4.000000          1.000000      25.000000      34.000000         1.000000       1.000000

# %%
# Feature Selection
from sklearn.feature_selection import SelectKBest, chi2

best_features = SelectKBest(score_func=chi2, k='all')

X = df_numeric_train.iloc[:, :-1]
y = df_numeric_train.iloc[:, -1] # Chi-Square Score for the column "labels" 
fit = best_features.fit(X, y)

df_scores = pd.DataFrame(fit.scores_)
df_col = pd.DataFrame(X.columns)

feature_score = pd.concat([df_col, df_scores], axis=1)
feature_score.columns = ['feature', 'score']
feature_score.sort_values(by=['score'], ascending=True, inplace=True)

# Top 20 Features
top_20_features = feature_score[0:21]

plt.figure(figsize=(10, 8))
plt.barh(top_20_features['feature'], top_20_features['score'], color='skyblue')
plt.title('Top 20 Features')
plt.xlabel('Chi-Square Score')
plt.ylabel('Features')
plt.show()

# %%
corr_matrix = df_numeric_train.corr()
plt.figure(figsize=(20, 20))

sns.heatmap(corr_matrix[(corr_matrix >= 0.4) | (corr_matrix <= -0.4)], vmax=1.0, 
            vmin=-1.0, linewidths=0.1, annot=True, annot_kws={"size": 6}, square=True)
plt.title('Korrelationsmatrix')
plt.show()

# %%
df_num_corr = df_numeric_train.corr(numeric_only=True)['label']
df_num_corr = df_num_corr[df_num_corr >= -1]
print(df_num_corr)
# Out:
# dur                 -0.038107
# spkts               -0.358317
# dpkts               -0.461601
# sbytes              -0.335856
# dbytes              -0.497162
# rate                 0.314953
# sttl                 0.624082
# dttl                 0.019369
# sload                0.342124
# dload               -0.589788
# sloss               -0.335394
# dloss               -0.340104
# sinpkt              -0.137335
# dinpkt              -0.075330
# sjit                -0.198024
# djit                -0.185304
# swin                -0.364877
# stcpb               -0.338998
# dtcpb               -0.338368
# dwin                -0.339166
# tcprtt              -0.013399
# synack              -0.038525
# ackdat               0.008813
# smean               -0.067186
# dmean               -0.513907
# trans_depth         -0.001805
# response_body_len   -0.076967
# ct_srv_src           0.250457
# ct_state_ttl         0.476559
# ct_dst_ltm           0.247052
# ct_src_dport_ltm     0.339795
# ct_dst_sport_ltm     0.387176
# ct_dst_src_ltm       0.307422
# is_ftp_login        -0.008762
# ct_ftp_cmd          -0.009092
# ct_flw_http_mthd    -0.001825
# ct_src_ltm           0.258960
# ct_srv_dst           0.251298
# is_sm_ips_ports     -0.160126
# label                1.000000
# Name: label, dtype: float64

# %%
golden_features_list = df_num_corr[abs(df_num_corr) > abs(0.4)].sort_values(ascending=False)
print("There are {} strongly correlated values with Target:\n{}".format(len(golden_features_list), golden_features_list))
# Out:
# There are 7 strongly correlated values with Target:
# label           1.000000
# sttl            0.624082
# ct_state_ttl    0.476559
# dpkts          -0.461601
# dbytes         -0.497162
# dmean          -0.513907
# dload          -0.589788
# Name: label, dtype: float64

# %% [markdown]
# ## 3. Categorical feature encoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
X = df_train.iloc[:,:-1]
y = df_train.iloc[:,-1]

# %%
feature_names = list(X.columns)
np.shape(X)
# Out:
# (257673, 42)

# %%
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1,2,3])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
np.shape(X)
# Out:
# (257673, 56)

# %%
len(feature_names)
# Out:
# 42

# %%
for label in list(df_cat_train['state'].value_counts().index)[::-1][1:]:
    feature_names.insert(0,label)
    
for label in list(df_cat_train['service'].value_counts().index)[::-1][1:]:
    feature_names.insert(0,label)
    
for label in list(df_cat_train['proto'].value_counts().index)[::-1][1:]:
    feature_names.insert(0,label)

# %%
len(feature_names)
# Out:
# 56

# %% [markdown]
# ## 4. Implementation and modeling

# %% [markdown]
# ### 4.0 Setup

# %%
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix

# %%
model_performance = pd.DataFrame(columns=['Accuracy','Recall','Precision',
                                          'F1-Score','time to train','time to predict','total time'])

# %%
NUMBER_OF_CLASSES = len(feature_names)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0, stratify=y, shuffle=True)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1, random_state = 0, stratify=y_train, shuffle=True)

# %%
sc = StandardScaler()
X_train[:, 18:] = sc.fit_transform(X_train[:, 18:])
X_test[:, 18:] = sc.transform(X_test[:, 18:])
#X_val[:, 18:] = sc.transform(X_val[:, 18:])

# %%
fig, axs = plt.subplots(3, 1, figsize=(10, 20))

# Plot für den ersten Subplot (X)
axs[0].plot(np.arange(NUMBER_OF_CLASSES), X[0])
axs[0].set_title("Dataset before scaling")
axs[0].grid()
axs[0].set_xticks(np.arange(NUMBER_OF_CLASSES))
axs[0].set_xticklabels(feature_names, rotation=90)  # Hier wird die Rotation hinzugefügt

# Plot für den zweiten Subplot (X_train)
axs[1].plot(np.arange(NUMBER_OF_CLASSES), X_train[0])
axs[1].set_title("Trainset after scaling")
axs[1].grid()
axs[1].set_xticks(np.arange(NUMBER_OF_CLASSES))
axs[1].set_xticklabels(feature_names, rotation=90)  # Hier wird die Rotation hinzugefügt

# Plot für den dritten Subplot (X_test)
axs[2].plot(np.arange(NUMBER_OF_CLASSES), X_test[0])
axs[2].set_title("Testset after scaling")
axs[2].grid()
axs[2].set_xticks(np.arange(NUMBER_OF_CLASSES))
axs[2].set_xticklabels(feature_names, rotation=90)  # Hier wird die Rotation hinzugefügt

plt.tight_layout()
plt.show()

# %%
Toller code stopper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 rdefdfdf
#
# NameError: name 'rdefdfdf' is not defined

# %% [markdown]
# ### 4.1 Klassification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
# from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, ExtraTreesClassifier, RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
if TRAIN_DATA_FROM_SCRATCH:
    # List of models to train
    models = {
        'Logistische Regression' : LogisticRegression(),
        'k-NN': KNeighborsClassifier(),
        'Entscheidungsbaum': DecisionTreeClassifier(),
        'Extra Trees': ExtraTreesClassifier(),
        'Random Forest': RandomForestClassifier(),
        'GradientBoostingClassifier': GradientBoostingClassifier()}
    # Parameter to use in grid search
    param_grid = {
        'Logistische Regression': {'max_iter': [5000, 7500], 'solver': ['lbfgs', 'newton-cg', 'sag', 'saga']},
        'k-NN': {'n_neighbors': [3, 5, 7], 'leaf_size': [10, 30, 50, 70]},
        'Entscheidungsbaum': {'max_depth': [ 5, 7, 10, 13], 'min_samples_split': [5, 8, 12], 'min_samples_leaf': [3, 5, 7, 15]},
        'Extra Trees': {'n_estimators': [50, 200], 'max_depth': [5, 7, 10, 13]},
        'Random Forest': {'n_estimators': [50, 200], 'max_depth': [5, 7, 10, 13]},
        'GradientBoostingClassifier': {'n_estimators': [100, 200], 'learning_rate': [0.1, 0.2]}
    }

    results = []
    try:
        for model_name, model in models.items():

            grid_search = GridSearchCV(model, param_grid[model_name], cv=3, n_jobs=-1)
            grid_search.fit(X_train, y_train)
            best_params = grid_search.best_params_
            
            model.set_params(**best_params)
            start_time = time.time()
            model.fit(X_train, y_train)
            training_time = time.time() - start_time
            
            start_time = time.time()
            y_pred = model.predict(X_test)
            prediction_time = time.time() - start_time
            
            accuracy = accuracy_score(y_test, y_pred)
            recall = recall_score(y_test, y_pred, average='weighted')
            precision = precision_score(y_test, y_pred, average='weighted')
            f1 = f1_score(y_test, y_pred, average='weighted')
            
            results.append({
                'Modell': model_name,
                'Parameter': best_params,
                'Trainingszeit': training_time,
                'Vorhersagezeit': prediction_time,
                'Genauigkeit': accuracy,
                'Recall': recall,
                'Precision': precision,
                'F1 Score': f1,
            })
            print("Trainierte Modelle:", model_name)
        df_results = pd.DataFrame(results)
        df_results.to_csv('./data/df_results_k.csv', index=False)
        
    except Exception as e:
        print(f"Fehler beim Trainieren und Speichern der Ergebnisse: {e}")
        df_results = pd.DataFrame()
else:
    try:
        df_results = pd.read_csv('./data/df_results_k.csv')
        print("Ergebnisse erfolgreich geladen.")
    except FileNotFoundError:
        print("Die Datei df_results_k.csv wurde nicht gefunden.")
        df_results = pd.DataFrame()
# Out:
# Trainierte Modelle: Logistische Regression
# Trainierte Modelle: k-NN
# Trainierte Modelle: Entscheidungsbaum
# Trainierte Modelle: Extra Trees
# Trainierte Modelle: Random Forest
# Trainierte Modelle: GradientBoostingClassifier

# %% [markdown]
# ### 4.2 Deep-Learning structures

# %%
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, GRU, Dropout
from keras import layers
import keras 
from numpy import array
import tensorflow as tf

# %%
results = []

# %%
TRAIN_DATA_FROM_SCRATCH = False # Default: False
TOTAL_FEATURES = len(feature_names)
EPOCHS = 200 # Default: 200
BATCH_SIZE = 1000 # Default: 1000
LEARNING_RATE = 0.001 # Default: 0.01
EARLY_STOPPING_PATIENCE = 10 # Default: 10; When "EPOCHS" = Train until complete

# %%
SPARSITY_WEIGHT = 0.0001  # Used for Sparse autoencoder: default 0.0001
MODEL_NAME = "SAE"

# %%
#The LSTM and GRU input layer must be 3D.
#The meaning of the 3 input dimensions are: samples, time steps, and total amount of features.
#Since we are not using 
X_train_array = array(X_train) 
X_test_array  = array(X_test)
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0] ,1 ,TOTAL_FEATURES)
X_test_reshaped  = X_test_array.reshape(X_test_array.shape[0] ,1 ,TOTAL_FEATURES)

# %%
X_train_reshaped.shape
# Out:
# (206138, 1, 56)

# %% [markdown]
# #### 4.2.0 Helper Functions

# %%
# Helper function to calculate the accuracy
def evaluate_model(model, X, y_true, print_output=True, number_of_outputs=1):
    if number_of_outputs == 1:
        y_pred = model.predict(X)
    else:
        _, y_pred = model.predict(X)
        
    y_pred_classes = y_pred.argmax(axis=-1)
    accuracy = accuracy_score(y_true, y_pred_classes)
    recall = recall_score(y_true, y_pred_classes, average='weighted')
    precision = precision_score(y_true, y_pred_classes, average='weighted')
    f1 = f1_score(y_true, y_pred_classes, average='weighted')
    
    end_predict = time.time()
    
    if print_output:
        print("Modell:",model.name)
        print("Genauigkeit:", accuracy)
        print("Recall:", recall)
        print("Precision:", precision)
        print("F1 Score:", f1)
        
    return accuracy, recall, precision, f1, end_predict

# %%
# Helper function to calculate the accuracy for models using timeseries 
def evaluate_model_timeseries(model, X, y_true, print_output=True, number_of_outputs=1):

    if number_of_outputs == 1:
        reconstructions= model.predict(X)
    else:
        reconstructions, _ = model.predict(X)
    
    test_loss = tf.keras.losses.mae(reconstructions, X)
    threshold_test = (np.mean(test_loss) + np.std(test_loss))
    predictions_final = np.where(np.mean((test_loss < threshold_test).numpy().astype(int), axis=1) < 1, 0, 1)
    
    accuracy = accuracy_score(y_true, predictions_final)
    recall = recall_score(y_true, predictions_final, average='weighted')
    precision = precision_score(y_true, predictions_final, average='weighted')
    f1 = f1_score(y_true, predictions_final, average='weighted')
    
    end_predict = time.time()
    
    if print_output:
        print("Modell:",model.name)
        print("Genauigkeit:", accuracy)
        print("Recall:", recall)
        print("Precision:", precision)
        print("F1 Score:", f1)
        
    return accuracy, recall, precision, f1, end_predict

# %%
def append_model_reults(model, results, training_time, prediction_time, accuracy, recall, precision, f1):
    
    results.append({
        'Modell': model.name,
        'Parameter': "",
        'Trainingszeit': training_time,
        'Vorhersagezeit': prediction_time,
        'Genauigkeit': accuracy,
        'Recall': recall,
        'Precision': precision,
        'F1 Score': f1
        })
    return results

# %%
def save_plot_history_to_json(name, hist):
    try:
        with open('train_histories.json', 'r') as file:
            data = file.read()
            if data:
                list = json.loads(data)
            else:
                list = []
    except FileNotFoundError:
        list = []

    version = 1
    unique_name = f'Model_{name}'

    while any(entry['model_name'] == unique_name for entry in list):
        version += 1
        unique_name = f'Model_{name}_v{version}'

    history_dict = {
        'model_name': unique_name, 
        'epoch': np.array(hist.epoch).tolist(),
    }

    if 'accuracy' in hist.history:
        history_dict['accuracy'] = np.array(hist.history['accuracy']).tolist()
    if 'loss' in hist.history:
        history_dict['loss'] = np.array(hist.history['loss']).tolist()
    if 'val_loss' in hist.history:
        history_dict['val_loss'] = np.array(hist.history['val_loss']).tolist()
    
    list.append(history_dict) 
    with open('train_histories.json', 'w') as file:
        json.dump(list, file)

# %%
def plot_autoencoder_reconstruction(decoded_data, X_test):
    total_subplots = 16
    selected_features = random.sample(range(X_test.shape[0]), total_subplots)

    plt.figure(figsize=(20, 10))
    for idx, feature_idx in enumerate(selected_features):
        plt.subplot(4, 4, idx + 1)
        plt.plot(X_test[idx, 0], 'b')
        plt.plot(decoded_data[idx, 0], 'r', linewidth=0.5)
        plt.fill_between(np.arange(TOTAL_FEATURES), decoded_data[idx, 0], X_test[idx, 0], color='lightcoral', alpha=0.7)
        plt.title(f'Feature {feature_idx + 1}')
        plt.legend(labels=["Input", "Reconstruction", "Error"])
        plt.suptitle("Modell: {model}".format(model=MODEL_NAME), fontsize=20)

    plt.tight_layout()
    plt.show()

# %%
def plot_mae_distribution(model, X, labels, number_of_outputs=1):
    if number_of_outputs == 1:
        reconstructions = model.predict(X)
    else:
        reconstructions,_ = model.predict(X)
    loss = tf.keras.losses.mae(reconstructions, X)
    threshold = (np.mean(loss) + np.std(loss))
    predictions = np.where(np.mean((loss < threshold).numpy().astype(int), axis=1) < 1, 0, 1)

    accuracy = accuracy_score(labels, predictions)
    
    loss_reduced = tf.reshape(loss, [loss.shape[0], -1])
    
    plt.title("Model: {model}, Threshold: {thresh:.2f}, Accuracy: {acc:.2%}".format(model=MODEL_NAME,thresh=threshold, acc=accuracy))
    plt.hist(loss_reduced.numpy(), bins=50)
    plt.xlabel("Train loss")
    plt.ylabel("No of examples")
    plt.show()

# %%
Toller code stopper
# Out:
#   Cell In[125], line 1
#     Code stopper
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 4.2.1 MLP Classifier

# %%
def build_model_mlp():
    model = Sequential(name="MLP_Classifier")
    model.add(Dense(128, input_dim=TOTAL_FEATURES, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(20, activation='softmax'))
    
    opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics='accuracy')
    
    return model

# %%
model = build_model_mlp()

# %%
start = time.time()
history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)
# history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2, validation_data=(X_val, y_val))
end_train = time.time()
# Out:
# Epoch 1/200
# 209/209 - 1s - loss: 0.4006 - accuracy: 0.8668 - val_loss: 0.1682 - val_accuracy: 0.9143 - 1s/epoch - 7ms/step
# Epoch 2/200
# 209/209 - 1s - loss: 0.1620 - accuracy: 0.9160 - val_loss: 0.1555 - val_accuracy: 0.9209 - 683ms/epoch - 3ms/step
# Epoch 3/200
# 209/209 - 1s - loss: 0.1544 - accuracy: 0.9208 - val_loss: 0.1503 - val_accuracy: 0.9242 - 763ms/epoch - 4ms/step
# Epoch 4/200
# 209/209 - 1s - loss: 0.1492 - accuracy: 0.9241 - val_loss: 0.1453 - val_accuracy: 0.9262 - 667ms/epoch - 3ms/step
# Epoch 5/200
# 209/209 - 1s - loss: 0.1454 - accuracy: 0.9270 - val_loss: 0.1470 - val_accuracy: 0.9270 - 676ms/epoch - 3ms/step
# Epoch 6/200
# 209/209 - 1s - loss: 0.1411 - accuracy: 0.9295 - val_loss: 0.1440 - val_accuracy: 0.9262 - 644ms/epoch - 3ms/step
# Epoch 7/200
# 209/209 - 1s - loss: 0.1397 - accuracy: 0.9302 - val_loss: 0.1382 - val_accuracy: 0.9318 - 598ms/epoch - 3ms/step
# Epoch 8/200
# 209/209 - 1s - loss: 0.1393 - accuracy: 0.9305 - val_loss: 0.1370 - val_accuracy: 0.9298 - 633ms/epoch - 3ms/step
# Epoch 9/200
# 209/209 - 1s - loss: 0.1355 - accuracy: 0.9327 - val_loss: 0.1446 - val_accuracy: 0.9292 - 663ms/epoch - 3ms/step
# Epoch 10/200
# 209/209 - 1s - loss: 0.1349 - accuracy: 0.9330 - val_loss: 0.1388 - val_accuracy: 0.9314 - 589ms/epoch - 3ms/step
# Epoch 11/200
# 209/209 - 1s - loss: 0.1340 - accuracy: 0.9333 - val_loss: 0.1333 - val_accuracy: 0.9333 - 576ms/epoch - 3ms/step
# Epoch 12/200
# 209/209 - 1s - loss: 0.1330 - accuracy: 0.9339 - val_loss: 0.1339 - val_accuracy: 0.9326 - 624ms/epoch - 3ms/step
# Epoch 13/200
# 209/209 - 1s - loss: 0.1319 - accuracy: 0.9342 - val_loss: 0.1336 - val_accuracy: 0.9333 - 668ms/epoch - 3ms/step
# Epoch 14/200
# 209/209 - 1s - loss: 0.1313 - accuracy: 0.9347 - val_loss: 0.1332 - val_accuracy: 0.9324 - 579ms/epoch - 3ms/step
# Epoch 15/200
# 209/209 - 1s - loss: 0.1307 - accuracy: 0.9353 - val_loss: 0.1305 - val_accuracy: 0.9360 - 591ms/epoch - 3ms/step
# Epoch 16/200
# 209/209 - 1s - loss: 0.1307 - accuracy: 0.9345 - val_loss: 0.1471 - val_accuracy: 0.9232 - 579ms/epoch - 3ms/step
# Epoch 17/200
# 209/209 - 1s - loss: 0.1306 - accuracy: 0.9344 - val_loss: 0.1357 - val_accuracy: 0.9317 - 638ms/epoch - 3ms/step
# Epoch 18/200
# 209/209 - 1s - loss: 0.1293 - accuracy: 0.9359 - val_loss: 0.1313 - val_accuracy: 0.9340 - 608ms/epoch - 3ms/step
# Epoch 19/200
# 209/209 - 1s - loss: 0.1290 - accuracy: 0.9362 - val_loss: 0.1296 - val_accuracy: 0.9352 - 584ms/epoch - 3ms/step
# Epoch 20/200
# 209/209 - 1s - loss: 0.1292 - accuracy: 0.9353 - val_loss: 0.1304 - val_accuracy: 0.9353 - 609ms/epoch - 3ms/step
# Epoch 21/200
# 209/209 - 1s - loss: 0.1279 - accuracy: 0.9360 - val_loss: 0.1300 - val_accuracy: 0.9355 - 586ms/epoch - 3ms/step
# Epoch 22/200
# 209/209 - 1s - loss: 0.1276 - accuracy: 0.9362 - val_loss: 0.1381 - val_accuracy: 0.9317 - 616ms/epoch - 3ms/step
# Epoch 23/200
# 209/209 - 1s - loss: 0.1272 - accuracy: 0.9366 - val_loss: 0.1299 - val_accuracy: 0.9351 - 552ms/epoch - 3ms/step
# Epoch 24/200
# 209/209 - 1s - loss: 0.1270 - accuracy: 0.9371 - val_loss: 0.1309 - val_accuracy: 0.9328 - 575ms/epoch - 3ms/step
# Epoch 25/200
# 209/209 - 1s - loss: 0.1270 - accuracy: 0.9365 - val_loss: 0.1293 - val_accuracy: 0.9351 - 577ms/epoch - 3ms/step
# Epoch 26/200
# 209/209 - 1s - loss: 0.1263 - accuracy: 0.9373 - val_loss: 0.1298 - val_accuracy: 0.9343 - 597ms/epoch - 3ms/step
# Epoch 27/200
# 209/209 - 1s - loss: 0.1259 - accuracy: 0.9376 - val_loss: 0.1274 - val_accuracy: 0.9359 - 575ms/epoch - 3ms/step
# Epoch 28/200
# 209/209 - 1s - loss: 0.1254 - accuracy: 0.9376 - val_loss: 0.1279 - val_accuracy: 0.9364 - 530ms/epoch - 3ms/step
# Epoch 29/200
# 209/209 - 1s - loss: 0.1258 - accuracy: 0.9372 - val_loss: 0.1284 - val_accuracy: 0.9346 - 573ms/epoch - 3ms/step
# Epoch 30/200
# 209/209 - 1s - loss: 0.1247 - accuracy: 0.9378 - val_loss: 0.1295 - val_accuracy: 0.9357 - 576ms/epoch - 3ms/step
# Epoch 31/200
# 209/209 - 1s - loss: 0.1250 - accuracy: 0.9378 - val_loss: 0.1268 - val_accuracy: 0.9355 - 545ms/epoch - 3ms/step
# Epoch 32/200
# 209/209 - 1s - loss: 0.1247 - accuracy: 0.9380 - val_loss: 0.1289 - val_accuracy: 0.9364 - 561ms/epoch - 3ms/step
# Epoch 33/200
# 209/209 - 1s - loss: 0.1244 - accuracy: 0.9380 - val_loss: 0.1273 - val_accuracy: 0.9358 - 538ms/epoch - 3ms/step
# Epoch 34/200
# 209/209 - 1s - loss: 0.1240 - accuracy: 0.9382 - val_loss: 0.1272 - val_accuracy: 0.9364 - 548ms/epoch - 3ms/step
# Epoch 35/200
# 209/209 - 1s - loss: 0.1234 - accuracy: 0.9382 - val_loss: 0.1268 - val_accuracy: 0.9372 - 613ms/epoch - 3ms/step
# Epoch 36/200
# 209/209 - 1s - loss: 0.1235 - accuracy: 0.9383 - val_loss: 0.1280 - val_accuracy: 0.9353 - 588ms/epoch - 3ms/step
# Epoch 37/200
# 209/209 - 1s - loss: 0.1239 - accuracy: 0.9377 - val_loss: 0.1299 - val_accuracy: 0.9353 - 594ms/epoch - 3ms/step
# Epoch 38/200
# 209/209 - 1s - loss: 0.1236 - accuracy: 0.9388 - val_loss: 0.1289 - val_accuracy: 0.9354 - 525ms/epoch - 3ms/step
# Epoch 39/200
# 209/209 - 1s - loss: 0.1229 - accuracy: 0.9389 - val_loss: 0.1274 - val_accuracy: 0.9369 - 584ms/epoch - 3ms/step
# Epoch 40/200
# 209/209 - 1s - loss: 0.1225 - accuracy: 0.9388 - val_loss: 0.1260 - val_accuracy: 0.9373 - 529ms/epoch - 3ms/step
# Epoch 41/200
# 209/209 - 1s - loss: 0.1227 - accuracy: 0.9393 - val_loss: 0.1260 - val_accuracy: 0.9381 - 549ms/epoch - 3ms/step
# Epoch 42/200
# 209/209 - 1s - loss: 0.1227 - accuracy: 0.9387 - val_loss: 0.1267 - val_accuracy: 0.9372 - 560ms/epoch - 3ms/step
# Epoch 43/200
# 209/209 - 1s - loss: 0.1220 - accuracy: 0.9392 - val_loss: 0.1301 - val_accuracy: 0.9356 - 567ms/epoch - 3ms/step
# Epoch 44/200
# 209/209 - 1s - loss: 0.1221 - accuracy: 0.9393 - val_loss: 0.1269 - val_accuracy: 0.9367 - 602ms/epoch - 3ms/step
# Epoch 45/200
# 209/209 - 1s - loss: 0.1216 - accuracy: 0.9395 - val_loss: 0.1265 - val_accuracy: 0.9370 - 532ms/epoch - 3ms/step
# Epoch 46/200
# 209/209 - 1s - loss: 0.1210 - accuracy: 0.9397 - val_loss: 0.1258 - val_accuracy: 0.9375 - 547ms/epoch - 3ms/step
# Epoch 47/200
# 209/209 - 1s - loss: 0.1214 - accuracy: 0.9397 - val_loss: 0.1265 - val_accuracy: 0.9364 - 643ms/epoch - 3ms/step
# Epoch 48/200
# 209/209 - 1s - loss: 0.1213 - accuracy: 0.9397 - val_loss: 0.1269 - val_accuracy: 0.9370 - 619ms/epoch - 3ms/step
# Epoch 49/200
# 209/209 - 1s - loss: 0.1210 - accuracy: 0.9400 - val_loss: 0.1297 - val_accuracy: 0.9371 - 613ms/epoch - 3ms/step
# Epoch 50/200
# 209/209 - 1s - loss: 0.1205 - accuracy: 0.9402 - val_loss: 0.1255 - val_accuracy: 0.9375 - 628ms/epoch - 3ms/step
# Epoch 51/200
# 209/209 - 1s - loss: 0.1203 - accuracy: 0.9401 - val_loss: 0.1246 - val_accuracy: 0.9396 - 641ms/epoch - 3ms/step
# Epoch 52/200
# 209/209 - 1s - loss: 0.1195 - accuracy: 0.9406 - val_loss: 0.1266 - val_accuracy: 0.9377 - 627ms/epoch - 3ms/step
# Epoch 53/200
# 209/209 - 1s - loss: 0.1204 - accuracy: 0.9402 - val_loss: 0.1288 - val_accuracy: 0.9358 - 598ms/epoch - 3ms/step
# Epoch 54/200
# 209/209 - 1s - loss: 0.1195 - accuracy: 0.9406 - val_loss: 0.1242 - val_accuracy: 0.9388 - 586ms/epoch - 3ms/step
# Epoch 55/200
# 209/209 - 1s - loss: 0.1197 - accuracy: 0.9405 - val_loss: 0.1263 - val_accuracy: 0.9393 - 562ms/epoch - 3ms/step
# Epoch 56/200
# 209/209 - 1s - loss: 0.1193 - accuracy: 0.9405 - val_loss: 0.1250 - val_accuracy: 0.9379 - 578ms/epoch - 3ms/step
# Epoch 57/200
# 209/209 - 1s - loss: 0.1195 - accuracy: 0.9408 - val_loss: 0.1242 - val_accuracy: 0.9404 - 544ms/epoch - 3ms/step
# Epoch 58/200
# 209/209 - 1s - loss: 0.1192 - accuracy: 0.9413 - val_loss: 0.1280 - val_accuracy: 0.9369 - 527ms/epoch - 3ms/step
# Epoch 59/200
# 209/209 - 1s - loss: 0.1191 - accuracy: 0.9407 - val_loss: 0.1263 - val_accuracy: 0.9380 - 522ms/epoch - 2ms/step
# Epoch 60/200
# 209/209 - 1s - loss: 0.1195 - accuracy: 0.9406 - val_loss: 0.1253 - val_accuracy: 0.9378 - 558ms/epoch - 3ms/step
# Epoch 61/200
# 209/209 - 1s - loss: 0.1183 - accuracy: 0.9410 - val_loss: 0.1250 - val_accuracy: 0.9378 - 570ms/epoch - 3ms/step
# Epoch 62/200
# 209/209 - 1s - loss: 0.1180 - accuracy: 0.9416 - val_loss: 0.1269 - val_accuracy: 0.9377 - 560ms/epoch - 3ms/step
# Epoch 63/200
# 209/209 - 1s - loss: 0.1185 - accuracy: 0.9413 - val_loss: 0.1258 - val_accuracy: 0.9397 - 553ms/epoch - 3ms/step
# Epoch 64/200
# 209/209 - 1s - loss: 0.1179 - accuracy: 0.9416 - val_loss: 0.1247 - val_accuracy: 0.9391 - 554ms/epoch - 3ms/step
# Epoch 65/200
# 209/209 - 1s - loss: 0.1182 - accuracy: 0.9415 - val_loss: 0.1248 - val_accuracy: 0.9384 - 590ms/epoch - 3ms/step
# Epoch 66/200
# 209/209 - 1s - loss: 0.1182 - accuracy: 0.9417 - val_loss: 0.1256 - val_accuracy: 0.9384 - 550ms/epoch - 3ms/step
# Epoch 67/200
# 209/209 - 1s - loss: 0.1177 - accuracy: 0.9418 - val_loss: 0.1263 - val_accuracy: 0.9388 - 559ms/epoch - 3ms/step
# Epoch 68/200
# 209/209 - 1s - loss: 0.1175 - accuracy: 0.9415 - val_loss: 0.1248 - val_accuracy: 0.9395 - 573ms/epoch - 3ms/step
# Epoch 69/200
# 209/209 - 1s - loss: 0.1172 - accuracy: 0.9415 - val_loss: 0.1259 - val_accuracy: 0.9383 - 584ms/epoch - 3ms/step
# Epoch 70/200
# 209/209 - 1s - loss: 0.1173 - accuracy: 0.9418 - val_loss: 0.1260 - val_accuracy: 0.9380 - 583ms/epoch - 3ms/step
# Epoch 71/200
# 209/209 - 1s - loss: 0.1170 - accuracy: 0.9419 - val_loss: 0.1247 - val_accuracy: 0.9389 - 602ms/epoch - 3ms/step
# Epoch 72/200
# 209/209 - 1s - loss: 0.1170 - accuracy: 0.9421 - val_loss: 0.1261 - val_accuracy: 0.9380 - 586ms/epoch - 3ms/step
# Epoch 73/200
# 209/209 - 1s - loss: 0.1165 - accuracy: 0.9424 - val_loss: 0.1239 - val_accuracy: 0.9392 - 660ms/epoch - 3ms/step
# Epoch 74/200
# 209/209 - 1s - loss: 0.1168 - accuracy: 0.9421 - val_loss: 0.1242 - val_accuracy: 0.9384 - 617ms/epoch - 3ms/step
# Epoch 75/200
# 209/209 - 1s - loss: 0.1166 - accuracy: 0.9421 - val_loss: 0.1250 - val_accuracy: 0.9392 - 627ms/epoch - 3ms/step
# Epoch 76/200
# 209/209 - 1s - loss: 0.1163 - accuracy: 0.9429 - val_loss: 0.1244 - val_accuracy: 0.9392 - 665ms/epoch - 3ms/step
# Epoch 77/200
# 209/209 - 1s - loss: 0.1163 - accuracy: 0.9427 - val_loss: 0.1260 - val_accuracy: 0.9390 - 625ms/epoch - 3ms/step
# Epoch 78/200
# 209/209 - 1s - loss: 0.1160 - accuracy: 0.9423 - val_loss: 0.1239 - val_accuracy: 0.9389 - 632ms/epoch - 3ms/step
# Epoch 79/200
# 209/209 - 1s - loss: 0.1159 - accuracy: 0.9426 - val_loss: 0.1276 - val_accuracy: 0.9376 - 586ms/epoch - 3ms/step
# Epoch 80/200
# 209/209 - 1s - loss: 0.1159 - accuracy: 0.9426 - val_loss: 0.1269 - val_accuracy: 0.9379 - 573ms/epoch - 3ms/step
# Epoch 81/200
# 209/209 - 1s - loss: 0.1152 - accuracy: 0.9429 - val_loss: 0.1245 - val_accuracy: 0.9398 - 588ms/epoch - 3ms/step
# Epoch 82/200
# 209/209 - 1s - loss: 0.1157 - accuracy: 0.9428 - val_loss: 0.1262 - val_accuracy: 0.9379 - 620ms/epoch - 3ms/step
# Epoch 83/200
# 209/209 - 1s - loss: 0.1157 - accuracy: 0.9427 - val_loss: 0.1257 - val_accuracy: 0.9383 - 571ms/epoch - 3ms/step
# Epoch 84/200
# 209/209 - 1s - loss: 0.1155 - accuracy: 0.9429 - val_loss: 0.1244 - val_accuracy: 0.9388 - 559ms/epoch - 3ms/step
# Epoch 85/200
# 209/209 - 1s - loss: 0.1154 - accuracy: 0.9430 - val_loss: 0.1289 - val_accuracy: 0.9380 - 607ms/epoch - 3ms/step
# Epoch 86/200
# 209/209 - 1s - loss: 0.1154 - accuracy: 0.9431 - val_loss: 0.1284 - val_accuracy: 0.9376 - 629ms/epoch - 3ms/step
# Epoch 87/200
# 209/209 - 1s - loss: 0.1151 - accuracy: 0.9431 - val_loss: 0.1262 - val_accuracy: 0.9395 - 569ms/epoch - 3ms/step
# Epoch 88/200
# 209/209 - 1s - loss: 0.1152 - accuracy: 0.9429 - val_loss: 0.1267 - val_accuracy: 0.9387 - 552ms/epoch - 3ms/step
# Epoch 89/200
# 209/209 - 1s - loss: 0.1150 - accuracy: 0.9432 - val_loss: 0.1253 - val_accuracy: 0.9404 - 577ms/epoch - 3ms/step
# Epoch 90/200
# 209/209 - 1s - loss: 0.1146 - accuracy: 0.9432 - val_loss: 0.1250 - val_accuracy: 0.9384 - 604ms/epoch - 3ms/step
# Epoch 91/200
# 209/209 - 1s - loss: 0.1143 - accuracy: 0.9436 - val_loss: 0.1243 - val_accuracy: 0.9392 - 586ms/epoch - 3ms/step
# Epoch 92/200
# 209/209 - 1s - loss: 0.1139 - accuracy: 0.9434 - val_loss: 0.1261 - val_accuracy: 0.9396 - 602ms/epoch - 3ms/step
# Epoch 93/200
# 209/209 - 1s - loss: 0.1141 - accuracy: 0.9435 - val_loss: 0.1251 - val_accuracy: 0.9386 - 595ms/epoch - 3ms/step
# Epoch 94/200
# 209/209 - 1s - loss: 0.1136 - accuracy: 0.9435 - val_loss: 0.1247 - val_accuracy: 0.9387 - 622ms/epoch - 3ms/step
# Epoch 95/200
# 209/209 - 1s - loss: 0.1137 - accuracy: 0.9434 - val_loss: 0.1251 - val_accuracy: 0.9398 - 571ms/epoch - 3ms/step
# Epoch 96/200
# 209/209 - 1s - loss: 0.1139 - accuracy: 0.9439 - val_loss: 0.1253 - val_accuracy: 0.9397 - 562ms/epoch - 3ms/step
# Epoch 97/200
# 209/209 - 1s - loss: 0.1136 - accuracy: 0.9440 - val_loss: 0.1272 - val_accuracy: 0.9369 - 550ms/epoch - 3ms/step
# Epoch 98/200
# 209/209 - 1s - loss: 0.1138 - accuracy: 0.9437 - val_loss: 0.1255 - val_accuracy: 0.9386 - 655ms/epoch - 3ms/step
# Epoch 99/200
# 209/209 - 1s - loss: 0.1133 - accuracy: 0.9440 - val_loss: 0.1280 - val_accuracy: 0.9388 - 622ms/epoch - 3ms/step
# Epoch 100/200
# 209/209 - 1s - loss: 0.1134 - accuracy: 0.9438 - val_loss: 0.1244 - val_accuracy: 0.9395 - 625ms/epoch - 3ms/step
# Epoch 101/200
# 209/209 - 1s - loss: 0.1132 - accuracy: 0.9440 - val_loss: 0.1247 - val_accuracy: 0.9400 - 638ms/epoch - 3ms/step
# Epoch 102/200
# 209/209 - 1s - loss: 0.1130 - accuracy: 0.9442 - val_loss: 0.1235 - val_accuracy: 0.9402 - 654ms/epoch - 3ms/step
# Epoch 103/200
# 209/209 - 1s - loss: 0.1133 - accuracy: 0.9440 - val_loss: 0.1252 - val_accuracy: 0.9397 - 616ms/epoch - 3ms/step
# Epoch 104/200
# 209/209 - 1s - loss: 0.1130 - accuracy: 0.9441 - val_loss: 0.1262 - val_accuracy: 0.9394 - 622ms/epoch - 3ms/step
# Epoch 105/200
# 209/209 - 1s - loss: 0.1123 - accuracy: 0.9444 - val_loss: 0.1259 - val_accuracy: 0.9395 - 610ms/epoch - 3ms/step
# Epoch 106/200
# 209/209 - 1s - loss: 0.1132 - accuracy: 0.9441 - val_loss: 0.1289 - val_accuracy: 0.9380 - 597ms/epoch - 3ms/step
# Epoch 107/200
# 209/209 - 1s - loss: 0.1123 - accuracy: 0.9446 - val_loss: 0.1244 - val_accuracy: 0.9398 - 553ms/epoch - 3ms/step
# Epoch 108/200
# 209/209 - 1s - loss: 0.1129 - accuracy: 0.9443 - val_loss: 0.1244 - val_accuracy: 0.9407 - 537ms/epoch - 3ms/step
# Epoch 109/200
# 209/209 - 1s - loss: 0.1118 - accuracy: 0.9450 - val_loss: 0.1249 - val_accuracy: 0.9388 - 547ms/epoch - 3ms/step
# Epoch 110/200
# 209/209 - 1s - loss: 0.1121 - accuracy: 0.9444 - val_loss: 0.1248 - val_accuracy: 0.9395 - 581ms/epoch - 3ms/step
# Epoch 111/200
# 209/209 - 1s - loss: 0.1120 - accuracy: 0.9444 - val_loss: 0.1244 - val_accuracy: 0.9398 - 589ms/epoch - 3ms/step
# Epoch 112/200
# 209/209 - 1s - loss: 0.1117 - accuracy: 0.9445 - val_loss: 0.1260 - val_accuracy: 0.9396 - 588ms/epoch - 3ms/step
# Epoch 113/200
# 209/209 - 1s - loss: 0.1122 - accuracy: 0.9443 - val_loss: 0.1251 - val_accuracy: 0.9392 - 548ms/epoch - 3ms/step
# Epoch 114/200
# 209/209 - 1s - loss: 0.1115 - accuracy: 0.9447 - val_loss: 0.1269 - val_accuracy: 0.9389 - 561ms/epoch - 3ms/step
# Epoch 115/200
# 209/209 - 1s - loss: 0.1119 - accuracy: 0.9449 - val_loss: 0.1236 - val_accuracy: 0.9398 - 603ms/epoch - 3ms/step
# Epoch 116/200
# 209/209 - 1s - loss: 0.1114 - accuracy: 0.9450 - val_loss: 0.1242 - val_accuracy: 0.9392 - 542ms/epoch - 3ms/step
# Epoch 117/200
# 209/209 - 1s - loss: 0.1114 - accuracy: 0.9449 - val_loss: 0.1237 - val_accuracy: 0.9402 - 586ms/epoch - 3ms/step
# Epoch 118/200
# 209/209 - 1s - loss: 0.1114 - accuracy: 0.9455 - val_loss: 0.1247 - val_accuracy: 0.9416 - 585ms/epoch - 3ms/step
# Epoch 119/200
# 209/209 - 1s - loss: 0.1113 - accuracy: 0.9454 - val_loss: 0.1244 - val_accuracy: 0.9399 - 609ms/epoch - 3ms/step
# Epoch 120/200
# 209/209 - 1s - loss: 0.1105 - accuracy: 0.9457 - val_loss: 0.1241 - val_accuracy: 0.9398 - 617ms/epoch - 3ms/step
# Epoch 121/200
# 209/209 - 1s - loss: 0.1113 - accuracy: 0.9448 - val_loss: 0.1241 - val_accuracy: 0.9396 - 602ms/epoch - 3ms/step
# Epoch 122/200
# 209/209 - 1s - loss: 0.1109 - accuracy: 0.9450 - val_loss: 0.1237 - val_accuracy: 0.9406 - 590ms/epoch - 3ms/step
# Epoch 123/200
# 209/209 - 1s - loss: 0.1103 - accuracy: 0.9454 - val_loss: 0.1294 - val_accuracy: 0.9361 - 591ms/epoch - 3ms/step
# Epoch 124/200
# 209/209 - 1s - loss: 0.1104 - accuracy: 0.9455 - val_loss: 0.1241 - val_accuracy: 0.9400 - 636ms/epoch - 3ms/step
# Epoch 125/200
# 209/209 - 1s - loss: 0.1102 - accuracy: 0.9454 - val_loss: 0.1233 - val_accuracy: 0.9405 - 570ms/epoch - 3ms/step
# Epoch 126/200
# 209/209 - 1s - loss: 0.1104 - accuracy: 0.9455 - val_loss: 0.1245 - val_accuracy: 0.9396 - 572ms/epoch - 3ms/step
# Epoch 127/200
# 209/209 - 1s - loss: 0.1102 - accuracy: 0.9458 - val_loss: 0.1253 - val_accuracy: 0.9394 - 578ms/epoch - 3ms/step
# Epoch 128/200
# 209/209 - 1s - loss: 0.1101 - accuracy: 0.9456 - val_loss: 0.1243 - val_accuracy: 0.9399 - 613ms/epoch - 3ms/step
# Epoch 129/200
# 209/209 - 1s - loss: 0.1100 - accuracy: 0.9455 - val_loss: 0.1267 - val_accuracy: 0.9385 - 617ms/epoch - 3ms/step
# Epoch 130/200
# 209/209 - 1s - loss: 0.1097 - accuracy: 0.9459 - val_loss: 0.1227 - val_accuracy: 0.9413 - 608ms/epoch - 3ms/step
# Epoch 131/200
# 209/209 - 1s - loss: 0.1097 - accuracy: 0.9461 - val_loss: 0.1240 - val_accuracy: 0.9408 - 512ms/epoch - 2ms/step
# Epoch 132/200
# 209/209 - 1s - loss: 0.1088 - accuracy: 0.9468 - val_loss: 0.1237 - val_accuracy: 0.9407 - 545ms/epoch - 3ms/step
# Epoch 133/200
# 209/209 - 1s - loss: 0.1096 - accuracy: 0.9458 - val_loss: 0.1250 - val_accuracy: 0.9410 - 528ms/epoch - 3ms/step
# Epoch 134/200
# 209/209 - 0s - loss: 0.1093 - accuracy: 0.9459 - val_loss: 0.1258 - val_accuracy: 0.9395 - 487ms/epoch - 2ms/step
# Epoch 135/200
# 209/209 - 1s - loss: 0.1093 - accuracy: 0.9463 - val_loss: 0.1241 - val_accuracy: 0.9402 - 558ms/epoch - 3ms/step
# Epoch 136/200
# 209/209 - 1s - loss: 0.1088 - accuracy: 0.9467 - val_loss: 0.1248 - val_accuracy: 0.9380 - 549ms/epoch - 3ms/step
# Epoch 137/200
# 209/209 - 1s - loss: 0.1084 - accuracy: 0.9467 - val_loss: 0.1245 - val_accuracy: 0.9395 - 541ms/epoch - 3ms/step
# Epoch 138/200
# 209/209 - 1s - loss: 0.1090 - accuracy: 0.9464 - val_loss: 0.1222 - val_accuracy: 0.9400 - 528ms/epoch - 3ms/step
# Epoch 139/200
# 209/209 - 1s - loss: 0.1085 - accuracy: 0.9465 - val_loss: 0.1243 - val_accuracy: 0.9404 - 514ms/epoch - 2ms/step
# Epoch 140/200
# 209/209 - 1s - loss: 0.1083 - accuracy: 0.9467 - val_loss: 0.1242 - val_accuracy: 0.9410 - 524ms/epoch - 3ms/step
# Epoch 141/200
# 209/209 - 1s - loss: 0.1084 - accuracy: 0.9470 - val_loss: 0.1241 - val_accuracy: 0.9400 - 525ms/epoch - 3ms/step
# Epoch 142/200
# 209/209 - 1s - loss: 0.1078 - accuracy: 0.9472 - val_loss: 0.1231 - val_accuracy: 0.9415 - 516ms/epoch - 2ms/step
# Epoch 143/200
# 209/209 - 1s - loss: 0.1083 - accuracy: 0.9467 - val_loss: 0.1229 - val_accuracy: 0.9406 - 517ms/epoch - 2ms/step
# Epoch 144/200
# 209/209 - 1s - loss: 0.1083 - accuracy: 0.9469 - val_loss: 0.1253 - val_accuracy: 0.9401 - 537ms/epoch - 3ms/step
# Epoch 145/200
# 209/209 - 1s - loss: 0.1079 - accuracy: 0.9472 - val_loss: 0.1241 - val_accuracy: 0.9414 - 594ms/epoch - 3ms/step
# Epoch 146/200
# 209/209 - 1s - loss: 0.1076 - accuracy: 0.9470 - val_loss: 0.1225 - val_accuracy: 0.9420 - 520ms/epoch - 2ms/step
# Epoch 147/200
# 209/209 - 1s - loss: 0.1078 - accuracy: 0.9470 - val_loss: 0.1220 - val_accuracy: 0.9406 - 548ms/epoch - 3ms/step
# Epoch 148/200
# 209/209 - 1s - loss: 0.1072 - accuracy: 0.9475 - val_loss: 0.1255 - val_accuracy: 0.9385 - 547ms/epoch - 3ms/step
# Epoch 149/200
# 209/209 - 1s - loss: 0.1073 - accuracy: 0.9475 - val_loss: 0.1231 - val_accuracy: 0.9409 - 554ms/epoch - 3ms/step
# Epoch 150/200
# 209/209 - 1s - loss: 0.1072 - accuracy: 0.9474 - val_loss: 0.1264 - val_accuracy: 0.9408 - 590ms/epoch - 3ms/step
# Epoch 151/200
# 209/209 - 1s - loss: 0.1073 - accuracy: 0.9476 - val_loss: 0.1254 - val_accuracy: 0.9407 - 524ms/epoch - 3ms/step
# Epoch 152/200
# 209/209 - 1s - loss: 0.1072 - accuracy: 0.9471 - val_loss: 0.1249 - val_accuracy: 0.9417 - 515ms/epoch - 2ms/step
# Epoch 153/200
# 209/209 - 1s - loss: 0.1070 - accuracy: 0.9472 - val_loss: 0.1233 - val_accuracy: 0.9425 - 543ms/epoch - 3ms/step
# Epoch 154/200
# 209/209 - 1s - loss: 0.1071 - accuracy: 0.9473 - val_loss: 0.1248 - val_accuracy: 0.9406 - 517ms/epoch - 2ms/step
# Epoch 155/200
# 209/209 - 1s - loss: 0.1067 - accuracy: 0.9477 - val_loss: 0.1236 - val_accuracy: 0.9422 - 528ms/epoch - 3ms/step
# Epoch 156/200
# 209/209 - 1s - loss: 0.1065 - accuracy: 0.9478 - val_loss: 0.1250 - val_accuracy: 0.9408 - 502ms/epoch - 2ms/step
# Epoch 157/200
# 209/209 - 1s - loss: 0.1061 - accuracy: 0.9482 - val_loss: 0.1247 - val_accuracy: 0.9417 - 517ms/epoch - 2ms/step
# Epoch 158/200
# 209/209 - 1s - loss: 0.1072 - accuracy: 0.9473 - val_loss: 0.1245 - val_accuracy: 0.9410 - 507ms/epoch - 2ms/step
# Epoch 159/200
# 209/209 - 1s - loss: 0.1062 - accuracy: 0.9480 - val_loss: 0.1242 - val_accuracy: 0.9413 - 516ms/epoch - 2ms/step
# Epoch 160/200
# 209/209 - 1s - loss: 0.1062 - accuracy: 0.9481 - val_loss: 0.1239 - val_accuracy: 0.9415 - 510ms/epoch - 2ms/step
# Epoch 161/200
# 209/209 - 1s - loss: 0.1069 - accuracy: 0.9473 - val_loss: 0.1251 - val_accuracy: 0.9406 - 519ms/epoch - 2ms/step
# Epoch 162/200
# 209/209 - 1s - loss: 0.1058 - accuracy: 0.9478 - val_loss: 0.1238 - val_accuracy: 0.9418 - 536ms/epoch - 3ms/step
# Epoch 163/200
# 209/209 - 1s - loss: 0.1063 - accuracy: 0.9477 - val_loss: 0.1237 - val_accuracy: 0.9413 - 504ms/epoch - 2ms/step
# Epoch 164/200
# 209/209 - 1s - loss: 0.1058 - accuracy: 0.9485 - val_loss: 0.1241 - val_accuracy: 0.9409 - 518ms/epoch - 2ms/step
# Epoch 165/200
# 209/209 - 1s - loss: 0.1055 - accuracy: 0.9482 - val_loss: 0.1226 - val_accuracy: 0.9412 - 516ms/epoch - 2ms/step
# Epoch 166/200
# 209/209 - 1s - loss: 0.1053 - accuracy: 0.9488 - val_loss: 0.1243 - val_accuracy: 0.9405 - 540ms/epoch - 3ms/step
# Epoch 167/200
# 209/209 - 1s - loss: 0.1051 - accuracy: 0.9483 - val_loss: 0.1254 - val_accuracy: 0.9414 - 524ms/epoch - 3ms/step
# Epoch 168/200
# 209/209 - 1s - loss: 0.1054 - accuracy: 0.9486 - val_loss: 0.1263 - val_accuracy: 0.9400 - 532ms/epoch - 3ms/step
# Epoch 169/200
# 209/209 - 1s - loss: 0.1056 - accuracy: 0.9480 - val_loss: 0.1287 - val_accuracy: 0.9407 - 506ms/epoch - 2ms/step
# Epoch 170/200
# 209/209 - 1s - loss: 0.1054 - accuracy: 0.9486 - val_loss: 0.1286 - val_accuracy: 0.9399 - 524ms/epoch - 3ms/step
# Epoch 171/200
# 209/209 - 1s - loss: 0.1047 - accuracy: 0.9492 - val_loss: 0.1245 - val_accuracy: 0.9418 - 522ms/epoch - 2ms/step
# Epoch 172/200
# 209/209 - 1s - loss: 0.1047 - accuracy: 0.9489 - val_loss: 0.1259 - val_accuracy: 0.9404 - 501ms/epoch - 2ms/step
# Epoch 173/200
# 209/209 - 1s - loss: 0.1049 - accuracy: 0.9488 - val_loss: 0.1233 - val_accuracy: 0.9426 - 523ms/epoch - 3ms/step
# Epoch 174/200
# 209/209 - 1s - loss: 0.1047 - accuracy: 0.9491 - val_loss: 0.1246 - val_accuracy: 0.9414 - 523ms/epoch - 3ms/step
# Epoch 175/200
# 209/209 - 1s - loss: 0.1046 - accuracy: 0.9488 - val_loss: 0.1253 - val_accuracy: 0.9405 - 508ms/epoch - 2ms/step
# Epoch 176/200
# 209/209 - 1s - loss: 0.1047 - accuracy: 0.9488 - val_loss: 0.1248 - val_accuracy: 0.9414 - 513ms/epoch - 2ms/step
# Epoch 177/200
# 209/209 - 1s - loss: 0.1040 - accuracy: 0.9494 - val_loss: 0.1260 - val_accuracy: 0.9414 - 549ms/epoch - 3ms/step
# Epoch 178/200
# 209/209 - 1s - loss: 0.1044 - accuracy: 0.9489 - val_loss: 0.1244 - val_accuracy: 0.9420 - 529ms/epoch - 3ms/step
# Epoch 179/200
# 209/209 - 1s - loss: 0.1037 - accuracy: 0.9497 - val_loss: 0.1258 - val_accuracy: 0.9410 - 539ms/epoch - 3ms/step
# Epoch 180/200
# 209/209 - 1s - loss: 0.1046 - accuracy: 0.9491 - val_loss: 0.1272 - val_accuracy: 0.9408 - 530ms/epoch - 3ms/step
# Epoch 181/200
# 209/209 - 1s - loss: 0.1040 - accuracy: 0.9497 - val_loss: 0.1250 - val_accuracy: 0.9414 - 527ms/epoch - 3ms/step
# Epoch 182/200
# 209/209 - 1s - loss: 0.1034 - accuracy: 0.9496 - val_loss: 0.1231 - val_accuracy: 0.9436 - 537ms/epoch - 3ms/step
# Epoch 183/200
# 209/209 - 1s - loss: 0.1041 - accuracy: 0.9490 - val_loss: 0.1269 - val_accuracy: 0.9422 - 504ms/epoch - 2ms/step
# Epoch 184/200
# 209/209 - 1s - loss: 0.1037 - accuracy: 0.9495 - val_loss: 0.1243 - val_accuracy: 0.9427 - 509ms/epoch - 2ms/step
# Epoch 185/200
# 209/209 - 1s - loss: 0.1033 - accuracy: 0.9499 - val_loss: 0.1252 - val_accuracy: 0.9413 - 527ms/epoch - 3ms/step
# Epoch 186/200
# 209/209 - 1s - loss: 0.1034 - accuracy: 0.9497 - val_loss: 0.1233 - val_accuracy: 0.9427 - 528ms/epoch - 3ms/step
# Epoch 187/200
# 209/209 - 1s - loss: 0.1036 - accuracy: 0.9501 - val_loss: 0.1230 - val_accuracy: 0.9420 - 521ms/epoch - 2ms/step
# Epoch 188/200
# 209/209 - 1s - loss: 0.1028 - accuracy: 0.9496 - val_loss: 0.1266 - val_accuracy: 0.9413 - 545ms/epoch - 3ms/step
# Epoch 189/200
# 209/209 - 1s - loss: 0.1032 - accuracy: 0.9499 - val_loss: 0.1259 - val_accuracy: 0.9418 - 526ms/epoch - 3ms/step
# Epoch 190/200
# 209/209 - 1s - loss: 0.1036 - accuracy: 0.9495 - val_loss: 0.1248 - val_accuracy: 0.9423 - 511ms/epoch - 2ms/step
# Epoch 191/200
# 209/209 - 1s - loss: 0.1029 - accuracy: 0.9496 - val_loss: 0.1276 - val_accuracy: 0.9398 - 511ms/epoch - 2ms/step
# Epoch 192/200
# 209/209 - 1s - loss: 0.1026 - accuracy: 0.9498 - val_loss: 0.1253 - val_accuracy: 0.9425 - 502ms/epoch - 2ms/step
# Epoch 193/200
# 209/209 - 1s - loss: 0.1026 - accuracy: 0.9503 - val_loss: 0.1267 - val_accuracy: 0.9414 - 513ms/epoch - 2ms/step
# Epoch 194/200
# 209/209 - 1s - loss: 0.1030 - accuracy: 0.9500 - val_loss: 0.1252 - val_accuracy: 0.9415 - 512ms/epoch - 2ms/step
# Epoch 195/200
# 209/209 - 1s - loss: 0.1026 - accuracy: 0.9500 - val_loss: 0.1277 - val_accuracy: 0.9404 - 507ms/epoch - 2ms/step
# Epoch 196/200
# 209/209 - 1s - loss: 0.1028 - accuracy: 0.9500 - val_loss: 0.1253 - val_accuracy: 0.9426 - 508ms/epoch - 2ms/step
# Epoch 197/200
# 209/209 - 1s - loss: 0.1023 - accuracy: 0.9501 - val_loss: 0.1251 - val_accuracy: 0.9420 - 552ms/epoch - 3ms/step
# Epoch 198/200
# 209/209 - 1s - loss: 0.1024 - accuracy: 0.9500 - val_loss: 0.1267 - val_accuracy: 0.9417 - 502ms/epoch - 2ms/step
# Epoch 199/200
# 209/209 - 1s - loss: 0.1025 - accuracy: 0.9503 - val_loss: 0.1240 - val_accuracy: 0.9426 - 512ms/epoch - 2ms/step
# Epoch 200/200
# 209/209 - 1s - loss: 0.1017 - accuracy: 0.9507 - val_loss: 0.1247 - val_accuracy: 0.9414 - 510ms/epoch - 2ms/step

# %%
accuracy, recall, precision, f1, end_predict = evaluate_model(model, X_test, y_test, True)
# Out:
#    1/1611 [..............................] - ETA: 38s
# 1611/1611 [==============================] - 2s 1ms/step
# Modell: MLP_Classifier
# Genauigkeit: 0.9452216939943727
# Recall: 0.9452216939943727
# Precision: 0.9458816592533312
# F1 Score: 0.945409003546821

# %%
results = append_model_reults(model, results, end_train - start, end_predict - end_train, accuracy, recall, precision, f1)

# %% [markdown]
# #### 4.2.2 LSTM

# %%
# LSTM_1 = 128 X 64 X 32 X 20; 0.2 dropoout on each layer; 1 Dropout-Layer before Dense -> 91 test 93 train
# LSTM_2 = 256 X 128 X 64 X 32 X 20; 0.2 dropoout on each layer; 1 Dropout-Layer before Dense -> 91 test 93 train
# LSTM_3 = 256 X 128 X 64 X 32 X 20; -> Currently the best model -> 94.5 test 96 train
def build_model_lstm():
    model = Sequential(name="LSTM_3")
    
    model.add(LSTM(256, return_sequences=True, input_shape=(1, TOTAL_FEATURES), name="LSTM1"))
    model.add(LSTM(128, return_sequences=True, name="LSTM2"))
    model.add(LSTM(64, return_sequences=True, name="LSTM3"))
    model.add(LSTM(32, return_sequences=True, name="LSTM4"))
    
    model.add(Dense(20, activation='softmax')) 
    
    opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

# %%
model_lstm = build_model_lstm()
model_lstm.summary()
# Out:
# Model: "LSTM_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM1 (LSTM)                (None, 1, 256)            320512
#
#  LSTM2 (LSTM)                (None, 1, 128)            197120
#
#  LSTM3 (LSTM)                (None, 1, 64)             49408
#
#  LSTM4 (LSTM)                (None, 1, 32)             12416
#
#  dense_3 (Dense)             (None, 1, 20)             660
#
# =================================================================
# Total params: 580,116
# Trainable params: 580,116
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time.time()
history = model_lstm.fit(X_train_reshaped, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)
# history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2, validation_data=(X_val, y_val))
end_train = time.time()
# Out:
# Epoch 1/200
# 207/207 - 6s - loss: 0.8482 - accuracy: 0.8059 - 6s/epoch - 29ms/step
# Epoch 2/200
# 207/207 - 2s - loss: 0.2621 - accuracy: 0.8986 - 2s/epoch - 7ms/step
# Epoch 3/200
# 207/207 - 1s - loss: 0.2057 - accuracy: 0.9133 - 1s/epoch - 7ms/step
# Epoch 4/200
# 207/207 - 1s - loss: 0.1591 - accuracy: 0.9226 - 1s/epoch - 7ms/step
# Epoch 5/200
# 207/207 - 1s - loss: 0.1525 - accuracy: 0.9253 - 1s/epoch - 7ms/step
# Epoch 6/200
# 207/207 - 1s - loss: 0.1487 - accuracy: 0.9267 - 1s/epoch - 7ms/step
# Epoch 7/200
# 207/207 - 1s - loss: 0.1464 - accuracy: 0.9278 - 1s/epoch - 7ms/step
# Epoch 8/200
# 207/207 - 1s - loss: 0.1445 - accuracy: 0.9282 - 1s/epoch - 7ms/step
# Epoch 9/200
# 207/207 - 1s - loss: 0.1411 - accuracy: 0.9299 - 1s/epoch - 7ms/step
# Epoch 10/200
# 207/207 - 1s - loss: 0.1398 - accuracy: 0.9304 - 1s/epoch - 7ms/step
# Epoch 11/200
# 207/207 - 1s - loss: 0.1382 - accuracy: 0.9313 - 1s/epoch - 7ms/step
# Epoch 12/200
# 207/207 - 1s - loss: 0.1372 - accuracy: 0.9316 - 1s/epoch - 7ms/step
# Epoch 13/200
# 207/207 - 1s - loss: 0.1361 - accuracy: 0.9319 - 1s/epoch - 7ms/step
# Epoch 14/200
# 207/207 - 1s - loss: 0.1354 - accuracy: 0.9320 - 1s/epoch - 7ms/step
# Epoch 15/200
# 207/207 - 1s - loss: 0.1347 - accuracy: 0.9323 - 1s/epoch - 7ms/step
# Epoch 16/200
# 207/207 - 1s - loss: 0.1340 - accuracy: 0.9330 - 1s/epoch - 7ms/step
# Epoch 17/200
# 207/207 - 1s - loss: 0.1333 - accuracy: 0.9332 - 1s/epoch - 7ms/step
# Epoch 18/200
# 207/207 - 1s - loss: 0.1330 - accuracy: 0.9334 - 1s/epoch - 7ms/step
# Epoch 19/200
# 207/207 - 1s - loss: 0.1336 - accuracy: 0.9325 - 1s/epoch - 7ms/step
# Epoch 20/200
# 207/207 - 1s - loss: 0.1326 - accuracy: 0.9336 - 1s/epoch - 7ms/step
# Epoch 21/200
# 207/207 - 1s - loss: 0.1320 - accuracy: 0.9336 - 1s/epoch - 7ms/step
# Epoch 22/200
# 207/207 - 1s - loss: 0.1317 - accuracy: 0.9335 - 1s/epoch - 7ms/step
# Epoch 23/200
# 207/207 - 1s - loss: 0.1316 - accuracy: 0.9340 - 1s/epoch - 7ms/step
# Epoch 24/200
# 207/207 - 1s - loss: 0.1308 - accuracy: 0.9339 - 1s/epoch - 7ms/step
# Epoch 25/200
# 207/207 - 2s - loss: 0.1305 - accuracy: 0.9342 - 2s/epoch - 8ms/step
# Epoch 26/200
# 207/207 - 1s - loss: 0.1298 - accuracy: 0.9346 - 1s/epoch - 7ms/step
# Epoch 27/200
# 207/207 - 1s - loss: 0.1295 - accuracy: 0.9352 - 1s/epoch - 7ms/step
# Epoch 28/200
# 207/207 - 1s - loss: 0.1291 - accuracy: 0.9350 - 1s/epoch - 7ms/step
# Epoch 29/200
# 207/207 - 1s - loss: 0.1289 - accuracy: 0.9350 - 1s/epoch - 7ms/step
# Epoch 30/200
# 207/207 - 1s - loss: 0.1287 - accuracy: 0.9353 - 1s/epoch - 7ms/step
# Epoch 31/200
# 207/207 - 1s - loss: 0.1286 - accuracy: 0.9353 - 1s/epoch - 7ms/step
# Epoch 32/200
# 207/207 - 2s - loss: 0.1285 - accuracy: 0.9356 - 2s/epoch - 8ms/step
# Epoch 33/200
# 207/207 - 2s - loss: 0.1280 - accuracy: 0.9357 - 2s/epoch - 8ms/step
# Epoch 34/200
# 207/207 - 2s - loss: 0.1272 - accuracy: 0.9361 - 2s/epoch - 8ms/step
# Epoch 35/200
# 207/207 - 2s - loss: 0.1274 - accuracy: 0.9361 - 2s/epoch - 8ms/step
# Epoch 36/200
# 207/207 - 2s - loss: 0.1265 - accuracy: 0.9364 - 2s/epoch - 8ms/step
# Epoch 37/200
# 207/207 - 2s - loss: 0.1271 - accuracy: 0.9365 - 2s/epoch - 7ms/step
# Epoch 38/200
# 207/207 - 2s - loss: 0.1266 - accuracy: 0.9367 - 2s/epoch - 8ms/step
# Epoch 39/200
# 207/207 - 2s - loss: 0.1263 - accuracy: 0.9367 - 2s/epoch - 7ms/step
# Epoch 40/200
# 207/207 - 2s - loss: 0.1269 - accuracy: 0.9365 - 2s/epoch - 8ms/step
# Epoch 41/200
# 207/207 - 2s - loss: 0.1264 - accuracy: 0.9370 - 2s/epoch - 8ms/step
# Epoch 42/200
# 207/207 - 2s - loss: 0.1255 - accuracy: 0.9374 - 2s/epoch - 8ms/step
# Epoch 43/200
# 207/207 - 2s - loss: 0.1258 - accuracy: 0.9373 - 2s/epoch - 8ms/step
# Epoch 44/200
# 207/207 - 2s - loss: 0.1254 - accuracy: 0.9372 - 2s/epoch - 7ms/step
# Epoch 45/200
# 207/207 - 2s - loss: 0.1251 - accuracy: 0.9378 - 2s/epoch - 8ms/step
# Epoch 46/200
# 207/207 - 2s - loss: 0.1241 - accuracy: 0.9378 - 2s/epoch - 8ms/step
# Epoch 47/200
# 207/207 - 2s - loss: 0.1243 - accuracy: 0.9380 - 2s/epoch - 7ms/step
# Epoch 48/200
# 207/207 - 2s - loss: 0.1242 - accuracy: 0.9379 - 2s/epoch - 8ms/step
# Epoch 49/200
# 207/207 - 2s - loss: 0.1239 - accuracy: 0.9386 - 2s/epoch - 7ms/step
# Epoch 50/200
# 207/207 - 2s - loss: 0.1245 - accuracy: 0.9379 - 2s/epoch - 8ms/step
# Epoch 51/200
# 207/207 - 2s - loss: 0.1237 - accuracy: 0.9383 - 2s/epoch - 8ms/step
# Epoch 52/200
# 207/207 - 2s - loss: 0.1230 - accuracy: 0.9385 - 2s/epoch - 7ms/step
# Epoch 53/200
# 207/207 - 2s - loss: 0.1227 - accuracy: 0.9390 - 2s/epoch - 7ms/step
# Epoch 54/200
# 207/207 - 2s - loss: 0.1229 - accuracy: 0.9388 - 2s/epoch - 8ms/step
# Epoch 55/200
# 207/207 - 2s - loss: 0.1222 - accuracy: 0.9391 - 2s/epoch - 7ms/step
# Epoch 56/200
# 207/207 - 2s - loss: 0.1220 - accuracy: 0.9391 - 2s/epoch - 7ms/step
# Epoch 57/200
# 207/207 - 1s - loss: 0.1222 - accuracy: 0.9390 - 1s/epoch - 7ms/step
# Epoch 58/200
# 207/207 - 2s - loss: 0.1217 - accuracy: 0.9395 - 2s/epoch - 8ms/step
# Epoch 59/200
# 207/207 - 2s - loss: 0.1216 - accuracy: 0.9393 - 2s/epoch - 7ms/step
# Epoch 60/200
# 207/207 - 2s - loss: 0.1211 - accuracy: 0.9394 - 2s/epoch - 8ms/step
# Epoch 61/200
# 207/207 - 2s - loss: 0.1208 - accuracy: 0.9397 - 2s/epoch - 8ms/step
# Epoch 62/200
# 207/207 - 2s - loss: 0.1211 - accuracy: 0.9397 - 2s/epoch - 7ms/step
# Epoch 63/200
# 207/207 - 1s - loss: 0.1200 - accuracy: 0.9402 - 1s/epoch - 7ms/step
# Epoch 64/200
# 207/207 - 1s - loss: 0.1201 - accuracy: 0.9402 - 1s/epoch - 7ms/step
# Epoch 65/200
# 207/207 - 1s - loss: 0.1198 - accuracy: 0.9401 - 1s/epoch - 7ms/step
# Epoch 66/200
# 207/207 - 2s - loss: 0.1195 - accuracy: 0.9405 - 2s/epoch - 8ms/step
# Epoch 67/200
# 207/207 - 2s - loss: 0.1197 - accuracy: 0.9403 - 2s/epoch - 8ms/step
# Epoch 68/200
# 207/207 - 2s - loss: 0.1190 - accuracy: 0.9404 - 2s/epoch - 8ms/step
# Epoch 69/200
# 207/207 - 2s - loss: 0.1187 - accuracy: 0.9410 - 2s/epoch - 7ms/step
# Epoch 70/200
# 207/207 - 2s - loss: 0.1188 - accuracy: 0.9407 - 2s/epoch - 8ms/step
# Epoch 71/200
# 207/207 - 2s - loss: 0.1182 - accuracy: 0.9413 - 2s/epoch - 7ms/step
# Epoch 72/200
# 207/207 - 2s - loss: 0.1181 - accuracy: 0.9413 - 2s/epoch - 8ms/step
# Epoch 73/200
# 207/207 - 2s - loss: 0.1179 - accuracy: 0.9416 - 2s/epoch - 7ms/step
# Epoch 74/200
# 207/207 - 2s - loss: 0.1174 - accuracy: 0.9417 - 2s/epoch - 8ms/step
# Epoch 75/200
# 207/207 - 2s - loss: 0.1173 - accuracy: 0.9415 - 2s/epoch - 7ms/step
# Epoch 76/200
# 207/207 - 2s - loss: 0.1172 - accuracy: 0.9417 - 2s/epoch - 7ms/step
# Epoch 77/200
# 207/207 - 2s - loss: 0.1170 - accuracy: 0.9416 - 2s/epoch - 7ms/step
# Epoch 78/200
# 207/207 - 2s - loss: 0.1168 - accuracy: 0.9416 - 2s/epoch - 7ms/step
# Epoch 79/200
# 207/207 - 2s - loss: 0.1164 - accuracy: 0.9420 - 2s/epoch - 8ms/step
# Epoch 80/200
# 207/207 - 2s - loss: 0.1167 - accuracy: 0.9421 - 2s/epoch - 8ms/step
# Epoch 81/200
# 207/207 - 2s - loss: 0.1156 - accuracy: 0.9427 - 2s/epoch - 8ms/step
# Epoch 82/200
# 207/207 - 2s - loss: 0.1163 - accuracy: 0.9422 - 2s/epoch - 7ms/step
# Epoch 83/200
# 207/207 - 2s - loss: 0.1160 - accuracy: 0.9422 - 2s/epoch - 8ms/step
# Epoch 84/200
# 207/207 - 2s - loss: 0.1153 - accuracy: 0.9428 - 2s/epoch - 7ms/step
# Epoch 85/200
# 207/207 - 2s - loss: 0.1150 - accuracy: 0.9428 - 2s/epoch - 8ms/step
# Epoch 86/200
# 207/207 - 2s - loss: 0.1150 - accuracy: 0.9427 - 2s/epoch - 8ms/step
# Epoch 87/200
# 207/207 - 2s - loss: 0.1149 - accuracy: 0.9430 - 2s/epoch - 8ms/step
# Epoch 88/200
# 207/207 - 2s - loss: 0.1146 - accuracy: 0.9429 - 2s/epoch - 7ms/step
# Epoch 89/200
# 207/207 - 2s - loss: 0.1141 - accuracy: 0.9431 - 2s/epoch - 8ms/step
# Epoch 90/200
# 207/207 - 2s - loss: 0.1141 - accuracy: 0.9433 - 2s/epoch - 8ms/step
# Epoch 91/200
# 207/207 - 2s - loss: 0.1142 - accuracy: 0.9431 - 2s/epoch - 8ms/step
# Epoch 92/200
# 207/207 - 2s - loss: 0.1133 - accuracy: 0.9437 - 2s/epoch - 7ms/step
# Epoch 93/200
# 207/207 - 2s - loss: 0.1127 - accuracy: 0.9439 - 2s/epoch - 7ms/step
# Epoch 94/200
# 207/207 - 2s - loss: 0.1129 - accuracy: 0.9438 - 2s/epoch - 8ms/step
# Epoch 95/200
# 207/207 - 2s - loss: 0.1123 - accuracy: 0.9441 - 2s/epoch - 7ms/step
# Epoch 96/200
# 207/207 - 1s - loss: 0.1125 - accuracy: 0.9441 - 1s/epoch - 7ms/step
# Epoch 97/200
# 207/207 - 1s - loss: 0.1116 - accuracy: 0.9442 - 1s/epoch - 7ms/step
# Epoch 98/200
# 207/207 - 2s - loss: 0.1116 - accuracy: 0.9445 - 2s/epoch - 8ms/step
# Epoch 99/200
# 207/207 - 2s - loss: 0.1113 - accuracy: 0.9441 - 2s/epoch - 10ms/step
# Epoch 100/200
# 207/207 - 2s - loss: 0.1115 - accuracy: 0.9448 - 2s/epoch - 9ms/step
# Epoch 101/200
# 207/207 - 2s - loss: 0.1101 - accuracy: 0.9451 - 2s/epoch - 9ms/step
# Epoch 102/200
# 207/207 - 2s - loss: 0.1103 - accuracy: 0.9450 - 2s/epoch - 7ms/step
# Epoch 103/200
# 207/207 - 1s - loss: 0.1093 - accuracy: 0.9458 - 1s/epoch - 7ms/step
# Epoch 104/200
# 207/207 - 1s - loss: 0.1092 - accuracy: 0.9454 - 1s/epoch - 7ms/step
# Epoch 105/200
# 207/207 - 1s - loss: 0.1082 - accuracy: 0.9465 - 1s/epoch - 7ms/step
# Epoch 106/200
# 207/207 - 1s - loss: 0.1077 - accuracy: 0.9463 - 1s/epoch - 7ms/step
# Epoch 107/200
# 207/207 - 1s - loss: 0.1079 - accuracy: 0.9467 - 1s/epoch - 7ms/step
# Epoch 108/200
# 207/207 - 1s - loss: 0.1074 - accuracy: 0.9468 - 1s/epoch - 7ms/step
# Epoch 109/200
# 207/207 - 1s - loss: 0.1076 - accuracy: 0.9466 - 1s/epoch - 7ms/step
# Epoch 110/200
# 207/207 - 2s - loss: 0.1077 - accuracy: 0.9466 - 2s/epoch - 7ms/step
# Epoch 111/200
# 207/207 - 2s - loss: 0.1068 - accuracy: 0.9472 - 2s/epoch - 7ms/step
# Epoch 112/200
# 207/207 - 1s - loss: 0.1066 - accuracy: 0.9473 - 1s/epoch - 7ms/step
# Epoch 113/200
# 207/207 - 2s - loss: 0.1062 - accuracy: 0.9469 - 2s/epoch - 8ms/step
# Epoch 114/200
# 207/207 - 1s - loss: 0.1062 - accuracy: 0.9474 - 1s/epoch - 7ms/step
# Epoch 115/200
# 207/207 - 2s - loss: 0.1058 - accuracy: 0.9480 - 2s/epoch - 8ms/step
# Epoch 116/200
# 207/207 - 2s - loss: 0.1056 - accuracy: 0.9474 - 2s/epoch - 8ms/step
# Epoch 117/200
# 207/207 - 2s - loss: 0.1052 - accuracy: 0.9476 - 2s/epoch - 8ms/step
# Epoch 118/200
# 207/207 - 2s - loss: 0.1051 - accuracy: 0.9478 - 2s/epoch - 8ms/step
# Epoch 119/200
# 207/207 - 2s - loss: 0.1049 - accuracy: 0.9479 - 2s/epoch - 7ms/step
# Epoch 120/200
# 207/207 - 2s - loss: 0.1042 - accuracy: 0.9485 - 2s/epoch - 8ms/step
# Epoch 121/200
# 207/207 - 2s - loss: 0.1040 - accuracy: 0.9491 - 2s/epoch - 7ms/step
# Epoch 122/200
# 207/207 - 2s - loss: 0.1040 - accuracy: 0.9484 - 2s/epoch - 7ms/step
# Epoch 123/200
# 207/207 - 2s - loss: 0.1039 - accuracy: 0.9486 - 2s/epoch - 7ms/step
# Epoch 124/200
# 207/207 - 2s - loss: 0.1033 - accuracy: 0.9489 - 2s/epoch - 8ms/step
# Epoch 125/200
# 207/207 - 2s - loss: 0.1033 - accuracy: 0.9491 - 2s/epoch - 8ms/step
# Epoch 126/200
# 207/207 - 2s - loss: 0.1024 - accuracy: 0.9497 - 2s/epoch - 7ms/step
# Epoch 127/200
# 207/207 - 1s - loss: 0.1027 - accuracy: 0.9493 - 1s/epoch - 7ms/step
# Epoch 128/200
# 207/207 - 1s - loss: 0.1028 - accuracy: 0.9493 - 1s/epoch - 7ms/step
# Epoch 129/200
# 207/207 - 2s - loss: 0.1017 - accuracy: 0.9500 - 2s/epoch - 9ms/step
# Epoch 130/200
# 207/207 - 2s - loss: 0.1019 - accuracy: 0.9495 - 2s/epoch - 8ms/step
# Epoch 131/200
# 207/207 - 2s - loss: 0.1012 - accuracy: 0.9500 - 2s/epoch - 10ms/step
# Epoch 132/200
# 207/207 - 2s - loss: 0.1012 - accuracy: 0.9505 - 2s/epoch - 8ms/step
# Epoch 133/200
# 207/207 - 1s - loss: 0.1014 - accuracy: 0.9504 - 1s/epoch - 7ms/step
# Epoch 134/200
# 207/207 - 2s - loss: 0.1006 - accuracy: 0.9506 - 2s/epoch - 8ms/step
# Epoch 135/200
# 207/207 - 2s - loss: 0.1003 - accuracy: 0.9505 - 2s/epoch - 8ms/step
# Epoch 136/200
# 207/207 - 2s - loss: 0.1007 - accuracy: 0.9505 - 2s/epoch - 7ms/step
# Epoch 137/200
# 207/207 - 1s - loss: 0.0995 - accuracy: 0.9510 - 1s/epoch - 7ms/step
# Epoch 138/200
# 207/207 - 2s - loss: 0.0994 - accuracy: 0.9512 - 2s/epoch - 7ms/step
# Epoch 139/200
# 207/207 - 2s - loss: 0.0993 - accuracy: 0.9512 - 2s/epoch - 8ms/step
# Epoch 140/200
# 207/207 - 2s - loss: 0.0986 - accuracy: 0.9515 - 2s/epoch - 7ms/step
# Epoch 141/200
# 207/207 - 2s - loss: 0.0989 - accuracy: 0.9517 - 2s/epoch - 8ms/step
# Epoch 142/200
# 207/207 - 2s - loss: 0.0984 - accuracy: 0.9519 - 2s/epoch - 8ms/step
# Epoch 143/200
# 207/207 - 2s - loss: 0.0986 - accuracy: 0.9517 - 2s/epoch - 8ms/step
# Epoch 144/200
# 207/207 - 2s - loss: 0.0979 - accuracy: 0.9521 - 2s/epoch - 7ms/step
# Epoch 145/200
# 207/207 - 1s - loss: 0.0979 - accuracy: 0.9520 - 1s/epoch - 7ms/step
# Epoch 146/200
# 207/207 - 2s - loss: 0.0970 - accuracy: 0.9524 - 2s/epoch - 7ms/step
# Epoch 147/200
# 207/207 - 1s - loss: 0.0975 - accuracy: 0.9521 - 1s/epoch - 7ms/step
# Epoch 148/200
# 207/207 - 2s - loss: 0.0966 - accuracy: 0.9527 - 2s/epoch - 7ms/step
# Epoch 149/200
# 207/207 - 2s - loss: 0.0964 - accuracy: 0.9529 - 2s/epoch - 8ms/step
# Epoch 150/200
# 207/207 - 2s - loss: 0.0964 - accuracy: 0.9531 - 2s/epoch - 7ms/step
# Epoch 151/200
# 207/207 - 2s - loss: 0.0959 - accuracy: 0.9531 - 2s/epoch - 7ms/step
# Epoch 152/200
# 207/207 - 2s - loss: 0.0955 - accuracy: 0.9535 - 2s/epoch - 7ms/step
# Epoch 153/200
# 207/207 - 1s - loss: 0.0954 - accuracy: 0.9535 - 1s/epoch - 7ms/step
# Epoch 154/200
# 207/207 - 1s - loss: 0.0949 - accuracy: 0.9537 - 1s/epoch - 7ms/step
# Epoch 155/200
# 207/207 - 1s - loss: 0.0950 - accuracy: 0.9535 - 1s/epoch - 7ms/step
# Epoch 156/200
# 207/207 - 1s - loss: 0.0950 - accuracy: 0.9536 - 1s/epoch - 7ms/step
# Epoch 157/200
# 207/207 - 1s - loss: 0.0937 - accuracy: 0.9546 - 1s/epoch - 7ms/step
# Epoch 158/200
# 207/207 - 2s - loss: 0.0935 - accuracy: 0.9546 - 2s/epoch - 7ms/step
# Epoch 159/200
# 207/207 - 1s - loss: 0.0938 - accuracy: 0.9545 - 1s/epoch - 7ms/step
# Epoch 160/200
# 207/207 - 2s - loss: 0.0939 - accuracy: 0.9542 - 2s/epoch - 7ms/step
# Epoch 161/200
# 207/207 - 1s - loss: 0.0930 - accuracy: 0.9543 - 1s/epoch - 7ms/step
# Epoch 162/200
# 207/207 - 2s - loss: 0.0932 - accuracy: 0.9547 - 2s/epoch - 7ms/step
# Epoch 163/200
# 207/207 - 2s - loss: 0.0928 - accuracy: 0.9549 - 2s/epoch - 8ms/step
# Epoch 164/200
# 207/207 - 1s - loss: 0.0919 - accuracy: 0.9553 - 1s/epoch - 7ms/step
# Epoch 165/200
# 207/207 - 2s - loss: 0.0920 - accuracy: 0.9551 - 2s/epoch - 8ms/step
# Epoch 166/200
# 207/207 - 2s - loss: 0.0917 - accuracy: 0.9554 - 2s/epoch - 8ms/step
# Epoch 167/200
# 207/207 - 1s - loss: 0.0915 - accuracy: 0.9553 - 1s/epoch - 7ms/step
# Epoch 168/200
# 207/207 - 1s - loss: 0.0911 - accuracy: 0.9558 - 1s/epoch - 7ms/step
# Epoch 169/200
# 207/207 - 2s - loss: 0.0906 - accuracy: 0.9556 - 2s/epoch - 8ms/step
# Epoch 170/200
# 207/207 - 2s - loss: 0.0904 - accuracy: 0.9560 - 2s/epoch - 8ms/step
# Epoch 171/200
# 207/207 - 2s - loss: 0.0900 - accuracy: 0.9561 - 2s/epoch - 8ms/step
# Epoch 172/200
# 207/207 - 1s - loss: 0.0902 - accuracy: 0.9560 - 1s/epoch - 7ms/step
# Epoch 173/200
# 207/207 - 2s - loss: 0.0896 - accuracy: 0.9564 - 2s/epoch - 8ms/step
# Epoch 174/200
# 207/207 - 2s - loss: 0.0890 - accuracy: 0.9568 - 2s/epoch - 8ms/step
# Epoch 175/200
# 207/207 - 2s - loss: 0.0892 - accuracy: 0.9565 - 2s/epoch - 8ms/step
# Epoch 176/200
# 207/207 - 2s - loss: 0.0887 - accuracy: 0.9567 - 2s/epoch - 8ms/step
# Epoch 177/200
# 207/207 - 2s - loss: 0.0877 - accuracy: 0.9573 - 2s/epoch - 8ms/step
# Epoch 178/200
# 207/207 - 2s - loss: 0.0893 - accuracy: 0.9569 - 2s/epoch - 7ms/step
# Epoch 179/200
# 207/207 - 2s - loss: 0.0876 - accuracy: 0.9579 - 2s/epoch - 7ms/step
# Epoch 180/200
# 207/207 - 2s - loss: 0.0878 - accuracy: 0.9573 - 2s/epoch - 8ms/step
# Epoch 181/200
# 207/207 - 2s - loss: 0.0869 - accuracy: 0.9579 - 2s/epoch - 8ms/step
# Epoch 182/200
# 207/207 - 2s - loss: 0.0866 - accuracy: 0.9581 - 2s/epoch - 7ms/step
# Epoch 183/200
# 207/207 - 2s - loss: 0.0878 - accuracy: 0.9575 - 2s/epoch - 8ms/step
# Epoch 184/200
# 207/207 - 1s - loss: 0.0865 - accuracy: 0.9581 - 1s/epoch - 7ms/step
# Epoch 185/200
# 207/207 - 1s - loss: 0.0858 - accuracy: 0.9585 - 1s/epoch - 7ms/step
# Epoch 186/200
# 207/207 - 1s - loss: 0.0859 - accuracy: 0.9585 - 1s/epoch - 7ms/step
# Epoch 187/200
# 207/207 - 1s - loss: 0.0856 - accuracy: 0.9586 - 1s/epoch - 7ms/step
# Epoch 188/200
# 207/207 - 2s - loss: 0.0853 - accuracy: 0.9583 - 2s/epoch - 7ms/step
# Epoch 189/200
# 207/207 - 2s - loss: 0.0848 - accuracy: 0.9589 - 2s/epoch - 7ms/step
# Epoch 190/200
# 207/207 - 2s - loss: 0.0850 - accuracy: 0.9587 - 2s/epoch - 8ms/step
# Epoch 191/200
# 207/207 - 2s - loss: 0.0841 - accuracy: 0.9591 - 2s/epoch - 7ms/step
# Epoch 192/200
# 207/207 - 2s - loss: 0.0842 - accuracy: 0.9591 - 2s/epoch - 11ms/step
# Epoch 193/200
# 207/207 - 2s - loss: 0.0833 - accuracy: 0.9598 - 2s/epoch - 8ms/step
# Epoch 194/200
# 207/207 - 2s - loss: 0.0839 - accuracy: 0.9596 - 2s/epoch - 9ms/step
# Epoch 195/200
# 207/207 - 1s - loss: 0.0827 - accuracy: 0.9601 - 1s/epoch - 7ms/step
# Epoch 196/200
# 207/207 - 1s - loss: 0.0837 - accuracy: 0.9594 - 1s/epoch - 7ms/step
# Epoch 197/200
# 207/207 - 2s - loss: 0.0828 - accuracy: 0.9600 - 2s/epoch - 7ms/step
# Epoch 198/200
# 207/207 - 1s - loss: 0.0826 - accuracy: 0.9604 - 1s/epoch - 7ms/step
# Epoch 199/200
# 207/207 - 2s - loss: 0.0825 - accuracy: 0.9601 - 2s/epoch - 7ms/step
# Epoch 200/200
# 207/207 - 1s - loss: 0.0817 - accuracy: 0.9606 - 1s/epoch - 7ms/step

# %%
accuracy, recall, precision, f1, end_predict = evaluate_model(model_lstm, X_test_reshaped, y_test, True)
# Out:
# 1611/1611 [==============================] - 7s 3ms/step
# Modell: LSTM_3
# Genauigkeit: 0.9436693509265548
# Recall: 0.9436693509265548
# Precision: 0.9442254056128405
# F1 Score: 0.9438386424483918

# %%
results = append_model_reults(model_lstm, results, end_train - start, end_predict - end_train, accuracy, recall, precision, f1)

# %% [markdown]
# #### 4.2.3 GRU

# %%
# GRU_1 = 256 X 128 X 64 X 32 X 20; -> 94.2 test 97 train
# GRU_2 = 256 X 128 X 64 X 32 X 20; 1 Dropout-Layer 50% before Dense -> 94.44 test 96 train
# GRU_3 = 256 X 128 X 64 X 32 X 48; 1 Dropout-Layer 50% before Dense -> 94.45 test 96 train -> fastest model

def build_model_gru():
    model = Sequential(name="GRU_3")
    
    model.add(GRU(256, return_sequences=True, input_shape=(1, TOTAL_FEATURES), name="GRU1"))
    model.add(GRU(128, return_sequences=True, name="GRU2"))
    model.add(GRU(64, return_sequences=True, name="GRU3"))
    model.add(GRU(32, return_sequences=True, name="GRU4"))
    model.add(Dropout(0.5))
    model.add(Dense(48, activation='softmax', name="FinalDense")) 
    
    opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

# %%
model_gru = build_model_gru()
model_gru.summary()
# Out:
# Model: "GRU_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  GRU1 (GRU)                  (None, 1, 256)            241152
#
#  GRU2 (GRU)                  (None, 1, 128)            148224
#
#  GRU3 (GRU)                  (None, 1, 64)             37248
#
#  GRU4 (GRU)                  (None, 1, 32)             9408
#
#  dropout_6 (Dropout)         (None, 1, 32)             0
#
#  FinalDense (Dense)          (None, 1, 48)             1584
#
# =================================================================
# Total params: 437,616
# Trainable params: 437,616
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time.time()
history = model_gru.fit(X_train_reshaped, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2)
end_train = time.time()
# Out:
# Epoch 1/200
# 207/207 - 6s - loss: 0.8277 - accuracy: 0.8380 - 6s/epoch - 30ms/step
# Epoch 2/200
# 207/207 - 1s - loss: 0.2126 - accuracy: 0.9075 - 1s/epoch - 7ms/step
# Epoch 3/200
# 207/207 - 1s - loss: 0.1843 - accuracy: 0.9141 - 1s/epoch - 7ms/step
# Epoch 4/200
# 207/207 - 2s - loss: 0.1730 - accuracy: 0.9181 - 2s/epoch - 8ms/step
# Epoch 5/200
# 207/207 - 1s - loss: 0.1648 - accuracy: 0.9214 - 1s/epoch - 6ms/step
# Epoch 6/200
# 207/207 - 1s - loss: 0.1596 - accuracy: 0.9237 - 1s/epoch - 6ms/step
# Epoch 7/200
# 207/207 - 1s - loss: 0.1540 - accuracy: 0.9262 - 1s/epoch - 6ms/step
# Epoch 8/200
# 207/207 - 1s - loss: 0.1528 - accuracy: 0.9258 - 1s/epoch - 6ms/step
# Epoch 9/200
# 207/207 - 1s - loss: 0.1487 - accuracy: 0.9274 - 1s/epoch - 6ms/step
# Epoch 10/200
# 207/207 - 1s - loss: 0.1493 - accuracy: 0.9261 - 1s/epoch - 6ms/step
# Epoch 11/200
# 207/207 - 1s - loss: 0.1456 - accuracy: 0.9279 - 1s/epoch - 6ms/step
# Epoch 12/200
# 207/207 - 1s - loss: 0.1444 - accuracy: 0.9296 - 1s/epoch - 6ms/step
# Epoch 13/200
# 207/207 - 1s - loss: 0.1424 - accuracy: 0.9299 - 1s/epoch - 6ms/step
# Epoch 14/200
# 207/207 - 1s - loss: 0.1423 - accuracy: 0.9297 - 1s/epoch - 6ms/step
# Epoch 15/200
# 207/207 - 1s - loss: 0.1410 - accuracy: 0.9305 - 1s/epoch - 7ms/step
# Epoch 16/200
# 207/207 - 1s - loss: 0.1410 - accuracy: 0.9310 - 1s/epoch - 7ms/step
# Epoch 17/200
# 207/207 - 1s - loss: 0.1394 - accuracy: 0.9312 - 1s/epoch - 7ms/step
# Epoch 18/200
# 207/207 - 1s - loss: 0.1394 - accuracy: 0.9315 - 1s/epoch - 7ms/step
# Epoch 19/200
# 207/207 - 1s - loss: 0.1378 - accuracy: 0.9327 - 1s/epoch - 7ms/step
# Epoch 20/200
# 207/207 - 1s - loss: 0.1377 - accuracy: 0.9327 - 1s/epoch - 7ms/step
# Epoch 21/200
# 207/207 - 1s - loss: 0.1376 - accuracy: 0.9317 - 1s/epoch - 7ms/step
# Epoch 22/200
# 207/207 - 1s - loss: 0.1380 - accuracy: 0.9318 - 1s/epoch - 7ms/step
# Epoch 23/200
# 207/207 - 1s - loss: 0.1362 - accuracy: 0.9326 - 1s/epoch - 7ms/step
# Epoch 24/200
# 207/207 - 1s - loss: 0.1374 - accuracy: 0.9320 - 1s/epoch - 7ms/step
# Epoch 25/200
# 207/207 - 1s - loss: 0.1361 - accuracy: 0.9328 - 1s/epoch - 7ms/step
# Epoch 26/200
# 207/207 - 1s - loss: 0.1356 - accuracy: 0.9332 - 1s/epoch - 7ms/step
# Epoch 27/200
# 207/207 - 1s - loss: 0.1349 - accuracy: 0.9337 - 1s/epoch - 7ms/step
# Epoch 28/200
# 207/207 - 1s - loss: 0.1366 - accuracy: 0.9320 - 1s/epoch - 7ms/step
# Epoch 29/200
# 207/207 - 1s - loss: 0.1351 - accuracy: 0.9332 - 1s/epoch - 7ms/step
# Epoch 30/200
# 207/207 - 1s - loss: 0.1337 - accuracy: 0.9343 - 1s/epoch - 7ms/step
# Epoch 31/200
# 207/207 - 1s - loss: 0.1334 - accuracy: 0.9348 - 1s/epoch - 7ms/step
# Epoch 32/200
# 207/207 - 1s - loss: 0.1334 - accuracy: 0.9343 - 1s/epoch - 6ms/step
# Epoch 33/200
# 207/207 - 1s - loss: 0.1333 - accuracy: 0.9342 - 1s/epoch - 7ms/step
# Epoch 34/200
# 207/207 - 1s - loss: 0.1317 - accuracy: 0.9354 - 1s/epoch - 7ms/step
# Epoch 35/200
# 207/207 - 1s - loss: 0.1324 - accuracy: 0.9350 - 1s/epoch - 7ms/step
# Epoch 36/200
# 207/207 - 1s - loss: 0.1308 - accuracy: 0.9354 - 1s/epoch - 7ms/step
# Epoch 37/200
# 207/207 - 1s - loss: 0.1316 - accuracy: 0.9355 - 1s/epoch - 7ms/step
# Epoch 38/200
# 207/207 - 1s - loss: 0.1300 - accuracy: 0.9366 - 1s/epoch - 7ms/step
# Epoch 39/200
# 207/207 - 1s - loss: 0.1300 - accuracy: 0.9360 - 1s/epoch - 6ms/step
# Epoch 40/200
# 207/207 - 1s - loss: 0.1299 - accuracy: 0.9362 - 1s/epoch - 6ms/step
# Epoch 41/200
# 207/207 - 1s - loss: 0.1290 - accuracy: 0.9363 - 1s/epoch - 6ms/step
# Epoch 42/200
# 207/207 - 1s - loss: 0.1291 - accuracy: 0.9371 - 1s/epoch - 7ms/step
# Epoch 43/200
# 207/207 - 1s - loss: 0.1289 - accuracy: 0.9369 - 1s/epoch - 6ms/step
# Epoch 44/200
# 207/207 - 2s - loss: 0.1289 - accuracy: 0.9368 - 2s/epoch - 8ms/step
# Epoch 45/200
# 207/207 - 2s - loss: 0.1283 - accuracy: 0.9369 - 2s/epoch - 8ms/step
# Epoch 46/200
# 207/207 - 1s - loss: 0.1278 - accuracy: 0.9374 - 1s/epoch - 6ms/step
# Epoch 47/200
# 207/207 - 1s - loss: 0.1265 - accuracy: 0.9378 - 1s/epoch - 6ms/step
# Epoch 48/200
# 207/207 - 1s - loss: 0.1272 - accuracy: 0.9379 - 1s/epoch - 6ms/step
# Epoch 49/200
# 207/207 - 1s - loss: 0.1269 - accuracy: 0.9381 - 1s/epoch - 6ms/step
# Epoch 50/200
# 207/207 - 1s - loss: 0.1275 - accuracy: 0.9373 - 1s/epoch - 6ms/step
# Epoch 51/200
# 207/207 - 1s - loss: 0.1260 - accuracy: 0.9383 - 1s/epoch - 6ms/step
# Epoch 52/200
# 207/207 - 1s - loss: 0.1253 - accuracy: 0.9385 - 1s/epoch - 6ms/step
# Epoch 53/200
# 207/207 - 1s - loss: 0.1255 - accuracy: 0.9384 - 1s/epoch - 6ms/step
# Epoch 54/200
# 207/207 - 1s - loss: 0.1247 - accuracy: 0.9392 - 1s/epoch - 6ms/step
# Epoch 55/200
# 207/207 - 1s - loss: 0.1245 - accuracy: 0.9386 - 1s/epoch - 6ms/step
# Epoch 56/200
# 207/207 - 1s - loss: 0.1241 - accuracy: 0.9393 - 1s/epoch - 6ms/step
# Epoch 57/200
# 207/207 - 1s - loss: 0.1247 - accuracy: 0.9390 - 1s/epoch - 6ms/step
# Epoch 58/200
# 207/207 - 1s - loss: 0.1233 - accuracy: 0.9394 - 1s/epoch - 6ms/step
# Epoch 59/200
# 207/207 - 1s - loss: 0.1236 - accuracy: 0.9388 - 1s/epoch - 6ms/step
# Epoch 60/200
# 207/207 - 1s - loss: 0.1222 - accuracy: 0.9397 - 1s/epoch - 6ms/step
# Epoch 61/200
# 207/207 - 1s - loss: 0.1229 - accuracy: 0.9397 - 1s/epoch - 6ms/step
# Epoch 62/200
# 207/207 - 1s - loss: 0.1226 - accuracy: 0.9399 - 1s/epoch - 6ms/step
# Epoch 63/200
# 207/207 - 1s - loss: 0.1219 - accuracy: 0.9397 - 1s/epoch - 6ms/step
# Epoch 64/200
# 207/207 - 1s - loss: 0.1217 - accuracy: 0.9401 - 1s/epoch - 6ms/step
# Epoch 65/200
# 207/207 - 1s - loss: 0.1208 - accuracy: 0.9403 - 1s/epoch - 6ms/step
# Epoch 66/200
# 207/207 - 1s - loss: 0.1204 - accuracy: 0.9409 - 1s/epoch - 6ms/step
# Epoch 67/200
# 207/207 - 1s - loss: 0.1199 - accuracy: 0.9410 - 1s/epoch - 6ms/step
# Epoch 68/200
# 207/207 - 1s - loss: 0.1195 - accuracy: 0.9416 - 1s/epoch - 6ms/step
# Epoch 69/200
# 207/207 - 1s - loss: 0.1198 - accuracy: 0.9416 - 1s/epoch - 6ms/step
# Epoch 70/200
# 207/207 - 1s - loss: 0.1194 - accuracy: 0.9410 - 1s/epoch - 6ms/step
# Epoch 71/200
# 207/207 - 1s - loss: 0.1188 - accuracy: 0.9412 - 1s/epoch - 6ms/step
# Epoch 72/200
# 207/207 - 1s - loss: 0.1183 - accuracy: 0.9421 - 1s/epoch - 6ms/step
# Epoch 73/200
# 207/207 - 1s - loss: 0.1177 - accuracy: 0.9422 - 1s/epoch - 6ms/step
# Epoch 74/200
# 207/207 - 1s - loss: 0.1184 - accuracy: 0.9420 - 1s/epoch - 6ms/step
# Epoch 75/200
# 207/207 - 1s - loss: 0.1170 - accuracy: 0.9423 - 1s/epoch - 6ms/step
# Epoch 76/200
# 207/207 - 1s - loss: 0.1168 - accuracy: 0.9428 - 1s/epoch - 6ms/step
# Epoch 77/200
# 207/207 - 1s - loss: 0.1165 - accuracy: 0.9429 - 1s/epoch - 6ms/step
# Epoch 78/200
# 207/207 - 1s - loss: 0.1164 - accuracy: 0.9427 - 1s/epoch - 6ms/step
# Epoch 79/200
# 207/207 - 1s - loss: 0.1163 - accuracy: 0.9431 - 1s/epoch - 6ms/step
# Epoch 80/200
# 207/207 - 1s - loss: 0.1154 - accuracy: 0.9432 - 1s/epoch - 6ms/step
# Epoch 81/200
# 207/207 - 1s - loss: 0.1149 - accuracy: 0.9436 - 1s/epoch - 6ms/step
# Epoch 82/200
# 207/207 - 1s - loss: 0.1148 - accuracy: 0.9435 - 1s/epoch - 6ms/step
# Epoch 83/200
# 207/207 - 1s - loss: 0.1142 - accuracy: 0.9438 - 1s/epoch - 6ms/step
# Epoch 84/200
# 207/207 - 1s - loss: 0.1137 - accuracy: 0.9444 - 1s/epoch - 6ms/step
# Epoch 85/200
# 207/207 - 1s - loss: 0.1132 - accuracy: 0.9446 - 1s/epoch - 6ms/step
# Epoch 86/200
# 207/207 - 1s - loss: 0.1125 - accuracy: 0.9446 - 1s/epoch - 6ms/step
# Epoch 87/200
# 207/207 - 1s - loss: 0.1129 - accuracy: 0.9447 - 1s/epoch - 6ms/step
# Epoch 88/200
# 207/207 - 1s - loss: 0.1122 - accuracy: 0.9448 - 1s/epoch - 6ms/step
# Epoch 89/200
# 207/207 - 1s - loss: 0.1114 - accuracy: 0.9454 - 1s/epoch - 6ms/step
# Epoch 90/200
# 207/207 - 1s - loss: 0.1117 - accuracy: 0.9449 - 1s/epoch - 6ms/step
# Epoch 91/200
# 207/207 - 1s - loss: 0.1109 - accuracy: 0.9452 - 1s/epoch - 6ms/step
# Epoch 92/200
# 207/207 - 1s - loss: 0.1112 - accuracy: 0.9451 - 1s/epoch - 6ms/step
# Epoch 93/200
# 207/207 - 1s - loss: 0.1111 - accuracy: 0.9457 - 1s/epoch - 6ms/step
# Epoch 94/200
# 207/207 - 1s - loss: 0.1108 - accuracy: 0.9453 - 1s/epoch - 6ms/step
# Epoch 95/200
# 207/207 - 1s - loss: 0.1097 - accuracy: 0.9460 - 1s/epoch - 6ms/step
# Epoch 96/200
# 207/207 - 1s - loss: 0.1108 - accuracy: 0.9456 - 1s/epoch - 6ms/step
# Epoch 97/200
# 207/207 - 1s - loss: 0.1091 - accuracy: 0.9465 - 1s/epoch - 6ms/step
# Epoch 98/200
# 207/207 - 1s - loss: 0.1087 - accuracy: 0.9465 - 1s/epoch - 6ms/step
# Epoch 99/200
# 207/207 - 1s - loss: 0.1093 - accuracy: 0.9464 - 1s/epoch - 6ms/step
# Epoch 100/200
# 207/207 - 1s - loss: 0.1077 - accuracy: 0.9472 - 1s/epoch - 6ms/step
# Epoch 101/200
# 207/207 - 1s - loss: 0.1083 - accuracy: 0.9470 - 1s/epoch - 6ms/step
# Epoch 102/200
# 207/207 - 1s - loss: 0.1075 - accuracy: 0.9471 - 1s/epoch - 6ms/step
# Epoch 103/200
# 207/207 - 1s - loss: 0.1076 - accuracy: 0.9473 - 1s/epoch - 6ms/step
# Epoch 104/200
# 207/207 - 1s - loss: 0.1076 - accuracy: 0.9472 - 1s/epoch - 6ms/step
# Epoch 105/200
# 207/207 - 1s - loss: 0.1069 - accuracy: 0.9478 - 1s/epoch - 6ms/step
# Epoch 106/200
# 207/207 - 1s - loss: 0.1069 - accuracy: 0.9476 - 1s/epoch - 6ms/step
# Epoch 107/200
# 207/207 - 1s - loss: 0.1063 - accuracy: 0.9476 - 1s/epoch - 6ms/step
# Epoch 108/200
# 207/207 - 1s - loss: 0.1064 - accuracy: 0.9479 - 1s/epoch - 6ms/step
# Epoch 109/200
# 207/207 - 1s - loss: 0.1056 - accuracy: 0.9486 - 1s/epoch - 6ms/step
# Epoch 110/200
# 207/207 - 1s - loss: 0.1059 - accuracy: 0.9480 - 1s/epoch - 6ms/step
# Epoch 111/200
# 207/207 - 1s - loss: 0.1052 - accuracy: 0.9481 - 1s/epoch - 6ms/step
# Epoch 112/200
# 207/207 - 1s - loss: 0.1047 - accuracy: 0.9485 - 1s/epoch - 6ms/step
# Epoch 113/200
# 207/207 - 1s - loss: 0.1045 - accuracy: 0.9490 - 1s/epoch - 6ms/step
# Epoch 114/200
# 207/207 - 1s - loss: 0.1046 - accuracy: 0.9486 - 1s/epoch - 6ms/step
# Epoch 115/200
# 207/207 - 1s - loss: 0.1041 - accuracy: 0.9489 - 1s/epoch - 6ms/step
# Epoch 116/200
# 207/207 - 1s - loss: 0.1035 - accuracy: 0.9493 - 1s/epoch - 6ms/step
# Epoch 117/200
# 207/207 - 1s - loss: 0.1032 - accuracy: 0.9493 - 1s/epoch - 6ms/step
# Epoch 118/200
# 207/207 - 1s - loss: 0.1037 - accuracy: 0.9492 - 1s/epoch - 6ms/step
# Epoch 119/200
# 207/207 - 1s - loss: 0.1026 - accuracy: 0.9497 - 1s/epoch - 6ms/step
# Epoch 120/200
# 207/207 - 1s - loss: 0.1029 - accuracy: 0.9497 - 1s/epoch - 6ms/step
# Epoch 121/200
# 207/207 - 1s - loss: 0.1027 - accuracy: 0.9495 - 1s/epoch - 6ms/step
# Epoch 122/200
# 207/207 - 1s - loss: 0.1021 - accuracy: 0.9498 - 1s/epoch - 6ms/step
# Epoch 123/200
# 207/207 - 1s - loss: 0.1012 - accuracy: 0.9499 - 1s/epoch - 6ms/step
# Epoch 124/200
# 207/207 - 1s - loss: 0.1008 - accuracy: 0.9504 - 1s/epoch - 6ms/step
# Epoch 125/200
# 207/207 - 1s - loss: 0.1011 - accuracy: 0.9504 - 1s/epoch - 6ms/step
# Epoch 126/200
# 207/207 - 1s - loss: 0.1004 - accuracy: 0.9508 - 1s/epoch - 6ms/step
# Epoch 127/200
# 207/207 - 1s - loss: 0.1009 - accuracy: 0.9503 - 1s/epoch - 6ms/step
# Epoch 128/200
# 207/207 - 1s - loss: 0.0999 - accuracy: 0.9511 - 1s/epoch - 6ms/step
# Epoch 129/200
# 207/207 - 1s - loss: 0.1000 - accuracy: 0.9510 - 1s/epoch - 7ms/step
# Epoch 130/200
# 207/207 - 1s - loss: 0.0996 - accuracy: 0.9511 - 1s/epoch - 6ms/step
# Epoch 131/200
# 207/207 - 1s - loss: 0.0998 - accuracy: 0.9510 - 1s/epoch - 6ms/step
# Epoch 132/200
# 207/207 - 1s - loss: 0.0990 - accuracy: 0.9515 - 1s/epoch - 6ms/step
# Epoch 133/200
# 207/207 - 1s - loss: 0.0994 - accuracy: 0.9516 - 1s/epoch - 6ms/step
# Epoch 134/200
# 207/207 - 1s - loss: 0.0987 - accuracy: 0.9517 - 1s/epoch - 6ms/step
# Epoch 135/200
# 207/207 - 1s - loss: 0.0980 - accuracy: 0.9519 - 1s/epoch - 6ms/step
# Epoch 136/200
# 207/207 - 1s - loss: 0.0985 - accuracy: 0.9524 - 1s/epoch - 6ms/step
# Epoch 137/200
# 207/207 - 1s - loss: 0.0966 - accuracy: 0.9523 - 1s/epoch - 6ms/step
# Epoch 138/200
# 207/207 - 1s - loss: 0.0976 - accuracy: 0.9521 - 1s/epoch - 6ms/step
# Epoch 139/200
# 207/207 - 1s - loss: 0.0966 - accuracy: 0.9529 - 1s/epoch - 6ms/step
# Epoch 140/200
# 207/207 - 1s - loss: 0.0967 - accuracy: 0.9525 - 1s/epoch - 6ms/step
# Epoch 141/200
# 207/207 - 1s - loss: 0.0974 - accuracy: 0.9525 - 1s/epoch - 6ms/step
# Epoch 142/200
# 207/207 - 1s - loss: 0.0959 - accuracy: 0.9531 - 1s/epoch - 6ms/step
# Epoch 143/200
# 207/207 - 1s - loss: 0.0954 - accuracy: 0.9531 - 1s/epoch - 6ms/step
# Epoch 144/200
# 207/207 - 1s - loss: 0.0960 - accuracy: 0.9535 - 1s/epoch - 6ms/step
# Epoch 145/200
# 207/207 - 1s - loss: 0.0957 - accuracy: 0.9532 - 1s/epoch - 6ms/step
# Epoch 146/200
# 207/207 - 1s - loss: 0.1019 - accuracy: 0.9499 - 1s/epoch - 6ms/step
# Epoch 147/200
# 207/207 - 1s - loss: 0.0944 - accuracy: 0.9534 - 1s/epoch - 6ms/step
# Epoch 148/200
# 207/207 - 1s - loss: 0.0953 - accuracy: 0.9533 - 1s/epoch - 6ms/step
# Epoch 149/200
# 207/207 - 1s - loss: 0.0954 - accuracy: 0.9531 - 1s/epoch - 6ms/step
# Epoch 150/200
# 207/207 - 1s - loss: 0.0933 - accuracy: 0.9542 - 1s/epoch - 6ms/step
# Epoch 151/200
# 207/207 - 1s - loss: 0.0942 - accuracy: 0.9542 - 1s/epoch - 6ms/step
# Epoch 152/200
# 207/207 - 1s - loss: 0.0930 - accuracy: 0.9542 - 1s/epoch - 6ms/step
# Epoch 153/200
# 207/207 - 1s - loss: 0.0932 - accuracy: 0.9539 - 1s/epoch - 6ms/step
# Epoch 154/200
# 207/207 - 1s - loss: 0.0935 - accuracy: 0.9541 - 1s/epoch - 6ms/step
# Epoch 155/200
# 207/207 - 1s - loss: 0.0923 - accuracy: 0.9546 - 1s/epoch - 6ms/step
# Epoch 156/200
# 207/207 - 1s - loss: 0.0940 - accuracy: 0.9540 - 1s/epoch - 6ms/step
# Epoch 157/200
# 207/207 - 1s - loss: 0.0919 - accuracy: 0.9549 - 1s/epoch - 6ms/step
# Epoch 158/200
# 207/207 - 1s - loss: 0.0910 - accuracy: 0.9554 - 1s/epoch - 6ms/step
# Epoch 159/200
# 207/207 - 1s - loss: 0.0921 - accuracy: 0.9548 - 1s/epoch - 6ms/step
# Epoch 160/200
# 207/207 - 1s - loss: 0.0908 - accuracy: 0.9554 - 1s/epoch - 6ms/step
# Epoch 161/200
# 207/207 - 1s - loss: 0.0912 - accuracy: 0.9554 - 1s/epoch - 6ms/step
# Epoch 162/200
# 207/207 - 1s - loss: 0.0919 - accuracy: 0.9551 - 1s/epoch - 6ms/step
# Epoch 163/200
# 207/207 - 1s - loss: 0.0898 - accuracy: 0.9560 - 1s/epoch - 6ms/step
# Epoch 164/200
# 207/207 - 1s - loss: 0.0907 - accuracy: 0.9552 - 1s/epoch - 6ms/step
# Epoch 165/200
# 207/207 - 1s - loss: 0.0898 - accuracy: 0.9560 - 1s/epoch - 6ms/step
# Epoch 166/200
# 207/207 - 1s - loss: 0.0895 - accuracy: 0.9560 - 1s/epoch - 6ms/step
# Epoch 167/200
# 207/207 - 1s - loss: 0.0897 - accuracy: 0.9560 - 1s/epoch - 6ms/step
# Epoch 168/200
# 207/207 - 1s - loss: 0.0902 - accuracy: 0.9557 - 1s/epoch - 6ms/step
# Epoch 169/200
# 207/207 - 1s - loss: 0.0890 - accuracy: 0.9566 - 1s/epoch - 6ms/step
# Epoch 170/200
# 207/207 - 1s - loss: 0.0893 - accuracy: 0.9563 - 1s/epoch - 6ms/step
# Epoch 171/200
# 207/207 - 1s - loss: 0.0882 - accuracy: 0.9568 - 1s/epoch - 6ms/step
# Epoch 172/200
# 207/207 - 1s - loss: 0.0881 - accuracy: 0.9564 - 1s/epoch - 6ms/step
# Epoch 173/200
# 207/207 - 1s - loss: 0.0884 - accuracy: 0.9570 - 1s/epoch - 6ms/step
# Epoch 174/200
# 207/207 - 1s - loss: 0.0878 - accuracy: 0.9568 - 1s/epoch - 6ms/step
# Epoch 175/200
# 207/207 - 1s - loss: 0.0876 - accuracy: 0.9570 - 1s/epoch - 6ms/step
# Epoch 176/200
# 207/207 - 1s - loss: 0.0877 - accuracy: 0.9573 - 1s/epoch - 6ms/step
# Epoch 177/200
# 207/207 - 1s - loss: 0.0866 - accuracy: 0.9575 - 1s/epoch - 6ms/step
# Epoch 178/200
# 207/207 - 1s - loss: 0.0886 - accuracy: 0.9569 - 1s/epoch - 6ms/step
# Epoch 179/200
# 207/207 - 1s - loss: 0.0861 - accuracy: 0.9577 - 1s/epoch - 6ms/step
# Epoch 180/200
# 207/207 - 1s - loss: 0.0867 - accuracy: 0.9573 - 1s/epoch - 6ms/step
# Epoch 181/200
# 207/207 - 1s - loss: 0.0854 - accuracy: 0.9579 - 1s/epoch - 6ms/step
# Epoch 182/200
# 207/207 - 1s - loss: 0.0851 - accuracy: 0.9582 - 1s/epoch - 6ms/step
# Epoch 183/200
# 207/207 - 1s - loss: 0.0859 - accuracy: 0.9581 - 1s/epoch - 6ms/step
# Epoch 184/200
# 207/207 - 1s - loss: 0.0841 - accuracy: 0.9588 - 1s/epoch - 6ms/step
# Epoch 185/200
# 207/207 - 1s - loss: 0.0853 - accuracy: 0.9582 - 1s/epoch - 6ms/step
# Epoch 186/200
# 207/207 - 1s - loss: 0.0854 - accuracy: 0.9583 - 1s/epoch - 6ms/step
# Epoch 187/200
# 207/207 - 1s - loss: 0.0856 - accuracy: 0.9579 - 1s/epoch - 6ms/step
# Epoch 188/200
# 207/207 - 1s - loss: 0.0857 - accuracy: 0.9579 - 1s/epoch - 6ms/step
# Epoch 189/200
# 207/207 - 1s - loss: 0.0847 - accuracy: 0.9583 - 1s/epoch - 6ms/step
# Epoch 190/200
# 207/207 - 1s - loss: 0.0829 - accuracy: 0.9593 - 1s/epoch - 6ms/step
# Epoch 191/200
# 207/207 - 1s - loss: 0.0827 - accuracy: 0.9591 - 1s/epoch - 6ms/step
# Epoch 192/200
# 207/207 - 1s - loss: 0.0831 - accuracy: 0.9593 - 1s/epoch - 6ms/step
# Epoch 193/200
# 207/207 - 1s - loss: 0.0854 - accuracy: 0.9582 - 1s/epoch - 6ms/step
# Epoch 194/200
# 207/207 - 1s - loss: 0.0820 - accuracy: 0.9597 - 1s/epoch - 6ms/step
# Epoch 195/200
# 207/207 - 1s - loss: 0.0820 - accuracy: 0.9598 - 1s/epoch - 6ms/step
# Epoch 196/200
# 207/207 - 1s - loss: 0.0823 - accuracy: 0.9594 - 1s/epoch - 6ms/step
# Epoch 197/200
# 207/207 - 1s - loss: 0.0810 - accuracy: 0.9602 - 1s/epoch - 6ms/step
# Epoch 198/200
# 207/207 - 1s - loss: 0.0864 - accuracy: 0.9575 - 1s/epoch - 6ms/step
# Epoch 199/200
# 207/207 - 1s - loss: 0.0813 - accuracy: 0.9598 - 1s/epoch - 6ms/step
# Epoch 200/200
# 207/207 - 1s - loss: 0.0819 - accuracy: 0.9595 - 1s/epoch - 6ms/step

# %%
accuracy, recall, precision, f1, end_predict = evaluate_model(model_gru, X_test_reshaped, y_test, True)
# Out:
# 1611/1611 [==============================] - 5s 3ms/step
# Modell: GRU_3
# Genauigkeit: 0.9445231396138547
# Recall: 0.9445231396138547
# Precision: 0.944504913701851
# F1 Score: 0.9445137054763902

# %%
results = append_model_reults(model_gru, results, end_train - start, end_predict - end_train, accuracy, recall, precision, f1)

# %% [markdown]
# #### 4.2.4 Autoencoder (simple variant)
# - **Variant without Timestamps:** The simple variant does not support using MAE for anomaly prediction, given the absence of timestamps in the USBNW-15 dataset.
# - **Anomaly Detection:** Henceforth, it can be kept simple, as we did in the approach to anomaly detection for the classification algorithms.

# %%
# Autoencoder_1: encoder = 32 X 16 X 8; decoder = 16 X 32; -> 93.85 test 93 train
# Autoencoder_2: encoder = 32 X 16 X 8; decoder = 8 X 16 X 32; -> 93.9 test 93 train -> deutlich langsamer
# Autoencoder_3: encoder = 64 X 32 X 16; decoder = 32 X 64; -> 94.1 test 93.34 train -> am schnellsten und besten -> 2. 5.5s
# Autoencoder_4: encoder = 128 X 64 X 32 X 16; decoder = 32 X 64 X 128; -> 94.09 test 95.1 train -> am langsamsten 
# Autoencoder_5: encoder = 128 X 64 X 32; decoder = 32 X 64; -> 94.4 test 95.2 train -> schnell und am besten -> 1. 
# Autoencoder_6: encoder = 128 X 64 X 32; decoder = 64 X 128; -> 94 test 95.4 train -> keine Verbesserung
# Autoencoder_7: encoder = 256 X 128 X 64; decoder = 32 X 64; -> 94.35 test 96 train -> gute Genauigkeite + schnellste PTime -> 5s 
# Autoencoder_8: encoder = 256 X 128 X 64; decoder = 32 X 64; Dropout 50% -> ass
# Autoencoder_9: encoder = 256 X 128; decoder = 32 X 64; -> 94.38 test 96 train -> bestes Modell momentan
# Autoencoder_10: encoder = 256 X 128; decoder = 16 X 32; -> 94.39 test 95.5 train -> bestes Modell momentan
# Autoencoder_11: encoder = 256 X 128; decoder = 32; -> 94.3 test 95.7 train -> PTime 4.3s -> am schnellsten
# Autoencoder_12: encoder = 256 X 128; decoder = 128; -> 94.4 test 96.3 train -> PTime 4.7s -> #### Bestes Modell.
# Autoencoder_13: encoder = 512 X 256; decoder = 128; -> x test x train -> PTime x -> am schnellsten
# Autoencoder_14: encoder = 256 X 128; decoder = 64; loss = mae, metrics=['accuracy']; ass
# Autoencoder_15: encoder = 256 X 128; decoder = 64; loss = mae; ass

# %%
class AnomalyDetector(Model):
    def __init__(self, name="AnomalyDetector"):
        super(AnomalyDetector, self).__init__(name=name)
        self.encoder = tf.keras.Sequential([
            layers.Dense(256, activation="relu"),
            layers.Dense(128, activation="relu"),],
            name="encoder")
        
        self.decoder = tf.keras.Sequential([
            layers.Dense(128, activation="relu"),
            layers.Dense(TOTAL_FEATURES, activation="linear")],
            name="decoder")

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

model_autoencoder = AnomalyDetector(name="Autoencoder")
opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model_autoencoder.compile(optimizer=opt, loss=['mae'])

# %%
start = time.time()
history = model_autoencoder.fit(X_train_reshaped, X_train_reshaped, epochs=EPOCHS, batch_size=BATCH_SIZE, 
                               shuffle=True, validation_data=(X_test_reshaped, X_test_reshaped)) # Training model
end_train = time.time()
# Out:
# Epoch 1/200
# 207/207 [==============================] - 3s 6ms/step - loss: 0.1449 - val_loss: 0.0620
# Epoch 2/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0480 - val_loss: 0.0405
# Epoch 3/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0365 - val_loss: 0.0339
# Epoch 4/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0320 - val_loss: 0.0303
# Epoch 5/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0284 - val_loss: 0.0253
# Epoch 6/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0257 - val_loss: 0.0256
# Epoch 7/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0248 - val_loss: 0.0238
# Epoch 8/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0218 - val_loss: 0.0220
# Epoch 9/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0207 - val_loss: 0.0206
# Epoch 10/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0205 - val_loss: 0.0181
# Epoch 11/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0183 - val_loss: 0.0201
# Epoch 12/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0189 - val_loss: 0.0192
# Epoch 13/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0186 - val_loss: 0.0217
# Epoch 14/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0190 - val_loss: 0.0179
# Epoch 15/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0169 - val_loss: 0.0178
# Epoch 16/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0159 - val_loss: 0.0167
# Epoch 17/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0163 - val_loss: 0.0151
# Epoch 18/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0164 - val_loss: 0.0149
# Epoch 19/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0158 - val_loss: 0.0156
# Epoch 20/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0146 - val_loss: 0.0160
# Epoch 21/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0150 - val_loss: 0.0145
# Epoch 22/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0152 - val_loss: 0.0170
# Epoch 23/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0142 - val_loss: 0.0126
# Epoch 24/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0137 - val_loss: 0.0156
# Epoch 25/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0140 - val_loss: 0.0140
# Epoch 26/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0137 - val_loss: 0.0130
# Epoch 27/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0138 - val_loss: 0.0145
# Epoch 28/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0138 - val_loss: 0.0143
# Epoch 29/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0138 - val_loss: 0.0133
# Epoch 30/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0136 - val_loss: 0.0138
# Epoch 31/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0123 - val_loss: 0.0120
# Epoch 32/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0127 - val_loss: 0.0122
# Epoch 33/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0131 - val_loss: 0.0154
# Epoch 34/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0129 - val_loss: 0.0122
# Epoch 35/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0126 - val_loss: 0.0126
# Epoch 36/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0125 - val_loss: 0.0143
# Epoch 37/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0119 - val_loss: 0.0114
# Epoch 38/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0120 - val_loss: 0.0131
# Epoch 39/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0120 - val_loss: 0.0116
# Epoch 40/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0113 - val_loss: 0.0124
# Epoch 41/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0116 - val_loss: 0.0133
# Epoch 42/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0116 - val_loss: 0.0125
# Epoch 43/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0122 - val_loss: 0.0113
# Epoch 44/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0121 - val_loss: 0.0136
# Epoch 45/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0118 - val_loss: 0.0116
# Epoch 46/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0115 - val_loss: 0.0114
# Epoch 47/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0116 - val_loss: 0.0105
# Epoch 48/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0111 - val_loss: 0.0123
# Epoch 49/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0113 - val_loss: 0.0131
# Epoch 50/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0114 - val_loss: 0.0108
# Epoch 51/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0116 - val_loss: 0.0124
# Epoch 52/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0120 - val_loss: 0.0126
# Epoch 53/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0115 - val_loss: 0.0115
# Epoch 54/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0113 - val_loss: 0.0105
# Epoch 55/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0108 - val_loss: 0.0115
# Epoch 56/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0109 - val_loss: 0.0099
# Epoch 57/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0107 - val_loss: 0.0105
# Epoch 58/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0108 - val_loss: 0.0102
# Epoch 59/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0109 - val_loss: 0.0119
# Epoch 60/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0112 - val_loss: 0.0108
# Epoch 61/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0105 - val_loss: 0.0095
# Epoch 62/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0108 - val_loss: 0.0102
# Epoch 63/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0111 - val_loss: 0.0111
# Epoch 64/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0109 - val_loss: 0.0097
# Epoch 65/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0101 - val_loss: 0.0099
# Epoch 66/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0106 - val_loss: 0.0116
# Epoch 67/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0105 - val_loss: 0.0122
# Epoch 68/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0106 - val_loss: 0.0098
# Epoch 69/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0105 - val_loss: 0.0099
# Epoch 70/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0102 - val_loss: 0.0102
# Epoch 71/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0106 - val_loss: 0.0117
# Epoch 72/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 73/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0105 - val_loss: 0.0096
# Epoch 74/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0103 - val_loss: 0.0100
# Epoch 75/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 76/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0101 - val_loss: 0.0087
# Epoch 77/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0101 - val_loss: 0.0104
# Epoch 78/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 79/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 80/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0098 - val_loss: 0.0092
# Epoch 81/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0100 - val_loss: 0.0095
# Epoch 82/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0100 - val_loss: 0.0117
# Epoch 83/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0101 - val_loss: 0.0099
# Epoch 84/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0095 - val_loss: 0.0101
# Epoch 85/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0098 - val_loss: 0.0093
# Epoch 86/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0102 - val_loss: 0.0123
# Epoch 87/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0103 - val_loss: 0.0092
# Epoch 88/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0094 - val_loss: 0.0102
# Epoch 89/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0095 - val_loss: 0.0095
# Epoch 90/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0099 - val_loss: 0.0112
# Epoch 91/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0098 - val_loss: 0.0102
# Epoch 92/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0097 - val_loss: 0.0090
# Epoch 93/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0098 - val_loss: 0.0098
# Epoch 94/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0095 - val_loss: 0.0095
# Epoch 95/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0096 - val_loss: 0.0100
# Epoch 96/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0099 - val_loss: 0.0122
# Epoch 97/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0096 - val_loss: 0.0094
# Epoch 98/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0097 - val_loss: 0.0105
# Epoch 99/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0096 - val_loss: 0.0114
# Epoch 100/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0101 - val_loss: 0.0094
# Epoch 101/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0101 - val_loss: 0.0120
# Epoch 102/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0096 - val_loss: 0.0103
# Epoch 103/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0092 - val_loss: 0.0102
# Epoch 104/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0094 - val_loss: 0.0090
# Epoch 105/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0093 - val_loss: 0.0096
# Epoch 106/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0092 - val_loss: 0.0096
# Epoch 107/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0095 - val_loss: 0.0092
# Epoch 108/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0092 - val_loss: 0.0100
# Epoch 109/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0093 - val_loss: 0.0100
# Epoch 110/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 111/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0095 - val_loss: 0.0090
# Epoch 112/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0090 - val_loss: 0.0094
# Epoch 113/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 114/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0091 - val_loss: 0.0099
# Epoch 115/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0094 - val_loss: 0.0113
# Epoch 116/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0100 - val_loss: 0.0090
# Epoch 117/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0090 - val_loss: 0.0089
# Epoch 118/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 119/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 120/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0091 - val_loss: 0.0102
# Epoch 121/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0092 - val_loss: 0.0104
# Epoch 122/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0092 - val_loss: 0.0087
# Epoch 123/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0090 - val_loss: 0.0085
# Epoch 124/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0089 - val_loss: 0.0105
# Epoch 125/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 126/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0088 - val_loss: 0.0084
# Epoch 127/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0088 - val_loss: 0.0083
# Epoch 128/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0088 - val_loss: 0.0078
# Epoch 129/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0086 - val_loss: 0.0084
# Epoch 130/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0085 - val_loss: 0.0093
# Epoch 131/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 132/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0089 - val_loss: 0.0087
# Epoch 133/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0094 - val_loss: 0.0101
# Epoch 134/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0085 - val_loss: 0.0093
# Epoch 135/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0090 - val_loss: 0.0084
# Epoch 136/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 137/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 138/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 139/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 140/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0086 - val_loss: 0.0098
# Epoch 141/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 142/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0088 - val_loss: 0.0095
# Epoch 143/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 144/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0088
# Epoch 145/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0089 - val_loss: 0.0100
# Epoch 146/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 147/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 148/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 149/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0080 - val_loss: 0.0090
# Epoch 150/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 151/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 152/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0088
# Epoch 153/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0095
# Epoch 154/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0094 - val_loss: 0.0088
# Epoch 155/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0086
# Epoch 156/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 157/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0080 - val_loss: 0.0085
# Epoch 158/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 159/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0082 - val_loss: 0.0094
# Epoch 160/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 161/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 162/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 163/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0107
# Epoch 164/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 165/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0082 - val_loss: 0.0076
# Epoch 166/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0081 - val_loss: 0.0078
# Epoch 167/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0075
# Epoch 168/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0081
# Epoch 169/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0083 - val_loss: 0.0079
# Epoch 170/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0080 - val_loss: 0.0089
# Epoch 171/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0080
# Epoch 172/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 173/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0079 - val_loss: 0.0087
# Epoch 174/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0075
# Epoch 175/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 176/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0080 - val_loss: 0.0076
# Epoch 177/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 178/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0084 - val_loss: 0.0071
# Epoch 179/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0082 - val_loss: 0.0090
# Epoch 180/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 181/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0081 - val_loss: 0.0099
# Epoch 182/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 183/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 184/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0076 - val_loss: 0.0077
# Epoch 185/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0076 - val_loss: 0.0089
# Epoch 186/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 187/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0076 - val_loss: 0.0077
# Epoch 188/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0078
# Epoch 189/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0077 - val_loss: 0.0077
# Epoch 190/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0079 - val_loss: 0.0094
# Epoch 191/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0084 - val_loss: 0.0089
# Epoch 192/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0078 - val_loss: 0.0081
# Epoch 193/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 194/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 195/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 196/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0074 - val_loss: 0.0082
# Epoch 197/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 198/200
# 207/207 [==============================] - 1s 5ms/step - loss: 0.0077 - val_loss: 0.0070
# Epoch 199/200
# 207/207 [==============================] - 1s 6ms/step - loss: 0.0077 - val_loss: 0.0073
# Epoch 200/200
# 207/207 [==============================] - 1s 4ms/step - loss: 0.0077 - val_loss: 0.0076

# %%
accuracy, recall, precision, f1, end_predict = evaluate_model_timeseries(model_autoencoder, X_test_reshaped, y_test, True, 1) # Testing model
# Out:
# 1611/1611 [==============================] - 4s 2ms/step
# Modell: Autoencoder
# Genauigkeit: 0.6291452410982827
# Recall: 0.6291452410982827
# Precision: 0.567965553080559
# F1 Score: 0.5402931876183356

# %%
plot_mae_distribution(model_autoencoder, X_test_reshaped, y_test, number_of_outputs=1)
# Out:
# 1611/1611 [==============================] - 3s 2ms/step

# %%
encoded_data = model_autoencoder.encoder(X_test_reshaped).numpy()
decoded_data = model_autoencoder.decoder(encoded_data).numpy()

plot_autoencoder_reconstruction(decoded_data, X_test_reshaped)

# %%
class SupervisedAutoencoder(tf.keras.Model):
    def __init__(self, input_shape, name="SAE"):
        super(SupervisedAutoencoder, self).__init__(name=name)
        self.encoder = tf.keras.Sequential([
            layers.Flatten(input_shape=input_shape),
            layers.Dense(256, activation='relu'),
            layers.Dense(128, activation='relu'),
        ])
        
        self.decoder = tf.keras.Sequential([
            layers.Dense(128, activation='relu'),
            layers.Dense(input_shape[0] * input_shape[1], activation='linear'),
            layers.Reshape(input_shape)
        ])
        
        self.classification_layer = tf.keras.layers.Dense(TOTAL_FEATURES, activation='softmax')
        
    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        classification = self.classification_layer(encoded)
        return decoded, classification

# %%
model_autoencoder = SupervisedAutoencoder(input_shape=(1, TOTAL_FEATURES), name=MODEL_NAME)
opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model_autoencoder.compile(optimizer=opt, loss=['mse'], metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=EARLY_STOPPING_PATIENCE, restore_best_weights=True)

# %%
start = time.time()
history = model_autoencoder.fit(X_train_reshaped, X_train_reshaped, epochs=EPOCHS, batch_size=BATCH_SIZE, 
                                verbose=2, validation_data=(X_test_reshaped, X_test_reshaped), callbacks=[early_stopping]) # Training model
end_train = time.time()
accuracy, recall, precision, f1, end_predict = evaluate_model(model_autoencoder, X_test_reshaped, y_test, True, 2) # Testing model
# Out:
# Epoch 1/200
# WARNING:tensorflow:Gradients do not exist for variables ['SAE/dense_103/kernel:0', 'SAE/dense_103/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['SAE/dense_103/kernel:0', 'SAE/dense_103/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 207/207 - 2s - loss: 0.0712 - output_1_loss: 0.0712 - output_1_accuracy: 0.5872 - output_2_accuracy: 0.0094 - val_loss: 0.0067 - val_output_1_loss: 0.0067 - val_output_1_accuracy: 0.7601 - val_output_2_accuracy: 1.7464e-04 - 2s/epoch - 7ms/step
# Epoch 2/200
# 207/207 - 1s - loss: 0.0041 - output_1_loss: 0.0041 - output_1_accuracy: 0.8047 - output_2_accuracy: 9.7022e-05 - val_loss: 0.0027 - val_output_1_loss: 0.0027 - val_output_1_accuracy: 0.8543 - val_output_2_accuracy: 3.8809e-05 - 723ms/epoch - 3ms/step
# Epoch 3/200
# 207/207 - 1s - loss: 6.1619e-05 - output_1_loss: 6.1619e-05 - output_1_accuracy: 0.9167 - output_2_accuracy: 0.0047 - val_loss: 1.5298e-04 - val_output_1_loss: 1.5298e-04 - val_output_1_accuracy: 0.9287 - val_output_2_accuracy: 0.0048 - 696ms/epoch - 3ms/step
# 1611/1611 [==============================] - 2s 1ms/step
# Modell: SAE
# Genauigkeit: 0.0
# Recall: 0.0
# Precision: 0.0
# F1 Score: 0.0
# c:\Users\Alexej\miniconda3\envs\simple-htr-gpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Alexej\miniconda3\envs\simple-htr-gpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
accuracy, recall, precision, f1, end_predict = evaluate_model_timeseries(model_autoencoder, X_test_reshaped, y_test, True, 2) # Testing model
# Out:
# 1611/1611 [==============================] - 2s 1ms/step
# Modell: SAE
# Genauigkeit: 0.6334529931114776
# Recall: 0.6334529931114776
# Precision: 0.5813930313327613
# F1 Score: 0.5484448440378251

# %%
results = append_model_reults(model_autoencoder, results, end_train - start, end_predict - end_train, accuracy, recall, precision, f1)

# %%
# Plot der Verlustfunktion
plt.plot(history.history['output_1_loss'], label='Decoder Loss')
plt.plot(history.history['val_output_1_loss'], label='Decoder val_loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(model_autoencoder.name + ': Loss without Timestamps')
plt.legend()
plt.show()

# Plot der Genauigkeit
plt.plot(history.history['output_1_accuracy'], label='Decoder Accuracy')
plt.plot(history.history['val_output_1_accuracy'], label='Decoder Val_Accuracy')
plt.plot(history.history['output_2_accuracy'], label='Class Accuracy')
plt.plot(history.history['val_output_2_accuracy'], label='Class Val_Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title(model_autoencoder.name + ': Accuracy without Timestamps')
plt.legend()
plt.show()

# %% [markdown]
# #### 4.2.5 Autoencoder with conv

# %%
#model_autoencoder_test.build(input_shape=(None, 1, 56)) # for debugging
# Out:
# x:  (None, 1, 56)
# Shape nach Encoder: (None, 1, 128)
# Shape nach Decoder: (None, 1, 56)

# %%
# Best model ConvolutionalAutoencoder_6
class ConvolutionalAnomalyDetector(Model):
    def __init__(self, name="ConvolutionalAnomalyDetector"):
        super(ConvolutionalAnomalyDetector, self).__init__(name=name)
        self.encoder = tf.keras.Sequential([
            layers.Dense(256, activation='relu')],
            name="encoder")
        
        self.decoder = tf.keras.Sequential([
            layers.Dense(64, activation='relu'),
            layers.Conv1DTranspose(filters=TOTAL_FEATURES, kernel_size=3, activation='sigmoid', padding='same')],
            name="decoder")

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

model_conv_autoencoder = ConvolutionalAnomalyDetector(name="ConvolutionalAutoencoder_6")
opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model_conv_autoencoder.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
class ConvolutionalAnomalyDetector(Model):
    def __init__(self, name="ConvolutionalAnomalyDetector"):
        super(ConvolutionalAnomalyDetector, self).__init__(name=name)
        self.encoder = tf.keras.Sequential([
            layers.Conv1D(filters=32, kernel_size=7, padding="same", activation="relu"),
            layers.Dropout(rate=0.2),
            layers.Conv1D(filters=16, kernel_size=7, padding="same", activation="relu"),
            layers.Conv1DTranspose(filters=16, kernel_size=7, padding="same", activation="relu"),
            layers.Dropout(rate=0.2)],
            name="encoder")
        
        self.decoder = tf.keras.Sequential([
            layers.Conv1DTranspose(filters=32, kernel_size=7, padding="same", activation="relu"),
            layers.Conv1DTranspose(filters=TOTAL_FEATURES, kernel_size=3, activation='sigmoid', padding='same')],
            name="decoder")

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

model_conv_autoencoder = ConvolutionalAnomalyDetector(name="ConvolutionalAutoencoder_9")
opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model_conv_autoencoder.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model_autoencoder_conv = keras.Sequential(
    [
        layers.Conv1D(filters=32, kernel_size=7, padding="same", strides=2, activation="relu"),
        layers.Dropout(rate=0.2),
        layers.Conv1D(filters=16, kernel_size=7, padding="same", strides=2, activation="relu"),
        layers.Conv1DTranspose(filters=16, kernel_size=7, padding="same", strides=2, activation="relu"),
        layers.Dropout(rate=0.2),
        layers.Conv1DTranspose(filters=32, kernel_size=7, padding="same", strides=2, activation="relu"),
        layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
    ],
    name="ConvolutionalAutoencoder_4"
)
opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model_autoencoder_conv.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
start = time.time()
history = model_conv_autoencoder.fit(X_train_reshaped, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2) # Training model
end_train = time.time()
accuracy, recall, precision, f1, end_predict = evaluate_model(model_conv_autoencoder, X_test_reshaped, y_test, True) # Testing model
# Out:
# Epoch 1/200
# 207/207 - 19s - loss: 0.4567 - accuracy: 0.8733 - 19s/epoch - 91ms/step
# Epoch 2/200
# 207/207 - 1s - loss: 0.1639 - accuracy: 0.9156 - 653ms/epoch - 3ms/step
# Epoch 3/200
# 207/207 - 1s - loss: 0.1531 - accuracy: 0.9232 - 669ms/epoch - 3ms/step
# Epoch 4/200
# 207/207 - 1s - loss: 0.1498 - accuracy: 0.9238 - 636ms/epoch - 3ms/step
# Epoch 5/200
# 207/207 - 1s - loss: 0.1446 - accuracy: 0.9279 - 666ms/epoch - 3ms/step
# Epoch 6/200
# 207/207 - 1s - loss: 0.1428 - accuracy: 0.9283 - 659ms/epoch - 3ms/step
# Epoch 7/200
# 207/207 - 1s - loss: 0.1420 - accuracy: 0.9288 - 644ms/epoch - 3ms/step
# Epoch 8/200
# 207/207 - 1s - loss: 0.1389 - accuracy: 0.9306 - 684ms/epoch - 3ms/step
# Epoch 9/200
# 207/207 - 1s - loss: 0.1382 - accuracy: 0.9310 - 643ms/epoch - 3ms/step
# Epoch 10/200
# 207/207 - 1s - loss: 0.1365 - accuracy: 0.9322 - 633ms/epoch - 3ms/step
# Epoch 11/200
# 207/207 - 1s - loss: 0.1366 - accuracy: 0.9315 - 703ms/epoch - 3ms/step
# Epoch 12/200
# 207/207 - 1s - loss: 0.1359 - accuracy: 0.9325 - 715ms/epoch - 3ms/step
# Epoch 13/200
# 207/207 - 1s - loss: 0.1334 - accuracy: 0.9335 - 665ms/epoch - 3ms/step
# Epoch 14/200
# 207/207 - 1s - loss: 0.1329 - accuracy: 0.9336 - 693ms/epoch - 3ms/step
# Epoch 15/200
# 207/207 - 1s - loss: 0.1332 - accuracy: 0.9335 - 636ms/epoch - 3ms/step
# Epoch 16/200
# 207/207 - 1s - loss: 0.1316 - accuracy: 0.9348 - 630ms/epoch - 3ms/step
# Epoch 17/200
# 207/207 - 1s - loss: 0.1322 - accuracy: 0.9341 - 641ms/epoch - 3ms/step
# Epoch 18/200
# 207/207 - 1s - loss: 0.1310 - accuracy: 0.9345 - 660ms/epoch - 3ms/step
# Epoch 19/200
# 207/207 - 1s - loss: 0.1309 - accuracy: 0.9349 - 662ms/epoch - 3ms/step
# Epoch 20/200
# 207/207 - 1s - loss: 0.1298 - accuracy: 0.9351 - 637ms/epoch - 3ms/step
# Epoch 21/200
# 207/207 - 1s - loss: 0.1303 - accuracy: 0.9354 - 690ms/epoch - 3ms/step
# Epoch 22/200
# 207/207 - 1s - loss: 0.1292 - accuracy: 0.9359 - 718ms/epoch - 3ms/step
# Epoch 23/200
# 207/207 - 1s - loss: 0.1290 - accuracy: 0.9354 - 717ms/epoch - 3ms/step
# Epoch 24/200
# 207/207 - 1s - loss: 0.1285 - accuracy: 0.9357 - 824ms/epoch - 4ms/step
# Epoch 25/200
# 207/207 - 1s - loss: 0.1281 - accuracy: 0.9359 - 853ms/epoch - 4ms/step
# Epoch 26/200
# 207/207 - 1s - loss: 0.1279 - accuracy: 0.9361 - 662ms/epoch - 3ms/step
# Epoch 27/200
# 207/207 - 1s - loss: 0.1279 - accuracy: 0.9359 - 701ms/epoch - 3ms/step
# Epoch 28/200
# 207/207 - 1s - loss: 0.1273 - accuracy: 0.9360 - 656ms/epoch - 3ms/step
# Epoch 29/200
# 207/207 - 1s - loss: 0.1277 - accuracy: 0.9367 - 717ms/epoch - 3ms/step
# Epoch 30/200
# 207/207 - 1s - loss: 0.1277 - accuracy: 0.9359 - 646ms/epoch - 3ms/step
# Epoch 31/200
# 207/207 - 1s - loss: 0.1260 - accuracy: 0.9368 - 640ms/epoch - 3ms/step
# Epoch 32/200
# 207/207 - 1s - loss: 0.1266 - accuracy: 0.9367 - 640ms/epoch - 3ms/step
# Epoch 33/200
# 207/207 - 1s - loss: 0.1263 - accuracy: 0.9369 - 712ms/epoch - 3ms/step
# Epoch 34/200
# 207/207 - 1s - loss: 0.1266 - accuracy: 0.9366 - 665ms/epoch - 3ms/step
# Epoch 35/200
# 207/207 - 1s - loss: 0.1251 - accuracy: 0.9371 - 641ms/epoch - 3ms/step
# Epoch 36/200
# 207/207 - 1s - loss: 0.1255 - accuracy: 0.9371 - 636ms/epoch - 3ms/step
# Epoch 37/200
# 207/207 - 1s - loss: 0.1253 - accuracy: 0.9371 - 641ms/epoch - 3ms/step
# Epoch 38/200
# 207/207 - 1s - loss: 0.1249 - accuracy: 0.9376 - 743ms/epoch - 4ms/step
# Epoch 39/200
# 207/207 - 1s - loss: 0.1245 - accuracy: 0.9373 - 651ms/epoch - 3ms/step
# Epoch 40/200
# 207/207 - 1s - loss: 0.1252 - accuracy: 0.9371 - 761ms/epoch - 4ms/step
# Epoch 41/200
# 207/207 - 1s - loss: 0.1240 - accuracy: 0.9379 - 688ms/epoch - 3ms/step
# Epoch 42/200
# 207/207 - 1s - loss: 0.1239 - accuracy: 0.9381 - 784ms/epoch - 4ms/step
# Epoch 43/200
# 207/207 - 1s - loss: 0.1236 - accuracy: 0.9385 - 815ms/epoch - 4ms/step
# Epoch 44/200
# 207/207 - 1s - loss: 0.1233 - accuracy: 0.9382 - 784ms/epoch - 4ms/step
# Epoch 45/200
# 207/207 - 1s - loss: 0.1229 - accuracy: 0.9385 - 759ms/epoch - 4ms/step
# Epoch 46/200
# 207/207 - 1s - loss: 0.1230 - accuracy: 0.9389 - 729ms/epoch - 4ms/step
# Epoch 47/200
# 207/207 - 1s - loss: 0.1230 - accuracy: 0.9382 - 801ms/epoch - 4ms/step
# Epoch 48/200
# 207/207 - 1s - loss: 0.1224 - accuracy: 0.9391 - 800ms/epoch - 4ms/step
# Epoch 49/200
# 207/207 - 1s - loss: 0.1229 - accuracy: 0.9387 - 828ms/epoch - 4ms/step
# Epoch 50/200
# 207/207 - 1s - loss: 0.1228 - accuracy: 0.9386 - 790ms/epoch - 4ms/step
# Epoch 51/200
# 207/207 - 1s - loss: 0.1224 - accuracy: 0.9387 - 805ms/epoch - 4ms/step
# Epoch 52/200
# 207/207 - 1s - loss: 0.1226 - accuracy: 0.9389 - 820ms/epoch - 4ms/step
# Epoch 53/200
# 207/207 - 1s - loss: 0.1218 - accuracy: 0.9392 - 803ms/epoch - 4ms/step
# Epoch 54/200
# 207/207 - 1s - loss: 0.1216 - accuracy: 0.9390 - 784ms/epoch - 4ms/step
# Epoch 55/200
# 207/207 - 1s - loss: 0.1217 - accuracy: 0.9397 - 800ms/epoch - 4ms/step
# Epoch 56/200
# 207/207 - 1s - loss: 0.1212 - accuracy: 0.9393 - 705ms/epoch - 3ms/step
# Epoch 57/200
# 207/207 - 1s - loss: 0.1217 - accuracy: 0.9388 - 850ms/epoch - 4ms/step
# Epoch 58/200
# 207/207 - 1s - loss: 0.1210 - accuracy: 0.9395 - 821ms/epoch - 4ms/step
# Epoch 59/200
# 207/207 - 1s - loss: 0.1210 - accuracy: 0.9397 - 825ms/epoch - 4ms/step
# Epoch 60/200
# 207/207 - 1s - loss: 0.1211 - accuracy: 0.9396 - 718ms/epoch - 3ms/step
# Epoch 61/200
# 207/207 - 1s - loss: 0.1204 - accuracy: 0.9400 - 768ms/epoch - 4ms/step
# Epoch 62/200
# 207/207 - 1s - loss: 0.1204 - accuracy: 0.9401 - 813ms/epoch - 4ms/step
# Epoch 63/200
# 207/207 - 1s - loss: 0.1205 - accuracy: 0.9400 - 703ms/epoch - 3ms/step
# Epoch 64/200
# 207/207 - 1s - loss: 0.1204 - accuracy: 0.9401 - 656ms/epoch - 3ms/step
# Epoch 65/200
# 207/207 - 1s - loss: 0.1200 - accuracy: 0.9402 - 753ms/epoch - 4ms/step
# Epoch 66/200
# 207/207 - 1s - loss: 0.1195 - accuracy: 0.9406 - 801ms/epoch - 4ms/step
# Epoch 67/200
# 207/207 - 1s - loss: 0.1198 - accuracy: 0.9405 - 851ms/epoch - 4ms/step
# Epoch 68/200
# 207/207 - 1s - loss: 0.1196 - accuracy: 0.9400 - 822ms/epoch - 4ms/step
# Epoch 69/200
# 207/207 - 1s - loss: 0.1190 - accuracy: 0.9406 - 771ms/epoch - 4ms/step
# Epoch 70/200
# 207/207 - 1s - loss: 0.1187 - accuracy: 0.9407 - 758ms/epoch - 4ms/step
# Epoch 71/200
# 207/207 - 1s - loss: 0.1191 - accuracy: 0.9407 - 764ms/epoch - 4ms/step
# Epoch 72/200
# 207/207 - 1s - loss: 0.1184 - accuracy: 0.9410 - 757ms/epoch - 4ms/step
# Epoch 73/200
# 207/207 - 1s - loss: 0.1189 - accuracy: 0.9401 - 765ms/epoch - 4ms/step
# Epoch 74/200
# 207/207 - 1s - loss: 0.1182 - accuracy: 0.9409 - 786ms/epoch - 4ms/step
# Epoch 75/200
# 207/207 - 1s - loss: 0.1186 - accuracy: 0.9411 - 811ms/epoch - 4ms/step
# Epoch 76/200
# 207/207 - 1s - loss: 0.1182 - accuracy: 0.9411 - 773ms/epoch - 4ms/step
# Epoch 77/200
# 207/207 - 1s - loss: 0.1179 - accuracy: 0.9413 - 754ms/epoch - 4ms/step
# Epoch 78/200
# 207/207 - 1s - loss: 0.1180 - accuracy: 0.9416 - 778ms/epoch - 4ms/step
# Epoch 79/200
# 207/207 - 1s - loss: 0.1178 - accuracy: 0.9411 - 805ms/epoch - 4ms/step
# Epoch 80/200
# 207/207 - 1s - loss: 0.1173 - accuracy: 0.9417 - 806ms/epoch - 4ms/step
# Epoch 81/200
# 207/207 - 1s - loss: 0.1178 - accuracy: 0.9417 - 802ms/epoch - 4ms/step
# Epoch 82/200
# 207/207 - 1s - loss: 0.1174 - accuracy: 0.9418 - 755ms/epoch - 4ms/step
# Epoch 83/200
# 207/207 - 1s - loss: 0.1171 - accuracy: 0.9419 - 726ms/epoch - 4ms/step
# Epoch 84/200
# 207/207 - 1s - loss: 0.1175 - accuracy: 0.9415 - 651ms/epoch - 3ms/step
# Epoch 85/200
# 207/207 - 1s - loss: 0.1163 - accuracy: 0.9425 - 652ms/epoch - 3ms/step
# Epoch 86/200
# 207/207 - 1s - loss: 0.1172 - accuracy: 0.9419 - 658ms/epoch - 3ms/step
# Epoch 87/200
# 207/207 - 1s - loss: 0.1163 - accuracy: 0.9427 - 725ms/epoch - 4ms/step
# Epoch 88/200
# 207/207 - 1s - loss: 0.1165 - accuracy: 0.9422 - 662ms/epoch - 3ms/step
# Epoch 89/200
# 207/207 - 1s - loss: 0.1159 - accuracy: 0.9426 - 645ms/epoch - 3ms/step
# Epoch 90/200
# 207/207 - 1s - loss: 0.1160 - accuracy: 0.9425 - 661ms/epoch - 3ms/step
# Epoch 91/200
# 207/207 - 1s - loss: 0.1161 - accuracy: 0.9423 - 648ms/epoch - 3ms/step
# Epoch 92/200
# 207/207 - 1s - loss: 0.1155 - accuracy: 0.9427 - 755ms/epoch - 4ms/step
# Epoch 93/200
# 207/207 - 1s - loss: 0.1153 - accuracy: 0.9426 - 827ms/epoch - 4ms/step
# Epoch 94/200
# 207/207 - 1s - loss: 0.1150 - accuracy: 0.9429 - 803ms/epoch - 4ms/step
# Epoch 95/200
# 207/207 - 1s - loss: 0.1146 - accuracy: 0.9434 - 753ms/epoch - 4ms/step
# Epoch 96/200
# 207/207 - 1s - loss: 0.1147 - accuracy: 0.9433 - 649ms/epoch - 3ms/step
# Epoch 97/200
# 207/207 - 1s - loss: 0.1146 - accuracy: 0.9431 - 650ms/epoch - 3ms/step
# Epoch 98/200
# 207/207 - 1s - loss: 0.1144 - accuracy: 0.9431 - 653ms/epoch - 3ms/step
# Epoch 99/200
# 207/207 - 1s - loss: 0.1142 - accuracy: 0.9435 - 785ms/epoch - 4ms/step
# Epoch 100/200
# 207/207 - 1s - loss: 0.1140 - accuracy: 0.9435 - 673ms/epoch - 3ms/step
# Epoch 101/200
# 207/207 - 1s - loss: 0.1141 - accuracy: 0.9440 - 750ms/epoch - 4ms/step
# Epoch 102/200
# 207/207 - 1s - loss: 0.1142 - accuracy: 0.9430 - 782ms/epoch - 4ms/step
# Epoch 103/200
# 207/207 - 1s - loss: 0.1142 - accuracy: 0.9430 - 805ms/epoch - 4ms/step
# Epoch 104/200
# 207/207 - 1s - loss: 0.1133 - accuracy: 0.9440 - 705ms/epoch - 3ms/step
# Epoch 105/200
# 207/207 - 1s - loss: 0.1132 - accuracy: 0.9440 - 784ms/epoch - 4ms/step
# Epoch 106/200
# 207/207 - 1s - loss: 0.1133 - accuracy: 0.9439 - 681ms/epoch - 3ms/step
# Epoch 107/200
# 207/207 - 1s - loss: 0.1131 - accuracy: 0.9442 - 715ms/epoch - 3ms/step
# Epoch 108/200
# 207/207 - 1s - loss: 0.1131 - accuracy: 0.9439 - 797ms/epoch - 4ms/step
# Epoch 109/200
# 207/207 - 1s - loss: 0.1127 - accuracy: 0.9446 - 741ms/epoch - 4ms/step
# Epoch 110/200
# 207/207 - 1s - loss: 0.1126 - accuracy: 0.9440 - 825ms/epoch - 4ms/step
# Epoch 111/200
# 207/207 - 1s - loss: 0.1123 - accuracy: 0.9442 - 906ms/epoch - 4ms/step
# Epoch 112/200
# 207/207 - 1s - loss: 0.1123 - accuracy: 0.9447 - 969ms/epoch - 5ms/step
# Epoch 113/200
# 207/207 - 1s - loss: 0.1122 - accuracy: 0.9441 - 838ms/epoch - 4ms/step
# Epoch 114/200
# 207/207 - 1s - loss: 0.1119 - accuracy: 0.9448 - 885ms/epoch - 4ms/step
# Epoch 115/200
# 207/207 - 1s - loss: 0.1114 - accuracy: 0.9452 - 864ms/epoch - 4ms/step
# Epoch 116/200
# 207/207 - 1s - loss: 0.1122 - accuracy: 0.9450 - 762ms/epoch - 4ms/step
# Epoch 117/200
# 207/207 - 1s - loss: 0.1114 - accuracy: 0.9449 - 792ms/epoch - 4ms/step
# Epoch 118/200
# 207/207 - 1s - loss: 0.1114 - accuracy: 0.9449 - 807ms/epoch - 4ms/step
# Epoch 119/200
# 207/207 - 1s - loss: 0.1111 - accuracy: 0.9450 - 796ms/epoch - 4ms/step
# Epoch 120/200
# 207/207 - 1s - loss: 0.1117 - accuracy: 0.9446 - 812ms/epoch - 4ms/step
# Epoch 121/200
# 207/207 - 1s - loss: 0.1107 - accuracy: 0.9454 - 777ms/epoch - 4ms/step
# Epoch 122/200
# 207/207 - 1s - loss: 0.1108 - accuracy: 0.9458 - 788ms/epoch - 4ms/step
# Epoch 123/200
# 207/207 - 1s - loss: 0.1109 - accuracy: 0.9453 - 784ms/epoch - 4ms/step
# Epoch 124/200
# 207/207 - 1s - loss: 0.1098 - accuracy: 0.9460 - 776ms/epoch - 4ms/step
# Epoch 125/200
# 207/207 - 1s - loss: 0.1102 - accuracy: 0.9458 - 773ms/epoch - 4ms/step
# Epoch 126/200
# 207/207 - 1s - loss: 0.1100 - accuracy: 0.9458 - 761ms/epoch - 4ms/step
# Epoch 127/200
# 207/207 - 1s - loss: 0.1098 - accuracy: 0.9454 - 764ms/epoch - 4ms/step
# Epoch 128/200
# 207/207 - 1s - loss: 0.1094 - accuracy: 0.9461 - 795ms/epoch - 4ms/step
# Epoch 129/200
# 207/207 - 1s - loss: 0.1098 - accuracy: 0.9460 - 758ms/epoch - 4ms/step
# Epoch 130/200
# 207/207 - 1s - loss: 0.1094 - accuracy: 0.9461 - 756ms/epoch - 4ms/step
# Epoch 131/200
# 207/207 - 1s - loss: 0.1093 - accuracy: 0.9460 - 768ms/epoch - 4ms/step
# Epoch 132/200
# 207/207 - 1s - loss: 0.1087 - accuracy: 0.9466 - 786ms/epoch - 4ms/step
# Epoch 133/200
# 207/207 - 1s - loss: 0.1087 - accuracy: 0.9465 - 774ms/epoch - 4ms/step
# Epoch 134/200
# 207/207 - 1s - loss: 0.1087 - accuracy: 0.9461 - 777ms/epoch - 4ms/step
# Epoch 135/200
# 207/207 - 1s - loss: 0.1083 - accuracy: 0.9470 - 757ms/epoch - 4ms/step
# Epoch 136/200
# 207/207 - 1s - loss: 0.1086 - accuracy: 0.9467 - 772ms/epoch - 4ms/step
# Epoch 137/200
# 207/207 - 1s - loss: 0.1080 - accuracy: 0.9469 - 776ms/epoch - 4ms/step
# Epoch 138/200
# 207/207 - 1s - loss: 0.1087 - accuracy: 0.9466 - 767ms/epoch - 4ms/step
# Epoch 139/200
# 207/207 - 1s - loss: 0.1079 - accuracy: 0.9469 - 758ms/epoch - 4ms/step
# Epoch 140/200
# 207/207 - 1s - loss: 0.1076 - accuracy: 0.9471 - 781ms/epoch - 4ms/step
# Epoch 141/200
# 207/207 - 1s - loss: 0.1078 - accuracy: 0.9468 - 855ms/epoch - 4ms/step
# Epoch 142/200
# 207/207 - 1s - loss: 0.1072 - accuracy: 0.9475 - 829ms/epoch - 4ms/step
# Epoch 143/200
# 207/207 - 1s - loss: 0.1072 - accuracy: 0.9471 - 676ms/epoch - 3ms/step
# Epoch 144/200
# 207/207 - 1s - loss: 0.1072 - accuracy: 0.9474 - 833ms/epoch - 4ms/step
# Epoch 145/200
# 207/207 - 1s - loss: 0.1065 - accuracy: 0.9474 - 786ms/epoch - 4ms/step
# Epoch 146/200
# 207/207 - 1s - loss: 0.1070 - accuracy: 0.9476 - 848ms/epoch - 4ms/step
# Epoch 147/200
# 207/207 - 1s - loss: 0.1070 - accuracy: 0.9476 - 736ms/epoch - 4ms/step
# Epoch 148/200
# 207/207 - 1s - loss: 0.1063 - accuracy: 0.9479 - 705ms/epoch - 3ms/step
# Epoch 149/200
# 207/207 - 1s - loss: 0.1063 - accuracy: 0.9481 - 683ms/epoch - 3ms/step
# Epoch 150/200
# 207/207 - 1s - loss: 0.1060 - accuracy: 0.9481 - 687ms/epoch - 3ms/step
# Epoch 151/200
# 207/207 - 1s - loss: 0.1055 - accuracy: 0.9484 - 765ms/epoch - 4ms/step
# Epoch 152/200
# 207/207 - 1s - loss: 0.1058 - accuracy: 0.9481 - 697ms/epoch - 3ms/step
# Epoch 153/200
# 207/207 - 1s - loss: 0.1061 - accuracy: 0.9481 - 676ms/epoch - 3ms/step
# Epoch 154/200
# 207/207 - 1s - loss: 0.1057 - accuracy: 0.9484 - 675ms/epoch - 3ms/step
# Epoch 155/200
# 207/207 - 1s - loss: 0.1052 - accuracy: 0.9489 - 673ms/epoch - 3ms/step
# Epoch 156/200
# 207/207 - 1s - loss: 0.1054 - accuracy: 0.9484 - 667ms/epoch - 3ms/step
# Epoch 157/200
# 207/207 - 1s - loss: 0.1049 - accuracy: 0.9488 - 705ms/epoch - 3ms/step
# Epoch 158/200
# 207/207 - 1s - loss: 0.1051 - accuracy: 0.9485 - 726ms/epoch - 4ms/step
# Epoch 159/200
# 207/207 - 1s - loss: 0.1052 - accuracy: 0.9486 - 689ms/epoch - 3ms/step
# Epoch 160/200
# 207/207 - 1s - loss: 0.1046 - accuracy: 0.9490 - 686ms/epoch - 3ms/step
# Epoch 161/200
# 207/207 - 1s - loss: 0.1046 - accuracy: 0.9490 - 677ms/epoch - 3ms/step
# Epoch 162/200
# 207/207 - 1s - loss: 0.1042 - accuracy: 0.9491 - 676ms/epoch - 3ms/step
# Epoch 163/200
# 207/207 - 1s - loss: 0.1045 - accuracy: 0.9495 - 691ms/epoch - 3ms/step
# Epoch 164/200
# 207/207 - 1s - loss: 0.1037 - accuracy: 0.9491 - 733ms/epoch - 4ms/step
# Epoch 165/200
# 207/207 - 1s - loss: 0.1039 - accuracy: 0.9493 - 682ms/epoch - 3ms/step
# Epoch 166/200
# 207/207 - 1s - loss: 0.1036 - accuracy: 0.9493 - 674ms/epoch - 3ms/step
# Epoch 167/200
# 207/207 - 1s - loss: 0.1033 - accuracy: 0.9492 - 666ms/epoch - 3ms/step
# Epoch 168/200
# 207/207 - 1s - loss: 0.1031 - accuracy: 0.9497 - 682ms/epoch - 3ms/step
# Epoch 169/200
# 207/207 - 1s - loss: 0.1032 - accuracy: 0.9493 - 672ms/epoch - 3ms/step
# Epoch 170/200
# 207/207 - 1s - loss: 0.1029 - accuracy: 0.9499 - 675ms/epoch - 3ms/step
# Epoch 171/200
# 207/207 - 1s - loss: 0.1033 - accuracy: 0.9492 - 768ms/epoch - 4ms/step
# Epoch 172/200
# 207/207 - 1s - loss: 0.1029 - accuracy: 0.9498 - 792ms/epoch - 4ms/step
# Epoch 173/200
# 207/207 - 1s - loss: 0.1029 - accuracy: 0.9498 - 692ms/epoch - 3ms/step
# Epoch 174/200
# 207/207 - 1s - loss: 0.1031 - accuracy: 0.9496 - 715ms/epoch - 3ms/step
# Epoch 175/200
# 207/207 - 1s - loss: 0.1025 - accuracy: 0.9507 - 734ms/epoch - 4ms/step
# Epoch 176/200
# 207/207 - 1s - loss: 0.1023 - accuracy: 0.9503 - 706ms/epoch - 3ms/step
# Epoch 177/200
# 207/207 - 1s - loss: 0.1022 - accuracy: 0.9503 - 702ms/epoch - 3ms/step
# Epoch 178/200
# 207/207 - 1s - loss: 0.1023 - accuracy: 0.9501 - 725ms/epoch - 4ms/step
# Epoch 179/200
# 207/207 - 1s - loss: 0.1022 - accuracy: 0.9503 - 730ms/epoch - 4ms/step
# Epoch 180/200
# 207/207 - 1s - loss: 0.1015 - accuracy: 0.9509 - 643ms/epoch - 3ms/step
# Epoch 181/200
# 207/207 - 1s - loss: 0.1019 - accuracy: 0.9506 - 648ms/epoch - 3ms/step
# Epoch 182/200
# 207/207 - 1s - loss: 0.1016 - accuracy: 0.9509 - 666ms/epoch - 3ms/step
# Epoch 183/200
# 207/207 - 1s - loss: 0.1009 - accuracy: 0.9509 - 740ms/epoch - 4ms/step
# Epoch 184/200
# 207/207 - 1s - loss: 0.1008 - accuracy: 0.9509 - 674ms/epoch - 3ms/step
# Epoch 185/200
# 207/207 - 1s - loss: 0.1012 - accuracy: 0.9507 - 646ms/epoch - 3ms/step
# Epoch 186/200
# 207/207 - 1s - loss: 0.1008 - accuracy: 0.9516 - 659ms/epoch - 3ms/step
# Epoch 187/200
# 207/207 - 1s - loss: 0.1013 - accuracy: 0.9511 - 639ms/epoch - 3ms/step
# Epoch 188/200
# 207/207 - 1s - loss: 0.1006 - accuracy: 0.9512 - 740ms/epoch - 4ms/step
# Epoch 189/200
# 207/207 - 1s - loss: 0.1005 - accuracy: 0.9512 - 748ms/epoch - 4ms/step
# Epoch 190/200
# 207/207 - 1s - loss: 0.1007 - accuracy: 0.9511 - 724ms/epoch - 3ms/step
# Epoch 191/200
# 207/207 - 1s - loss: 0.1010 - accuracy: 0.9508 - 692ms/epoch - 3ms/step
# Epoch 192/200
# 207/207 - 1s - loss: 0.1006 - accuracy: 0.9513 - 698ms/epoch - 3ms/step
# Epoch 193/200
# 207/207 - 1s - loss: 0.1001 - accuracy: 0.9513 - 700ms/epoch - 3ms/step
# Epoch 194/200
# 207/207 - 1s - loss: 0.1001 - accuracy: 0.9517 - 685ms/epoch - 3ms/step
# Epoch 195/200
# 207/207 - 1s - loss: 0.1000 - accuracy: 0.9519 - 711ms/epoch - 3ms/step
# Epoch 196/200
# 207/207 - 1s - loss: 0.1000 - accuracy: 0.9517 - 759ms/epoch - 4ms/step
# Epoch 197/200
# 207/207 - 1s - loss: 0.0996 - accuracy: 0.9519 - 713ms/epoch - 3ms/step
# Epoch 198/200
# 207/207 - 1s - loss: 0.0997 - accuracy: 0.9517 - 670ms/epoch - 3ms/step
# Epoch 199/200
# 207/207 - 1s - loss: 0.0993 - accuracy: 0.9520 - 667ms/epoch - 3ms/step
# Epoch 200/200
# 207/207 - 1s - loss: 0.0991 - accuracy: 0.9519 - 680ms/epoch - 3ms/step
# 1611/1611 [==============================] - 3s 2ms/step
# Modell: ConvolutionalAutoencoder_6
# Genauigkeit: 0.9428349665276026
# Recall: 0.9428349665276026
# Precision: 0.9433470937639221
# F1 Score: 0.9429960388682064

# %%
results = append_model_reults(model_conv_autoencoder, results, end_train - start, end_predict - end_train, accuracy, recall, precision, f1)

# %% [markdown]
# #### 4.2.6 Sparse Autoencoder

# %%
# SparseAutoencoder_1: SPARSITY_WEIGHT = 0.01
# SparseAutoencoder_2: SPARSITY_WEIGHT = 1
# SparseAutoencoder_3: SPARSITY_WEIGHT = 0.1
# SparseAutoencoder_4: SPARSITY_WEIGHT = 0.001
# SparseAutoencoder_5: SPARSITY_WEIGHT = 0.0001
# SparseAutoencoder_6: SPARSITY_WEIGHT = 0.0001 + Autoencoder 12 design

# %%
# SparseAutoencoder_6:
class SparseAutoencoder(Model):
    def __init__(self, name="SparseAutoencoder"):
        super(SparseAutoencoder, self).__init__(name=name)
        self.encoder = tf.keras.Sequential([
            layers.Dense(256, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(128, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),],
            name="encoder")
        
        self.decoder = tf.keras.Sequential([
            layers.Dense(128, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(TOTAL_FEATURES, activation="sigmoid")],
            name="decoder")

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

model_sparse = SparseAutoencoder(name=MODEL_NAME)
opt = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# model_sparse.compile(optimizer=opt, loss="mse")
model_sparse.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
class SparseAutoencoder(Model):
    def __init__(self, name="SparseAutoencoder"):
        super(SparseAutoencoder, self).__init__(name=name)
        self.encoder = tf.keras.Sequential([
            layers.Dense(256, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(128, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(64, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(32, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(16, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT))],
            name="encoder")
        
        self.decoder = tf.keras.Sequential([
            layers.Dense(32, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(64, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(128, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(256, activation="relu", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT)),
            layers.Dense(TOTAL_FEATURES, activation="sigmoid", activity_regularizer=tf.keras.regularizers.l1(SPARSITY_WEIGHT))],
            name="decoder")

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

model_sparse = SparseAutoencoder(name=MODEL_NAME)
opt = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# model_sparse.compile(optimizer=opt, loss="mse")
model_sparse.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
start = time.time()
history = model_sparse.fit(X_train_reshaped, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2) # Training model
#history = model_sparse.fit(X_train_reshaped, X_train_reshaped, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_test_reshaped, X_test_reshaped))
end_train = time.time()
accuracy, recall, precision, f1, end_predict = evaluate_model(model_sparse, X_test_reshaped, y_test, True) # Testing model
# Out:
# Epoch 1/200
# 207/207 - 3s - loss: 0.4332 - accuracy: 0.7467 - 3s/epoch - 17ms/step
# Epoch 2/200
# 207/207 - 2s - loss: 0.1799 - accuracy: 0.9225 - 2s/epoch - 9ms/step
# Epoch 3/200
# 207/207 - 2s - loss: 0.1598 - accuracy: 0.9273 - 2s/epoch - 9ms/step
# Epoch 4/200
# 207/207 - 2s - loss: 0.1501 - accuracy: 0.9303 - 2s/epoch - 10ms/step
# Epoch 5/200
# 207/207 - 2s - loss: 0.1460 - accuracy: 0.9308 - 2s/epoch - 9ms/step
# Epoch 6/200
# 207/207 - 2s - loss: 0.1414 - accuracy: 0.9331 - 2s/epoch - 9ms/step
# Epoch 7/200
# 207/207 - 2s - loss: 0.1386 - accuracy: 0.9341 - 2s/epoch - 10ms/step
# Epoch 8/200
# 207/207 - 2s - loss: 0.1381 - accuracy: 0.9335 - 2s/epoch - 10ms/step
# Epoch 9/200
# 207/207 - 2s - loss: 0.1355 - accuracy: 0.9347 - 2s/epoch - 10ms/step
# Epoch 10/200
# 207/207 - 2s - loss: 0.1334 - accuracy: 0.9352 - 2s/epoch - 10ms/step
# Epoch 11/200
# 207/207 - 2s - loss: 0.1331 - accuracy: 0.9360 - 2s/epoch - 9ms/step
# Epoch 12/200
# 207/207 - 2s - loss: 0.1318 - accuracy: 0.9361 - 2s/epoch - 9ms/step
# Epoch 13/200
# 207/207 - 2s - loss: 0.1320 - accuracy: 0.9351 - 2s/epoch - 9ms/step
# Epoch 14/200
# 207/207 - 2s - loss: 0.1302 - accuracy: 0.9363 - 2s/epoch - 10ms/step
# Epoch 15/200
# 207/207 - 2s - loss: 0.1292 - accuracy: 0.9368 - 2s/epoch - 9ms/step
# Epoch 16/200
# 207/207 - 2s - loss: 0.1292 - accuracy: 0.9371 - 2s/epoch - 8ms/step
# Epoch 17/200
# 207/207 - 2s - loss: 0.1276 - accuracy: 0.9378 - 2s/epoch - 9ms/step
# Epoch 18/200
# 207/207 - 2s - loss: 0.1278 - accuracy: 0.9372 - 2s/epoch - 10ms/step
# Epoch 19/200
# 207/207 - 2s - loss: 0.1268 - accuracy: 0.9382 - 2s/epoch - 9ms/step
# Epoch 20/200
# 207/207 - 2s - loss: 0.1278 - accuracy: 0.9374 - 2s/epoch - 10ms/step
# Epoch 21/200
# 207/207 - 2s - loss: 0.1258 - accuracy: 0.9387 - 2s/epoch - 10ms/step
# Epoch 22/200
# 207/207 - 2s - loss: 0.1247 - accuracy: 0.9391 - 2s/epoch - 10ms/step
# Epoch 23/200
# 207/207 - 2s - loss: 0.1245 - accuracy: 0.9389 - 2s/epoch - 9ms/step
# Epoch 24/200
# 207/207 - 2s - loss: 0.1238 - accuracy: 0.9394 - 2s/epoch - 9ms/step
# Epoch 25/200
# 207/207 - 2s - loss: 0.1236 - accuracy: 0.9392 - 2s/epoch - 9ms/step
# Epoch 26/200
# 207/207 - 2s - loss: 0.1231 - accuracy: 0.9398 - 2s/epoch - 9ms/step
# Epoch 27/200
# 207/207 - 2s - loss: 0.1230 - accuracy: 0.9397 - 2s/epoch - 9ms/step
# Epoch 28/200
# 207/207 - 2s - loss: 0.1227 - accuracy: 0.9397 - 2s/epoch - 9ms/step
# Epoch 29/200
# 207/207 - 2s - loss: 0.1214 - accuracy: 0.9403 - 2s/epoch - 9ms/step
# Epoch 30/200
# 207/207 - 2s - loss: 0.1214 - accuracy: 0.9396 - 2s/epoch - 9ms/step
# Epoch 31/200
# 207/207 - 2s - loss: 0.1212 - accuracy: 0.9406 - 2s/epoch - 9ms/step
# Epoch 32/200
# 207/207 - 2s - loss: 0.1195 - accuracy: 0.9414 - 2s/epoch - 9ms/step
# Epoch 33/200
# 207/207 - 2s - loss: 0.1199 - accuracy: 0.9416 - 2s/epoch - 9ms/step
# Epoch 34/200
# 207/207 - 2s - loss: 0.1189 - accuracy: 0.9419 - 2s/epoch - 9ms/step
# Epoch 35/200
# 207/207 - 2s - loss: 0.1186 - accuracy: 0.9422 - 2s/epoch - 9ms/step
# Epoch 36/200
# 207/207 - 2s - loss: 0.1185 - accuracy: 0.9416 - 2s/epoch - 8ms/step
# Epoch 37/200
# 207/207 - 2s - loss: 0.1184 - accuracy: 0.9422 - 2s/epoch - 9ms/step
# Epoch 38/200
# 207/207 - 2s - loss: 0.1169 - accuracy: 0.9426 - 2s/epoch - 8ms/step
# Epoch 39/200
# 207/207 - 2s - loss: 0.1177 - accuracy: 0.9423 - 2s/epoch - 9ms/step
# Epoch 40/200
# 207/207 - 2s - loss: 0.1171 - accuracy: 0.9430 - 2s/epoch - 8ms/step
# Epoch 41/200
# 207/207 - 2s - loss: 0.1156 - accuracy: 0.9435 - 2s/epoch - 8ms/step
# Epoch 42/200
# 207/207 - 2s - loss: 0.1147 - accuracy: 0.9439 - 2s/epoch - 9ms/step
# Epoch 43/200
# 207/207 - 2s - loss: 0.1160 - accuracy: 0.9432 - 2s/epoch - 8ms/step
# Epoch 44/200
# 207/207 - 2s - loss: 0.1155 - accuracy: 0.9434 - 2s/epoch - 9ms/step
# Epoch 45/200
# 207/207 - 2s - loss: 0.1145 - accuracy: 0.9438 - 2s/epoch - 9ms/step
# Epoch 46/200
# 207/207 - 2s - loss: 0.1148 - accuracy: 0.9438 - 2s/epoch - 9ms/step
# Epoch 47/200
# 207/207 - 2s - loss: 0.1156 - accuracy: 0.9434 - 2s/epoch - 9ms/step
# Epoch 48/200
# 207/207 - 2s - loss: 0.1138 - accuracy: 0.9446 - 2s/epoch - 9ms/step
# Epoch 49/200
# 207/207 - 2s - loss: 0.1143 - accuracy: 0.9444 - 2s/epoch - 9ms/step
# Epoch 50/200
# 207/207 - 2s - loss: 0.1133 - accuracy: 0.9447 - 2s/epoch - 9ms/step
# Epoch 51/200
# 207/207 - 2s - loss: 0.1124 - accuracy: 0.9452 - 2s/epoch - 9ms/step
# Epoch 52/200
# 207/207 - 2s - loss: 0.1122 - accuracy: 0.9452 - 2s/epoch - 9ms/step
# Epoch 53/200
# 207/207 - 2s - loss: 0.1124 - accuracy: 0.9450 - 2s/epoch - 9ms/step
# Epoch 54/200
# 207/207 - 2s - loss: 0.1125 - accuracy: 0.9452 - 2s/epoch - 9ms/step
# Epoch 55/200
# 207/207 - 2s - loss: 0.1122 - accuracy: 0.9451 - 2s/epoch - 9ms/step
# Epoch 56/200
# 207/207 - 2s - loss: 0.1116 - accuracy: 0.9458 - 2s/epoch - 9ms/step
# Epoch 57/200
# 207/207 - 2s - loss: 0.1107 - accuracy: 0.9460 - 2s/epoch - 9ms/step
# Epoch 58/200
# 207/207 - 2s - loss: 0.1108 - accuracy: 0.9461 - 2s/epoch - 9ms/step
# Epoch 59/200
# 207/207 - 2s - loss: 0.1114 - accuracy: 0.9461 - 2s/epoch - 9ms/step
# Epoch 60/200
# 207/207 - 2s - loss: 0.1112 - accuracy: 0.9457 - 2s/epoch - 9ms/step
# Epoch 61/200
# 207/207 - 2s - loss: 0.1107 - accuracy: 0.9463 - 2s/epoch - 9ms/step
# Epoch 62/200
# 207/207 - 2s - loss: 0.1109 - accuracy: 0.9465 - 2s/epoch - 9ms/step
# Epoch 63/200
# 207/207 - 2s - loss: 0.1095 - accuracy: 0.9473 - 2s/epoch - 8ms/step
# Epoch 64/200
# 207/207 - 2s - loss: 0.1099 - accuracy: 0.9464 - 2s/epoch - 9ms/step
# Epoch 65/200
# 207/207 - 2s - loss: 0.1095 - accuracy: 0.9466 - 2s/epoch - 9ms/step
# Epoch 66/200
# 207/207 - 2s - loss: 0.1089 - accuracy: 0.9471 - 2s/epoch - 8ms/step
# Epoch 67/200
# 207/207 - 2s - loss: 0.1092 - accuracy: 0.9469 - 2s/epoch - 9ms/step
# Epoch 68/200
# 207/207 - 2s - loss: 0.1092 - accuracy: 0.9469 - 2s/epoch - 8ms/step
# Epoch 69/200
# 207/207 - 2s - loss: 0.1076 - accuracy: 0.9478 - 2s/epoch - 9ms/step
# Epoch 70/200
# 207/207 - 2s - loss: 0.1083 - accuracy: 0.9474 - 2s/epoch - 9ms/step
# Epoch 71/200
# 207/207 - 2s - loss: 0.1076 - accuracy: 0.9476 - 2s/epoch - 8ms/step
# Epoch 72/200
# 207/207 - 2s - loss: 0.1068 - accuracy: 0.9484 - 2s/epoch - 9ms/step
# Epoch 73/200
# 207/207 - 2s - loss: 0.1081 - accuracy: 0.9474 - 2s/epoch - 9ms/step
# Epoch 74/200
# 207/207 - 2s - loss: 0.1074 - accuracy: 0.9481 - 2s/epoch - 9ms/step
# Epoch 75/200
# 207/207 - 2s - loss: 0.1080 - accuracy: 0.9474 - 2s/epoch - 9ms/step
# Epoch 76/200
# 207/207 - 2s - loss: 0.1063 - accuracy: 0.9487 - 2s/epoch - 9ms/step
# Epoch 77/200
# 207/207 - 2s - loss: 0.1069 - accuracy: 0.9481 - 2s/epoch - 9ms/step
# Epoch 78/200
# 207/207 - 2s - loss: 0.1058 - accuracy: 0.9484 - 2s/epoch - 9ms/step
# Epoch 79/200
# 207/207 - 2s - loss: 0.1072 - accuracy: 0.9479 - 2s/epoch - 9ms/step
# Epoch 80/200
# 207/207 - 2s - loss: 0.1068 - accuracy: 0.9487 - 2s/epoch - 9ms/step
# Epoch 81/200
# 207/207 - 2s - loss: 0.1059 - accuracy: 0.9490 - 2s/epoch - 9ms/step
# Epoch 82/200
# 207/207 - 2s - loss: 0.1052 - accuracy: 0.9492 - 2s/epoch - 9ms/step
# Epoch 83/200
# 207/207 - 2s - loss: 0.1066 - accuracy: 0.9483 - 2s/epoch - 9ms/step
# Epoch 84/200
# 207/207 - 2s - loss: 0.1057 - accuracy: 0.9492 - 2s/epoch - 9ms/step
# Epoch 85/200
# 207/207 - 2s - loss: 0.1047 - accuracy: 0.9492 - 2s/epoch - 9ms/step
# Epoch 86/200
# 207/207 - 2s - loss: 0.1047 - accuracy: 0.9495 - 2s/epoch - 9ms/step
# Epoch 87/200
# 207/207 - 2s - loss: 0.1043 - accuracy: 0.9496 - 2s/epoch - 9ms/step
# Epoch 88/200
# 207/207 - 2s - loss: 0.1038 - accuracy: 0.9495 - 2s/epoch - 9ms/step
# Epoch 89/200
# 207/207 - 2s - loss: 0.1038 - accuracy: 0.9498 - 2s/epoch - 9ms/step
# Epoch 90/200
# 207/207 - 2s - loss: 0.1035 - accuracy: 0.9501 - 2s/epoch - 9ms/step
# Epoch 91/200
# 207/207 - 2s - loss: 0.1032 - accuracy: 0.9500 - 2s/epoch - 9ms/step
# Epoch 92/200
# 207/207 - 2s - loss: 0.1029 - accuracy: 0.9506 - 2s/epoch - 9ms/step
# Epoch 93/200
# 207/207 - 2s - loss: 0.1027 - accuracy: 0.9506 - 2s/epoch - 9ms/step
# Epoch 94/200
# 207/207 - 2s - loss: 0.1035 - accuracy: 0.9501 - 2s/epoch - 9ms/step
# Epoch 95/200
# 207/207 - 2s - loss: 0.1044 - accuracy: 0.9497 - 2s/epoch - 9ms/step
# Epoch 96/200
# 207/207 - 2s - loss: 0.1028 - accuracy: 0.9504 - 2s/epoch - 9ms/step
# Epoch 97/200
# 207/207 - 2s - loss: 0.1032 - accuracy: 0.9500 - 2s/epoch - 9ms/step
# Epoch 98/200
# 207/207 - 2s - loss: 0.1036 - accuracy: 0.9501 - 2s/epoch - 9ms/step
# Epoch 99/200
# 207/207 - 2s - loss: 0.1016 - accuracy: 0.9510 - 2s/epoch - 9ms/step
# Epoch 100/200
# 207/207 - 2s - loss: 0.1026 - accuracy: 0.9502 - 2s/epoch - 9ms/step
# Epoch 101/200
# 207/207 - 2s - loss: 0.1017 - accuracy: 0.9508 - 2s/epoch - 9ms/step
# Epoch 102/200
# 207/207 - 2s - loss: 0.1023 - accuracy: 0.9508 - 2s/epoch - 9ms/step
# Epoch 103/200
# 207/207 - 2s - loss: 0.1014 - accuracy: 0.9510 - 2s/epoch - 9ms/step
# Epoch 104/200
# 207/207 - 2s - loss: 0.1010 - accuracy: 0.9516 - 2s/epoch - 9ms/step
# Epoch 105/200
# 207/207 - 2s - loss: 0.1008 - accuracy: 0.9513 - 2s/epoch - 9ms/step
# Epoch 106/200
# 207/207 - 2s - loss: 0.1018 - accuracy: 0.9512 - 2s/epoch - 9ms/step
# Epoch 107/200
# 207/207 - 2s - loss: 0.1003 - accuracy: 0.9515 - 2s/epoch - 9ms/step
# Epoch 108/200
# 207/207 - 2s - loss: 0.1007 - accuracy: 0.9514 - 2s/epoch - 9ms/step
# Epoch 109/200
# 207/207 - 2s - loss: 0.0999 - accuracy: 0.9522 - 2s/epoch - 9ms/step
# Epoch 110/200
# 207/207 - 2s - loss: 0.0994 - accuracy: 0.9520 - 2s/epoch - 9ms/step
# Epoch 111/200
# 207/207 - 2s - loss: 0.0996 - accuracy: 0.9517 - 2s/epoch - 9ms/step
# Epoch 112/200
# 207/207 - 2s - loss: 0.1002 - accuracy: 0.9521 - 2s/epoch - 9ms/step
# Epoch 113/200
# 207/207 - 2s - loss: 0.0998 - accuracy: 0.9523 - 2s/epoch - 9ms/step
# Epoch 114/200
# 207/207 - 2s - loss: 0.0994 - accuracy: 0.9527 - 2s/epoch - 9ms/step
# Epoch 115/200
# 207/207 - 2s - loss: 0.0988 - accuracy: 0.9529 - 2s/epoch - 8ms/step
# Epoch 116/200
# 207/207 - 2s - loss: 0.0993 - accuracy: 0.9525 - 2s/epoch - 8ms/step
# Epoch 117/200
# 207/207 - 2s - loss: 0.0996 - accuracy: 0.9521 - 2s/epoch - 9ms/step
# Epoch 118/200
# 207/207 - 2s - loss: 0.0982 - accuracy: 0.9526 - 2s/epoch - 9ms/step
# Epoch 119/200
# 207/207 - 2s - loss: 0.0981 - accuracy: 0.9530 - 2s/epoch - 9ms/step
# Epoch 120/200
# 207/207 - 2s - loss: 0.1001 - accuracy: 0.9525 - 2s/epoch - 9ms/step
# Epoch 121/200
# 207/207 - 2s - loss: 0.0998 - accuracy: 0.9518 - 2s/epoch - 8ms/step
# Epoch 122/200
# 207/207 - 2s - loss: 0.0979 - accuracy: 0.9531 - 2s/epoch - 9ms/step
# Epoch 123/200
# 207/207 - 2s - loss: 0.0982 - accuracy: 0.9529 - 2s/epoch - 8ms/step
# Epoch 124/200
# 207/207 - 2s - loss: 0.0978 - accuracy: 0.9535 - 2s/epoch - 9ms/step
# Epoch 125/200
# 207/207 - 2s - loss: 0.0976 - accuracy: 0.9533 - 2s/epoch - 8ms/step
# Epoch 126/200
# 207/207 - 2s - loss: 0.0972 - accuracy: 0.9531 - 2s/epoch - 8ms/step
# Epoch 127/200
# 207/207 - 2s - loss: 0.0968 - accuracy: 0.9536 - 2s/epoch - 9ms/step
# Epoch 128/200
# 207/207 - 2s - loss: 0.0989 - accuracy: 0.9526 - 2s/epoch - 8ms/step
# Epoch 129/200
# 207/207 - 2s - loss: 0.0961 - accuracy: 0.9535 - 2s/epoch - 8ms/step
# Epoch 130/200
# 207/207 - 2s - loss: 0.0959 - accuracy: 0.9540 - 2s/epoch - 9ms/step
# Epoch 131/200
# 207/207 - 2s - loss: 0.0969 - accuracy: 0.9537 - 2s/epoch - 9ms/step
# Epoch 132/200
# 207/207 - 2s - loss: 0.0968 - accuracy: 0.9536 - 2s/epoch - 9ms/step
# Epoch 133/200
# 207/207 - 2s - loss: 0.0960 - accuracy: 0.9541 - 2s/epoch - 9ms/step
# Epoch 134/200
# 207/207 - 2s - loss: 0.0955 - accuracy: 0.9541 - 2s/epoch - 9ms/step
# Epoch 135/200
# 207/207 - 2s - loss: 0.0958 - accuracy: 0.9540 - 2s/epoch - 9ms/step
# Epoch 136/200
# 207/207 - 2s - loss: 0.0954 - accuracy: 0.9545 - 2s/epoch - 8ms/step
# Epoch 137/200
# 207/207 - 2s - loss: 0.0957 - accuracy: 0.9543 - 2s/epoch - 9ms/step
# Epoch 138/200
# 207/207 - 2s - loss: 0.0959 - accuracy: 0.9538 - 2s/epoch - 8ms/step
# Epoch 139/200
# 207/207 - 2s - loss: 0.0973 - accuracy: 0.9537 - 2s/epoch - 8ms/step
# Epoch 140/200
# 207/207 - 2s - loss: 0.0959 - accuracy: 0.9543 - 2s/epoch - 9ms/step
# Epoch 141/200
# 207/207 - 2s - loss: 0.0946 - accuracy: 0.9545 - 2s/epoch - 9ms/step
# Epoch 142/200
# 207/207 - 2s - loss: 0.0948 - accuracy: 0.9547 - 2s/epoch - 9ms/step
# Epoch 143/200
# 207/207 - 2s - loss: 0.0952 - accuracy: 0.9546 - 2s/epoch - 9ms/step
# Epoch 144/200
# 207/207 - 2s - loss: 0.0942 - accuracy: 0.9549 - 2s/epoch - 9ms/step
# Epoch 145/200
# 207/207 - 2s - loss: 0.0946 - accuracy: 0.9547 - 2s/epoch - 9ms/step
# Epoch 146/200
# 207/207 - 2s - loss: 0.0940 - accuracy: 0.9549 - 2s/epoch - 8ms/step
# Epoch 147/200
# 207/207 - 2s - loss: 0.0938 - accuracy: 0.9553 - 2s/epoch - 9ms/step
# Epoch 148/200
# 207/207 - 2s - loss: 0.0931 - accuracy: 0.9558 - 2s/epoch - 9ms/step
# Epoch 149/200
# 207/207 - 2s - loss: 0.0932 - accuracy: 0.9557 - 2s/epoch - 9ms/step
# Epoch 150/200
# 207/207 - 2s - loss: 0.0934 - accuracy: 0.9558 - 2s/epoch - 9ms/step
# Epoch 151/200
# 207/207 - 2s - loss: 0.0932 - accuracy: 0.9558 - 2s/epoch - 9ms/step
# Epoch 152/200
# 207/207 - 2s - loss: 0.0930 - accuracy: 0.9556 - 2s/epoch - 9ms/step
# Epoch 153/200
# 207/207 - 2s - loss: 0.0927 - accuracy: 0.9557 - 2s/epoch - 9ms/step
# Epoch 154/200
# 207/207 - 2s - loss: 0.0937 - accuracy: 0.9554 - 2s/epoch - 9ms/step
# Epoch 155/200
# 207/207 - 2s - loss: 0.0930 - accuracy: 0.9558 - 2s/epoch - 9ms/step
# Epoch 156/200
# 207/207 - 2s - loss: 0.0934 - accuracy: 0.9556 - 2s/epoch - 9ms/step
# Epoch 157/200
# 207/207 - 2s - loss: 0.0926 - accuracy: 0.9559 - 2s/epoch - 9ms/step
# Epoch 158/200
# 207/207 - 2s - loss: 0.0928 - accuracy: 0.9562 - 2s/epoch - 9ms/step
# Epoch 159/200
# 207/207 - 2s - loss: 0.0923 - accuracy: 0.9560 - 2s/epoch - 9ms/step
# Epoch 160/200
# 207/207 - 2s - loss: 0.0918 - accuracy: 0.9561 - 2s/epoch - 9ms/step
# Epoch 161/200
# 207/207 - 2s - loss: 0.0922 - accuracy: 0.9560 - 2s/epoch - 9ms/step
# Epoch 162/200
# 207/207 - 2s - loss: 0.0917 - accuracy: 0.9559 - 2s/epoch - 9ms/step
# Epoch 163/200
# 207/207 - 2s - loss: 0.0907 - accuracy: 0.9565 - 2s/epoch - 9ms/step
# Epoch 164/200
# 207/207 - 2s - loss: 0.0911 - accuracy: 0.9566 - 2s/epoch - 9ms/step
# Epoch 165/200
# 207/207 - 2s - loss: 0.0913 - accuracy: 0.9568 - 2s/epoch - 9ms/step
# Epoch 166/200
# 207/207 - 2s - loss: 0.0909 - accuracy: 0.9569 - 2s/epoch - 9ms/step
# Epoch 167/200
# 207/207 - 2s - loss: 0.0915 - accuracy: 0.9570 - 2s/epoch - 9ms/step
# Epoch 168/200
# 207/207 - 2s - loss: 0.0901 - accuracy: 0.9573 - 2s/epoch - 9ms/step
# Epoch 169/200
# 207/207 - 2s - loss: 0.0900 - accuracy: 0.9570 - 2s/epoch - 9ms/step
# Epoch 170/200
# 207/207 - 2s - loss: 0.0928 - accuracy: 0.9560 - 2s/epoch - 9ms/step
# Epoch 171/200
# 207/207 - 2s - loss: 0.0911 - accuracy: 0.9570 - 2s/epoch - 9ms/step
# Epoch 172/200
# 207/207 - 2s - loss: 0.0902 - accuracy: 0.9573 - 2s/epoch - 9ms/step
# Epoch 173/200
# 207/207 - 2s - loss: 0.0891 - accuracy: 0.9578 - 2s/epoch - 9ms/step
# Epoch 174/200
# 207/207 - 2s - loss: 0.0896 - accuracy: 0.9574 - 2s/epoch - 9ms/step
# Epoch 175/200
# 207/207 - 2s - loss: 0.0917 - accuracy: 0.9566 - 2s/epoch - 9ms/step
# Epoch 176/200
# 207/207 - 2s - loss: 0.0891 - accuracy: 0.9575 - 2s/epoch - 8ms/step
# Epoch 177/200
# 207/207 - 2s - loss: 0.0892 - accuracy: 0.9581 - 2s/epoch - 9ms/step
# Epoch 178/200
# 207/207 - 2s - loss: 0.0894 - accuracy: 0.9579 - 2s/epoch - 9ms/step
# Epoch 179/200
# 207/207 - 2s - loss: 0.0880 - accuracy: 0.9582 - 2s/epoch - 9ms/step
# Epoch 180/200
# 207/207 - 2s - loss: 0.0884 - accuracy: 0.9584 - 2s/epoch - 9ms/step
# Epoch 181/200
# 207/207 - 2s - loss: 0.0893 - accuracy: 0.9572 - 2s/epoch - 9ms/step
# Epoch 182/200
# 207/207 - 2s - loss: 0.0885 - accuracy: 0.9578 - 2s/epoch - 9ms/step
# Epoch 183/200
# 207/207 - 2s - loss: 0.0888 - accuracy: 0.9579 - 2s/epoch - 9ms/step
# Epoch 184/200
# 207/207 - 2s - loss: 0.0881 - accuracy: 0.9583 - 2s/epoch - 9ms/step
# Epoch 185/200
# 207/207 - 2s - loss: 0.0888 - accuracy: 0.9577 - 2s/epoch - 9ms/step
# Epoch 186/200
# 207/207 - 2s - loss: 0.0877 - accuracy: 0.9588 - 2s/epoch - 9ms/step
# Epoch 187/200
# 207/207 - 2s - loss: 0.0881 - accuracy: 0.9585 - 2s/epoch - 9ms/step
# Epoch 188/200
# 207/207 - 2s - loss: 0.0878 - accuracy: 0.9584 - 2s/epoch - 9ms/step
# Epoch 189/200
# 207/207 - 2s - loss: 0.0892 - accuracy: 0.9578 - 2s/epoch - 9ms/step
# Epoch 190/200
# 207/207 - 2s - loss: 0.0877 - accuracy: 0.9581 - 2s/epoch - 9ms/step
# Epoch 191/200
# 207/207 - 2s - loss: 0.0875 - accuracy: 0.9585 - 2s/epoch - 9ms/step
# Epoch 192/200
# 207/207 - 2s - loss: 0.0864 - accuracy: 0.9593 - 2s/epoch - 9ms/step
# Epoch 193/200
# 207/207 - 2s - loss: 0.0873 - accuracy: 0.9587 - 2s/epoch - 9ms/step
# Epoch 194/200
# 207/207 - 2s - loss: 0.0869 - accuracy: 0.9590 - 2s/epoch - 9ms/step
# Epoch 195/200
# 207/207 - 2s - loss: 0.0856 - accuracy: 0.9593 - 2s/epoch - 9ms/step
# Epoch 196/200
# 207/207 - 2s - loss: 0.0875 - accuracy: 0.9586 - 2s/epoch - 9ms/step
# Epoch 197/200
# 207/207 - 2s - loss: 0.0859 - accuracy: 0.9595 - 2s/epoch - 9ms/step
# Epoch 198/200
# 207/207 - 2s - loss: 0.0861 - accuracy: 0.9598 - 2s/epoch - 9ms/step
# Epoch 199/200
# 207/207 - 2s - loss: 0.0869 - accuracy: 0.9591 - 2s/epoch - 9ms/step
# Epoch 200/200
# 207/207 - 2s - loss: 0.0859 - accuracy: 0.9595 - 2s/epoch - 9ms/step
# 1611/1611 [==============================] - 7s 4ms/step
# Modell: SparseAutoencoder_6
# Genauigkeit: 0.9443679053070728
# Recall: 0.9443679053070728
# Precision: 0.9445520782491927
# F1 Score: 0.944440422883731

# %%
results = append_model_reults(model_sparse, results, end_train - start, end_predict - end_train, accuracy, recall, precision, f1)

# %%
save_plot_history_to_json(MODEL_NAME, history)

# %% [markdown]
# #### 4.2.7 Sequence-to-sequence Autoencoder

# %%
class SequenceToSequenceAutoencoder(Model):
    def __init__(self, name="SequenceToSequenceAutoencoder"):
        super(SequenceToSequenceAutoencoder, self).__init__(name=name)
        
        self.encoder = tf.keras.Sequential([
            layers.LSTM(128, activation="relu", return_sequences=True),],
            name="encoder")
        
        self.decoder = tf.keras.Sequential([
            layers.LSTM(64, activation="relu", return_sequences=True),
            layers.TimeDistributed(layers.Dense(TOTAL_FEATURES, activation="sigmoid"))],
            name="decoder")

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

model_seq = SequenceToSequenceAutoencoder(name=MODEL_NAME)
opt = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)

model_seq.compile(optimizer=opt, loss="mse", metrics=['accuracy'])
#model_seq.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
start = time.time()
#history = model_seq.fit(X_train_reshaped, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2) # Training model
history = model_seq.fit(X_train_reshaped, X_train_reshaped, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_test_reshaped, X_test_reshaped), verbose=2)
end_train = time.time()
accuracy, recall, precision, f1, end_predict = evaluate_model_timeseries(model_seq, X_test_reshaped, y_test, True) # evaluate_model_timeseries when training with mse loss
# Out:
# Epoch 1/200
# 207/207 - 4s - loss: 0.4972 - accuracy: 0.0355 - val_loss: 0.3742 - val_accuracy: 0.0190 - 4s/epoch - 19ms/step
# Epoch 2/200
# 207/207 - 2s - loss: 0.3706 - accuracy: 0.0628 - val_loss: 0.3653 - val_accuracy: 0.1085 - 2s/epoch - 9ms/step
# Epoch 3/200
# 207/207 - 2s - loss: 0.3654 - accuracy: 0.0879 - val_loss: 0.3620 - val_accuracy: 0.0769 - 2s/epoch - 9ms/step
# Epoch 4/200
# 207/207 - 2s - loss: 0.3636 - accuracy: 0.0745 - val_loss: 0.3613 - val_accuracy: 0.0712 - 2s/epoch - 8ms/step
# Epoch 5/200
# 207/207 - 2s - loss: 0.3626 - accuracy: 0.0658 - val_loss: 0.3601 - val_accuracy: 0.0634 - 2s/epoch - 8ms/step
# Epoch 6/200
# 207/207 - 2s - loss: 0.3617 - accuracy: 0.0602 - val_loss: 0.3593 - val_accuracy: 0.0573 - 2s/epoch - 8ms/step
# Epoch 7/200
# 207/207 - 2s - loss: 0.3612 - accuracy: 0.0571 - val_loss: 0.3590 - val_accuracy: 0.0570 - 2s/epoch - 8ms/step
# Epoch 8/200
# 207/207 - 2s - loss: 0.3605 - accuracy: 0.0573 - val_loss: 0.3584 - val_accuracy: 0.0588 - 2s/epoch - 8ms/step
# Epoch 9/200
# 207/207 - 2s - loss: 0.3602 - accuracy: 0.0590 - val_loss: 0.3581 - val_accuracy: 0.0619 - 2s/epoch - 8ms/step
# Epoch 10/200
# 207/207 - 2s - loss: 0.3599 - accuracy: 0.0669 - val_loss: 0.3579 - val_accuracy: 0.0704 - 2s/epoch - 8ms/step
# Epoch 11/200
# 207/207 - 2s - loss: 0.3597 - accuracy: 0.0733 - val_loss: 0.3568 - val_accuracy: 0.0853 - 2s/epoch - 8ms/step
# Epoch 12/200
# 207/207 - 2s - loss: 0.3584 - accuracy: 0.0714 - val_loss: 0.3563 - val_accuracy: 0.0743 - 2s/epoch - 8ms/step
# Epoch 13/200
# 207/207 - 2s - loss: 0.3582 - accuracy: 0.0740 - val_loss: 0.3562 - val_accuracy: 0.0712 - 2s/epoch - 8ms/step
# Epoch 14/200
# 207/207 - 2s - loss: 0.3581 - accuracy: 0.0793 - val_loss: 0.3562 - val_accuracy: 0.0753 - 2s/epoch - 8ms/step
# Epoch 15/200
# 207/207 - 2s - loss: 0.3581 - accuracy: 0.0815 - val_loss: 0.3561 - val_accuracy: 0.0791 - 2s/epoch - 8ms/step
# Epoch 16/200
# 207/207 - 2s - loss: 0.3580 - accuracy: 0.0806 - val_loss: 0.3560 - val_accuracy: 0.0759 - 2s/epoch - 9ms/step
# Epoch 17/200
# 207/207 - 2s - loss: 0.3580 - accuracy: 0.0828 - val_loss: 0.3560 - val_accuracy: 0.0879 - 2s/epoch - 8ms/step
# Epoch 18/200
# 207/207 - 2s - loss: 0.3579 - accuracy: 0.0819 - val_loss: 0.3559 - val_accuracy: 0.0768 - 2s/epoch - 8ms/step
# Epoch 19/200
# 207/207 - 2s - loss: 0.3578 - accuracy: 0.0813 - val_loss: 0.3558 - val_accuracy: 0.0827 - 2s/epoch - 8ms/step
# Epoch 20/200
# 207/207 - 2s - loss: 0.3578 - accuracy: 0.0829 - val_loss: 0.3558 - val_accuracy: 0.0863 - 2s/epoch - 8ms/step
# Epoch 21/200
# 207/207 - 2s - loss: 0.3577 - accuracy: 0.0824 - val_loss: 0.3557 - val_accuracy: 0.0772 - 2s/epoch - 8ms/step
# Epoch 22/200
# 207/207 - 2s - loss: 0.3577 - accuracy: 0.0867 - val_loss: 0.3557 - val_accuracy: 0.0805 - 2s/epoch - 8ms/step
# Epoch 23/200
# 207/207 - 2s - loss: 0.3577 - accuracy: 0.0851 - val_loss: 0.3557 - val_accuracy: 0.0841 - 2s/epoch - 8ms/step
# Epoch 24/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0810 - val_loss: 0.3557 - val_accuracy: 0.0822 - 2s/epoch - 8ms/step
# Epoch 25/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0810 - val_loss: 0.3556 - val_accuracy: 0.0748 - 2s/epoch - 8ms/step
# Epoch 26/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0816 - val_loss: 0.3556 - val_accuracy: 0.0799 - 2s/epoch - 9ms/step
# Epoch 27/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0830 - val_loss: 0.3556 - val_accuracy: 0.0790 - 2s/epoch - 9ms/step
# Epoch 28/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0834 - val_loss: 0.3556 - val_accuracy: 0.0865 - 2s/epoch - 9ms/step
# Epoch 29/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0846 - val_loss: 0.3556 - val_accuracy: 0.0843 - 2s/epoch - 9ms/step
# Epoch 30/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0857 - val_loss: 0.3556 - val_accuracy: 0.0850 - 2s/epoch - 9ms/step
# Epoch 31/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0872 - val_loss: 0.3556 - val_accuracy: 0.0877 - 2s/epoch - 9ms/step
# Epoch 32/200
# 207/207 - 2s - loss: 0.3576 - accuracy: 0.0874 - val_loss: 0.3556 - val_accuracy: 0.0853 - 2s/epoch - 9ms/step
# Epoch 33/200
# 207/207 - 2s - loss: 0.3575 - accuracy: 0.0856 - val_loss: 0.3556 - val_accuracy: 0.0865 - 2s/epoch - 9ms/step
# Epoch 34/200
# 207/207 - 2s - loss: 0.3562 - accuracy: 0.0831 - val_loss: 0.3538 - val_accuracy: 0.0782 - 2s/epoch - 9ms/step
# Epoch 35/200
# 207/207 - 2s - loss: 0.3557 - accuracy: 0.0800 - val_loss: 0.3537 - val_accuracy: 0.0820 - 2s/epoch - 9ms/step
# Epoch 36/200
# 207/207 - 2s - loss: 0.3557 - accuracy: 0.0752 - val_loss: 0.3537 - val_accuracy: 0.0737 - 2s/epoch - 8ms/step
# Epoch 37/200
# 207/207 - 2s - loss: 0.3557 - accuracy: 0.0741 - val_loss: 0.3537 - val_accuracy: 0.0737 - 2s/epoch - 8ms/step
# Epoch 38/200
# 207/207 - 2s - loss: 0.3557 - accuracy: 0.0750 - val_loss: 0.3537 - val_accuracy: 0.0743 - 2s/epoch - 9ms/step
# Epoch 39/200
# 207/207 - 2s - loss: 0.3556 - accuracy: 0.0724 - val_loss: 0.3537 - val_accuracy: 0.0731 - 2s/epoch - 8ms/step
# Epoch 40/200
# 207/207 - 2s - loss: 0.3556 - accuracy: 0.0689 - val_loss: 0.3537 - val_accuracy: 0.0673 - 2s/epoch - 8ms/step
# Epoch 41/200
# 207/207 - 2s - loss: 0.3556 - accuracy: 0.0647 - val_loss: 0.3537 - val_accuracy: 0.0650 - 2s/epoch - 8ms/step
# Epoch 42/200
# 207/207 - 2s - loss: 0.3556 - accuracy: 0.0632 - val_loss: 0.3537 - val_accuracy: 0.0615 - 2s/epoch - 8ms/step
# Epoch 43/200
# 207/207 - 2s - loss: 0.3556 - accuracy: 0.0597 - val_loss: 0.3537 - val_accuracy: 0.0605 - 2s/epoch - 8ms/step
# Epoch 44/200
# 207/207 - 2s - loss: 0.3556 - accuracy: 0.0576 - val_loss: 0.3536 - val_accuracy: 0.0600 - 2s/epoch - 8ms/step
# Epoch 45/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0577 - val_loss: 0.3536 - val_accuracy: 0.0593 - 2s/epoch - 8ms/step
# Epoch 46/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0566 - val_loss: 0.3536 - val_accuracy: 0.0536 - 2s/epoch - 8ms/step
# Epoch 47/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0552 - val_loss: 0.3536 - val_accuracy: 0.0516 - 2s/epoch - 8ms/step
# Epoch 48/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0542 - val_loss: 0.3535 - val_accuracy: 0.0540 - 2s/epoch - 9ms/step
# Epoch 49/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0533 - val_loss: 0.3536 - val_accuracy: 0.0516 - 2s/epoch - 9ms/step
# Epoch 50/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0526 - val_loss: 0.3535 - val_accuracy: 0.0503 - 2s/epoch - 10ms/step
# Epoch 51/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0515 - val_loss: 0.3535 - val_accuracy: 0.0495 - 2s/epoch - 9ms/step
# Epoch 52/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0497 - val_loss: 0.3535 - val_accuracy: 0.0503 - 2s/epoch - 9ms/step
# Epoch 53/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0482 - val_loss: 0.3535 - val_accuracy: 0.0479 - 2s/epoch - 8ms/step
# Epoch 54/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0481 - val_loss: 0.3536 - val_accuracy: 0.0454 - 2s/epoch - 8ms/step
# Epoch 55/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0466 - val_loss: 0.3535 - val_accuracy: 0.0469 - 2s/epoch - 9ms/step
# Epoch 56/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0463 - val_loss: 0.3535 - val_accuracy: 0.0423 - 2s/epoch - 9ms/step
# Epoch 57/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0439 - val_loss: 0.3535 - val_accuracy: 0.0432 - 2s/epoch - 8ms/step
# Epoch 58/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0435 - val_loss: 0.3535 - val_accuracy: 0.0406 - 2s/epoch - 8ms/step
# Epoch 59/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0420 - val_loss: 0.3535 - val_accuracy: 0.0430 - 2s/epoch - 8ms/step
# Epoch 60/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0416 - val_loss: 0.3535 - val_accuracy: 0.0394 - 2s/epoch - 8ms/step
# Epoch 61/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0420 - val_loss: 0.3535 - val_accuracy: 0.0400 - 2s/epoch - 8ms/step
# Epoch 62/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0407 - val_loss: 0.3535 - val_accuracy: 0.0397 - 2s/epoch - 8ms/step
# Epoch 63/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0398 - val_loss: 0.3535 - val_accuracy: 0.0417 - 2s/epoch - 9ms/step
# Epoch 64/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0391 - val_loss: 0.3535 - val_accuracy: 0.0381 - 2s/epoch - 9ms/step
# Epoch 65/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0379 - val_loss: 0.3535 - val_accuracy: 0.0362 - 2s/epoch - 8ms/step
# Epoch 66/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0375 - val_loss: 0.3535 - val_accuracy: 0.0347 - 2s/epoch - 9ms/step
# Epoch 67/200
# 207/207 - 2s - loss: 0.3555 - accuracy: 0.0370 - val_loss: 0.3535 - val_accuracy: 0.0360 - 2s/epoch - 9ms/step
# Epoch 68/200
# 207/207 - 2s - loss: 0.3554 - accuracy: 0.0372 - val_loss: 0.3535 - val_accuracy: 0.0383 - 2s/epoch - 8ms/step
# Epoch 69/200
# 207/207 - 2s - loss: 0.3554 - accuracy: 0.0370 - val_loss: 0.3535 - val_accuracy: 0.0365 - 2s/epoch - 9ms/step
# Epoch 70/200
# 207/207 - 2s - loss: 0.3554 - accuracy: 0.0370 - val_loss: 0.3535 - val_accuracy: 0.0372 - 2s/epoch - 9ms/step
# Epoch 71/200
# 207/207 - 2s - loss: 0.3554 - accuracy: 0.0373 - val_loss: 0.3535 - val_accuracy: 0.0363 - 2s/epoch - 9ms/step
# Epoch 72/200
# 207/207 - 2s - loss: 0.3554 - accuracy: 0.0366 - val_loss: 0.3534 - val_accuracy: 0.0364 - 2s/epoch - 9ms/step
# Epoch 73/200
# 207/207 - 2s - loss: 0.3553 - accuracy: 0.0362 - val_loss: 0.3534 - val_accuracy: 0.0342 - 2s/epoch - 9ms/step
# Epoch 74/200
# 207/207 - 2s - loss: 0.3546 - accuracy: 0.0385 - val_loss: 0.3523 - val_accuracy: 0.0368 - 2s/epoch - 9ms/step
# Epoch 75/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0370 - val_loss: 0.3523 - val_accuracy: 0.0359 - 2s/epoch - 9ms/step
# Epoch 76/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0367 - val_loss: 0.3523 - val_accuracy: 0.0370 - 2s/epoch - 9ms/step
# Epoch 77/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0370 - val_loss: 0.3523 - val_accuracy: 0.0371 - 2s/epoch - 9ms/step
# Epoch 78/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0371 - val_loss: 0.3523 - val_accuracy: 0.0357 - 2s/epoch - 9ms/step
# Epoch 79/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0365 - val_loss: 0.3523 - val_accuracy: 0.0365 - 2s/epoch - 8ms/step
# Epoch 80/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0359 - val_loss: 0.3523 - val_accuracy: 0.0363 - 2s/epoch - 10ms/step
# Epoch 81/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0355 - val_loss: 0.3523 - val_accuracy: 0.0358 - 2s/epoch - 9ms/step
# Epoch 82/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0355 - val_loss: 0.3523 - val_accuracy: 0.0369 - 2s/epoch - 9ms/step
# Epoch 83/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0356 - val_loss: 0.3523 - val_accuracy: 0.0355 - 2s/epoch - 9ms/step
# Epoch 84/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0353 - val_loss: 0.3523 - val_accuracy: 0.0351 - 2s/epoch - 9ms/step
# Epoch 85/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0353 - val_loss: 0.3523 - val_accuracy: 0.0340 - 2s/epoch - 9ms/step
# Epoch 86/200
# 207/207 - 2s - loss: 0.3543 - accuracy: 0.0349 - val_loss: 0.3523 - val_accuracy: 0.0359 - 2s/epoch - 9ms/step
# Epoch 87/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0343 - val_loss: 0.3523 - val_accuracy: 0.0349 - 2s/epoch - 9ms/step
# Epoch 88/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0346 - val_loss: 0.3522 - val_accuracy: 0.0342 - 2s/epoch - 9ms/step
# Epoch 89/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0342 - val_loss: 0.3522 - val_accuracy: 0.0335 - 2s/epoch - 9ms/step
# Epoch 90/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0341 - val_loss: 0.3523 - val_accuracy: 0.0353 - 2s/epoch - 9ms/step
# Epoch 91/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0339 - val_loss: 0.3523 - val_accuracy: 0.0345 - 2s/epoch - 9ms/step
# Epoch 92/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0342 - val_loss: 0.3522 - val_accuracy: 0.0359 - 2s/epoch - 9ms/step
# Epoch 93/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0339 - val_loss: 0.3522 - val_accuracy: 0.0351 - 2s/epoch - 8ms/step
# Epoch 94/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0334 - val_loss: 0.3522 - val_accuracy: 0.0349 - 2s/epoch - 9ms/step
# Epoch 95/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0335 - val_loss: 0.3522 - val_accuracy: 0.0343 - 2s/epoch - 9ms/step
# Epoch 96/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0327 - val_loss: 0.3522 - val_accuracy: 0.0324 - 2s/epoch - 8ms/step
# Epoch 97/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0323 - val_loss: 0.3522 - val_accuracy: 0.0324 - 2s/epoch - 9ms/step
# Epoch 98/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0321 - val_loss: 0.3522 - val_accuracy: 0.0292 - 2s/epoch - 8ms/step
# Epoch 99/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0326 - val_loss: 0.3523 - val_accuracy: 0.0321 - 2s/epoch - 9ms/step
# Epoch 100/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0310 - val_loss: 0.3522 - val_accuracy: 0.0317 - 2s/epoch - 9ms/step
# Epoch 101/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0317 - val_loss: 0.3522 - val_accuracy: 0.0277 - 2s/epoch - 9ms/step
# Epoch 102/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0300 - val_loss: 0.3522 - val_accuracy: 0.0296 - 2s/epoch - 10ms/step
# Epoch 103/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0301 - val_loss: 0.3522 - val_accuracy: 0.0285 - 2s/epoch - 10ms/step
# Epoch 104/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0288 - val_loss: 0.3522 - val_accuracy: 0.0307 - 2s/epoch - 11ms/step
# Epoch 105/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0293 - val_loss: 0.3522 - val_accuracy: 0.0289 - 2s/epoch - 10ms/step
# Epoch 106/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0298 - val_loss: 0.3522 - val_accuracy: 0.0327 - 2s/epoch - 9ms/step
# Epoch 107/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0281 - val_loss: 0.3522 - val_accuracy: 0.0279 - 2s/epoch - 9ms/step
# Epoch 108/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0278 - val_loss: 0.3522 - val_accuracy: 0.0289 - 2s/epoch - 9ms/step
# Epoch 109/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0281 - val_loss: 0.3522 - val_accuracy: 0.0277 - 2s/epoch - 9ms/step
# Epoch 110/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0275 - val_loss: 0.3522 - val_accuracy: 0.0264 - 2s/epoch - 8ms/step
# Epoch 111/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0272 - val_loss: 0.3522 - val_accuracy: 0.0280 - 2s/epoch - 9ms/step
# Epoch 112/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0282 - val_loss: 0.3522 - val_accuracy: 0.0274 - 2s/epoch - 8ms/step
# Epoch 113/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0272 - val_loss: 0.3522 - val_accuracy: 0.0270 - 2s/epoch - 8ms/step
# Epoch 114/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0272 - val_loss: 0.3522 - val_accuracy: 0.0266 - 2s/epoch - 8ms/step
# Epoch 115/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0268 - val_loss: 0.3522 - val_accuracy: 0.0272 - 2s/epoch - 9ms/step
# Epoch 116/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0273 - val_loss: 0.3522 - val_accuracy: 0.0275 - 2s/epoch - 9ms/step
# Epoch 117/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0270 - val_loss: 0.3522 - val_accuracy: 0.0272 - 2s/epoch - 9ms/step
# Epoch 118/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0278 - val_loss: 0.3522 - val_accuracy: 0.0267 - 2s/epoch - 9ms/step
# Epoch 119/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0277 - val_loss: 0.3522 - val_accuracy: 0.0281 - 2s/epoch - 8ms/step
# Epoch 120/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0282 - val_loss: 0.3522 - val_accuracy: 0.0278 - 2s/epoch - 8ms/step
# Epoch 121/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0277 - val_loss: 0.3522 - val_accuracy: 0.0282 - 2s/epoch - 8ms/step
# Epoch 122/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0272 - val_loss: 0.3522 - val_accuracy: 0.0270 - 2s/epoch - 8ms/step
# Epoch 123/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0273 - val_loss: 0.3522 - val_accuracy: 0.0282 - 2s/epoch - 9ms/step
# Epoch 124/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0274 - val_loss: 0.3522 - val_accuracy: 0.0278 - 2s/epoch - 9ms/step
# Epoch 125/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0273 - val_loss: 0.3522 - val_accuracy: 0.0267 - 2s/epoch - 9ms/step
# Epoch 126/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0272 - val_loss: 0.3522 - val_accuracy: 0.0269 - 2s/epoch - 8ms/step
# Epoch 127/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0274 - val_loss: 0.3522 - val_accuracy: 0.0261 - 2s/epoch - 8ms/step
# Epoch 128/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0273 - val_loss: 0.3522 - val_accuracy: 0.0278 - 2s/epoch - 8ms/step
# Epoch 129/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0280 - val_loss: 0.3522 - val_accuracy: 0.0287 - 2s/epoch - 8ms/step
# Epoch 130/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0277 - val_loss: 0.3522 - val_accuracy: 0.0296 - 2s/epoch - 9ms/step
# Epoch 131/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0263 - val_loss: 0.3522 - val_accuracy: 0.0275 - 2s/epoch - 9ms/step
# Epoch 132/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0266 - val_loss: 0.3522 - val_accuracy: 0.0262 - 2s/epoch - 9ms/step
# Epoch 133/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0268 - val_loss: 0.3522 - val_accuracy: 0.0266 - 2s/epoch - 9ms/step
# Epoch 134/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0268 - val_loss: 0.3522 - val_accuracy: 0.0263 - 2s/epoch - 9ms/step
# Epoch 135/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0264 - val_loss: 0.3522 - val_accuracy: 0.0255 - 2s/epoch - 9ms/step
# Epoch 136/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0262 - val_loss: 0.3522 - val_accuracy: 0.0259 - 2s/epoch - 9ms/step
# Epoch 137/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0265 - val_loss: 0.3522 - val_accuracy: 0.0259 - 2s/epoch - 9ms/step
# Epoch 138/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0260 - val_loss: 0.3522 - val_accuracy: 0.0267 - 2s/epoch - 9ms/step
# Epoch 139/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0261 - val_loss: 0.3522 - val_accuracy: 0.0257 - 2s/epoch - 9ms/step
# Epoch 140/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0263 - val_loss: 0.3522 - val_accuracy: 0.0261 - 2s/epoch - 9ms/step
# Epoch 141/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0267 - val_loss: 0.3522 - val_accuracy: 0.0266 - 2s/epoch - 11ms/step
# Epoch 142/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0259 - val_loss: 0.3522 - val_accuracy: 0.0263 - 2s/epoch - 9ms/step
# Epoch 143/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0266 - val_loss: 0.3522 - val_accuracy: 0.0256 - 2s/epoch - 8ms/step
# Epoch 144/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0266 - val_loss: 0.3522 - val_accuracy: 0.0273 - 2s/epoch - 8ms/step
# Epoch 145/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0267 - val_loss: 0.3522 - val_accuracy: 0.0257 - 2s/epoch - 8ms/step
# Epoch 146/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0262 - val_loss: 0.3522 - val_accuracy: 0.0265 - 2s/epoch - 8ms/step
# Epoch 147/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0260 - val_loss: 0.3522 - val_accuracy: 0.0264 - 2s/epoch - 8ms/step
# Epoch 148/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0266 - val_loss: 0.3522 - val_accuracy: 0.0258 - 2s/epoch - 9ms/step
# Epoch 149/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0259 - val_loss: 0.3522 - val_accuracy: 0.0257 - 2s/epoch - 9ms/step
# Epoch 150/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0262 - val_loss: 0.3522 - val_accuracy: 0.0266 - 2s/epoch - 8ms/step
# Epoch 151/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0268 - val_loss: 0.3522 - val_accuracy: 0.0266 - 2s/epoch - 8ms/step
# Epoch 152/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0262 - val_loss: 0.3522 - val_accuracy: 0.0266 - 2s/epoch - 10ms/step
# Epoch 153/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0268 - val_loss: 0.3522 - val_accuracy: 0.0264 - 2s/epoch - 9ms/step
# Epoch 154/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0265 - val_loss: 0.3522 - val_accuracy: 0.0263 - 2s/epoch - 9ms/step
# Epoch 155/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0271 - val_loss: 0.3522 - val_accuracy: 0.0252 - 2s/epoch - 9ms/step
# Epoch 156/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0265 - val_loss: 0.3522 - val_accuracy: 0.0262 - 2s/epoch - 9ms/step
# Epoch 157/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0264 - val_loss: 0.3522 - val_accuracy: 0.0273 - 2s/epoch - 8ms/step
# Epoch 158/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0268 - val_loss: 0.3522 - val_accuracy: 0.0264 - 2s/epoch - 8ms/step
# Epoch 159/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0269 - val_loss: 0.3522 - val_accuracy: 0.0260 - 2s/epoch - 9ms/step
# Epoch 160/200
# 207/207 - 2s - loss: 0.3542 - accuracy: 0.0269 - val_loss: 0.3522 - val_accuracy: 0.0264 - 2s/epoch - 8ms/step
# Epoch 161/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0270 - val_loss: 0.3522 - val_accuracy: 0.0275 - 2s/epoch - 8ms/step
# Epoch 162/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0275 - val_loss: 0.3522 - val_accuracy: 0.0264 - 2s/epoch - 9ms/step
# Epoch 163/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0269 - val_loss: 0.3521 - val_accuracy: 0.0271 - 2s/epoch - 8ms/step
# Epoch 164/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0272 - val_loss: 0.3522 - val_accuracy: 0.0277 - 2s/epoch - 8ms/step
# Epoch 165/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0272 - val_loss: 0.3522 - val_accuracy: 0.0258 - 2s/epoch - 8ms/step
# Epoch 166/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0269 - val_loss: 0.3522 - val_accuracy: 0.0270 - 2s/epoch - 8ms/step
# Epoch 167/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0268 - val_loss: 0.3522 - val_accuracy: 0.0266 - 2s/epoch - 8ms/step
# Epoch 168/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0274 - val_loss: 0.3522 - val_accuracy: 0.0275 - 2s/epoch - 8ms/step
# Epoch 169/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0273 - val_loss: 0.3522 - val_accuracy: 0.0268 - 2s/epoch - 8ms/step
# Epoch 170/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0279 - val_loss: 0.3521 - val_accuracy: 0.0279 - 2s/epoch - 8ms/step
# Epoch 171/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0276 - val_loss: 0.3522 - val_accuracy: 0.0275 - 2s/epoch - 8ms/step
# Epoch 172/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0278 - val_loss: 0.3522 - val_accuracy: 0.0275 - 2s/epoch - 8ms/step
# Epoch 173/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0271 - val_loss: 0.3521 - val_accuracy: 0.0259 - 2s/epoch - 8ms/step
# Epoch 174/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0274 - val_loss: 0.3522 - val_accuracy: 0.0277 - 2s/epoch - 8ms/step
# Epoch 175/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0278 - val_loss: 0.3521 - val_accuracy: 0.0271 - 2s/epoch - 8ms/step
# Epoch 176/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0278 - val_loss: 0.3522 - val_accuracy: 0.0278 - 2s/epoch - 8ms/step
# Epoch 177/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0279 - val_loss: 0.3522 - val_accuracy: 0.0272 - 2s/epoch - 9ms/step
# Epoch 178/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0278 - val_loss: 0.3521 - val_accuracy: 0.0279 - 2s/epoch - 9ms/step
# Epoch 179/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0283 - val_loss: 0.3521 - val_accuracy: 0.0263 - 2s/epoch - 8ms/step
# Epoch 180/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0274 - val_loss: 0.3522 - val_accuracy: 0.0278 - 2s/epoch - 9ms/step
# Epoch 181/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0279 - val_loss: 0.3522 - val_accuracy: 0.0274 - 2s/epoch - 9ms/step
# Epoch 182/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0274 - val_loss: 0.3521 - val_accuracy: 0.0268 - 2s/epoch - 9ms/step
# Epoch 183/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0278 - val_loss: 0.3522 - val_accuracy: 0.0268 - 2s/epoch - 8ms/step
# Epoch 184/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0277 - val_loss: 0.3521 - val_accuracy: 0.0284 - 2s/epoch - 8ms/step
# Epoch 185/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0276 - val_loss: 0.3521 - val_accuracy: 0.0285 - 2s/epoch - 8ms/step
# Epoch 186/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0280 - val_loss: 0.3521 - val_accuracy: 0.0279 - 2s/epoch - 8ms/step
# Epoch 187/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0280 - val_loss: 0.3521 - val_accuracy: 0.0278 - 2s/epoch - 9ms/step
# Epoch 188/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0277 - val_loss: 0.3521 - val_accuracy: 0.0269 - 2s/epoch - 8ms/step
# Epoch 189/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0280 - val_loss: 0.3522 - val_accuracy: 0.0280 - 2s/epoch - 8ms/step
# Epoch 190/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0287 - val_loss: 0.3521 - val_accuracy: 0.0270 - 2s/epoch - 8ms/step
# Epoch 191/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0275 - val_loss: 0.3521 - val_accuracy: 0.0280 - 2s/epoch - 9ms/step
# Epoch 192/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0280 - val_loss: 0.3521 - val_accuracy: 0.0292 - 2s/epoch - 10ms/step
# Epoch 193/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0282 - val_loss: 0.3522 - val_accuracy: 0.0279 - 2s/epoch - 9ms/step
# Epoch 194/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0283 - val_loss: 0.3521 - val_accuracy: 0.0292 - 2s/epoch - 9ms/step
# Epoch 195/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0287 - val_loss: 0.3521 - val_accuracy: 0.0302 - 2s/epoch - 9ms/step
# Epoch 196/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0293 - val_loss: 0.3521 - val_accuracy: 0.0273 - 2s/epoch - 9ms/step
# Epoch 197/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0293 - val_loss: 0.3521 - val_accuracy: 0.0271 - 2s/epoch - 9ms/step
# Epoch 198/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0284 - val_loss: 0.3521 - val_accuracy: 0.0289 - 2s/epoch - 9ms/step
# Epoch 199/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0290 - val_loss: 0.3522 - val_accuracy: 0.0282 - 2s/epoch - 9ms/step
# Epoch 200/200
# 207/207 - 2s - loss: 0.3541 - accuracy: 0.0290 - val_loss: 0.3521 - val_accuracy: 0.0275 - 2s/epoch - 9ms/step
# 1611/1611 [==============================] - 3s 2ms/step
# Modell: SegToSeq_2
# Genauigkeit: 0.57390123217231
# Recall: 0.57390123217231
# Precision: 0.4827115165459777
# F1 Score: 0.5030497784449742

# %%
results = append_model_reults(model_seq, results, end_train - start, end_predict - end_train, accuracy, recall, precision, f1)
save_plot_history_to_json(MODEL_NAME, history)

# %%
encoded_data = model_seq.encoder(X_test_reshaped).numpy()
plot_autoencoder_reconstruction(model_seq.decoder(encoded_data).numpy(), X_test_reshaped)

# %%
plot_mae_distribution(model_seq, X_train_reshaped, y_train)

# %% [markdown]
# #### 4.2.8 Variational-Autoencoder (VAE)

# %%
from keras import backend as K

# %%
LATENT_DIM = 2

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = K.shape(z_mean)[0]
        dim = K.int_shape(z_mean)[1]
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %%
class VariationalAutoencoder(Model):
    def __init__(self, name="VariationalAutoencoder"):
        super(VariationalAutoencoder, self).__init__(name=name)
        
        self.encoder = tf.keras.Sequential([
            layers.Flatten(),
            layers.Dense(256, activation="relu"),
            layers.Dense(TOTAL_FEATURES, activation="relu")],
            name="encoder")
        
        self.z_mean = layers.Dense(TOTAL_FEATURES, name="z_mean")
        self.z_log_var = layers.Dense(TOTAL_FEATURES, name="z_log_var")

        self.sampling = Sampling()

        self.decoder = tf.keras.Sequential([
            layers.Dense(64, activation="relu"),
            layers.Dense(TOTAL_FEATURES, activation="sigmoid")],
            name="decoder")

    def call(self, x):
        encoded = self.encoder(x)
        z_mean = self.z_mean(encoded)
        z_log_var = self.z_log_var(encoded)
        z = self.sampling([z_mean, z_log_var])
        decoded = self.decoder(z)

        return decoded, z_mean, z_log_var

# %%
model_vae = VariationalAutoencoder(name=MODEL_NAME)
opt = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
model_vae.compile(optimizer=opt, loss="mse")

# %%
start = time.time()
#history = model_seq.fit(X_train_reshaped, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2) # Training model
history = model_vae.fit(X_train_reshaped, X_train_reshaped, epochs=20, batch_size=BATCH_SIZE, validation_data=(X_test_reshaped, X_test_reshaped), verbose=2)
end_train = time.time()
# Out:
# Epoch 1/20
# Tensor("VAE_1/encoder/dense_48/Relu:0", shape=(None, 56), dtype=float32)
# Tensor("VAE_1/decoder/dense_50/Sigmoid:0", shape=(None, 56), dtype=float32)
# Tensor("VAE_1/encoder/dense_48/Relu:0", shape=(None, 56), dtype=float32)
# Tensor("VAE_1/decoder/dense_50/Sigmoid:0", shape=(None, 56), dtype=float32)
# Tensor("VAE_1/encoder/dense_48/Relu:0", shape=(None, 56), dtype=float32)
# Tensor("VAE_1/decoder/dense_50/Sigmoid:0", shape=(None, 56), dtype=float32)
# 207/207 - 11s - loss: 2.1888 - output_1_loss: 0.7519 - output_2_loss: 0.7190 - output_3_loss: 0.7179 - val_loss: 2.1327 - val_output_1_loss: 0.7129 - val_output_2_loss: 0.7099 - val_output_3_loss: 0.7099 - 11s/epoch - 55ms/step
# Epoch 2/20
# 207/207 - 10s - loss: 2.1427 - output_1_loss: 0.7153 - output_2_loss: 0.7137 - output_3_loss: 0.7137 - val_loss: 2.1305 - val_output_1_loss: 0.7108 - val_output_2_loss: 0.7099 - val_output_3_loss: 0.7099 - 10s/epoch - 50ms/step
# Epoch 3/20
# 207/207 - 12s - loss: 2.1416 - output_1_loss: 0.7143 - output_2_loss: 0.7137 - output_3_loss: 0.7137 - val_loss: 2.1300 - val_output_1_loss: 0.7103 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 57ms/step
# Epoch 4/20
# 207/207 - 11s - loss: 2.1413 - output_1_loss: 0.7140 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1298 - val_output_1_loss: 0.7101 - val_output_2_loss: 0.7099 - val_output_3_loss: 0.7099 - 11s/epoch - 54ms/step
# Epoch 5/20
# 207/207 - 12s - loss: 2.1411 - output_1_loss: 0.7138 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1295 - val_output_1_loss: 0.7100 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 59ms/step
# Epoch 6/20
# 207/207 - 12s - loss: 2.1410 - output_1_loss: 0.7138 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1296 - val_output_1_loss: 0.7099 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 59ms/step
# Epoch 7/20
# 207/207 - 10s - loss: 2.1409 - output_1_loss: 0.7137 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1296 - val_output_1_loss: 0.7099 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7099 - 10s/epoch - 50ms/step
# Epoch 8/20
# 207/207 - 10s - loss: 2.1410 - output_1_loss: 0.7137 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1295 - val_output_1_loss: 0.7099 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 10s/epoch - 50ms/step
# Epoch 9/20
# 207/207 - 12s - loss: 2.1409 - output_1_loss: 0.7137 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1294 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 58ms/step
# Epoch 10/20
# 207/207 - 12s - loss: 2.1409 - output_1_loss: 0.7137 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1294 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 58ms/step
# Epoch 11/20
# 207/207 - 12s - loss: 2.1409 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1295 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 58ms/step
# Epoch 12/20
# 207/207 - 12s - loss: 2.1408 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1293 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 60ms/step
# Epoch 13/20
# 207/207 - 12s - loss: 2.1409 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1294 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 56ms/step
# Epoch 14/20
# 207/207 - 11s - loss: 2.1408 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1294 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 11s/epoch - 52ms/step
# Epoch 15/20
# 207/207 - 11s - loss: 2.1408 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1294 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 11s/epoch - 52ms/step
# Epoch 16/20
# 207/207 - 11s - loss: 2.1408 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1294 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 11s/epoch - 51ms/step
# Epoch 17/20
# 207/207 - 11s - loss: 2.1408 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1294 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 11s/epoch - 53ms/step
# Epoch 18/20
# 207/207 - 12s - loss: 2.1408 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1294 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 60ms/step
# Epoch 19/20
# 207/207 - 12s - loss: 2.1408 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1293 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 58ms/step
# Epoch 20/20
# 207/207 - 12s - loss: 2.1408 - output_1_loss: 0.7136 - output_2_loss: 0.7136 - output_3_loss: 0.7136 - val_loss: 2.1293 - val_output_1_loss: 0.7098 - val_output_2_loss: 0.7098 - val_output_3_loss: 0.7098 - 12s/epoch - 56ms/step

# %%
accuracy, recall, precision, f1, end_predict = evaluate_model_timeseries(model_vae, X_test_reshaped, y_test, True) # evaluate_model_timeseries when training with mse loss
# Out:
#    1/1611 [..............................] - ETA: 34s
# 1611/1611 [==============================] - 2s 1ms/step
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 accuracy, recall, precision, f1, end_predict = evaluate_model_timeseries(model_vae, X_test_reshaped, y_test, True) # evaluate_model_timeseries when training with mse loss
#
# Cell In[57], line 5, in evaluate_model_timeseries(model, X, y_true, print_output)
#       2 def evaluate_model_timeseries(model, X, y_true, print_output=True):
#       4     reconstructions = model.predict(X)
# ----> 5     test_loss = tf.keras.losses.mae(reconstructions, X)
#       6     threshold_test = (np.mean(test_loss) + np.std(test_loss))
#       7     predictions_final = np.where(np.mean((test_loss < threshold_test).numpy().astype(int), axis=1) < 1, 0, 1)
#
# File c:\Users\Alexej\miniconda3\envs\simple-htr-gpu\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\Alexej\miniconda3\envs\simple-htr-gpu\lib\site-packages\keras\losses.py:1627, in mean_absolute_error(y_true, y_pred)
#    1625 y_pred = tf.convert_to_tensor(y_pred)
#    1626 y_true = tf.cast(y_true, y_pred.dtype)
# -> 1627 return backend.mean(tf.abs(y_pred - y_true), axis=-1)
#
# InvalidArgumentError: {{function_node __wrapped__Sub_device_/job:localhost/replica:0/task:0/device:GPU:0}} required broadcastable shapes [Op:Sub]

# %%
encoded_data = model_vae.encoder(X_test_reshaped).numpy()
plot_autoencoder_reconstruction(model_vae.decoder(encoded_data).numpy(), X_test_reshaped)

# %%
# Encoder verwenden, um Daten zu reduzieren
encoded_data = model_vae.encoder(X_test_reshaped).numpy()

# Decoder verwenden, um Daten zu rekonstruieren
decoded_data = model_vae.decoder(encoded_data).numpy()

# Anzahl der Beispiele zum Plotten
num_examples = 10
selected_indices = np.random.choice(range(len(X_test_reshaped)), num_examples, replace=False)

# Originaldaten vs. rekonstruierte Daten plotten
plt.figure(figsize=(15, 5))

for i, idx in enumerate(selected_indices, 1):
    plt.subplot(2, num_examples, i)
    plt.plot(X_test_reshaped[idx, 0], 'b')
    plt.title(f'Original {idx}')
    plt.subplot(2, num_examples, i + num_examples)
    plt.plot(decoded_data[idx, 0], 'r')
    plt.title(f'Reconstructed {idx}')

plt.tight_layout()
plt.show()

# %%
results = append_model_reults(model_vae, results, end_train - start, end_predict - end_train, accuracy, recall, precision, f1)
save_plot_history_to_json(MODEL_NAME, history)

# %%
encoded_data = model_vae.encoder(X_test_reshaped).numpy()
plot_autoencoder_reconstruction(model_vae.decoder(encoded_data).numpy(), X_test_reshaped)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[160], line 2
#       1 encoded_data = model_vae.encoder(X_test_reshaped).numpy()
# ----> 2 plot_autoencoder_reconstruction(model_vae.decoder(encoded_data).numpy(), X_test_reshaped)
#
# File c:\Users\Alexej\miniconda3\envs\simple-htr-gpu\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Alexej\miniconda3\envs\simple-htr-gpu\lib\site-packages\keras\engine\input_spec.py:277, in assert_input_compatibility(input_spec, inputs, layer_name)
#     272             value = value.value
#     273         if value is not None and shape_as_list[int(axis)] not in {
#     274             value,
#     275             None,
#     276         }:
# --> 277             raise ValueError(
#     278                 f'Input {input_index} of layer "{layer_name}" is '
#     279                 f"incompatible with the layer: expected axis {axis} "
#     280                 f"of input shape to have value {value}, "
#     281                 "but received input with "
#     282                 f"shape {display_shape(x.shape)}"
#     283             )
#     284 # Check shape.
#     285 if spec.shape is not None and shape.rank is not None:
#
# ValueError: Exception encountered when calling layer "decoder" "                 f"(type Sequential).
#
# Input 0 of layer "dense_37" is incompatible with the layer: expected axis -1 of input shape to have value 56, but received input with shape (51535, 128)
#
# Call arguments received by layer "decoder" "                 f"(type Sequential):
#   • inputs=tf.Tensor(shape=(51535, 128), dtype=float32)
#   • training=None
#   • mask=None

# %%
plot_mae_distribution(model_vae, X_train_reshaped, y_train)

# %% [markdown]
# ## 5. Evaluation of all models

# %%
df_results_sae= pd.DataFrame(results)
df_results_sae.to_csv('./data/df_results_sae.csv', index=False)

# %%
df_results_a = pd.read_csv('./data/df_results_a.csv')
df_results_d = pd.read_csv('./data/df_results_d.csv')
df_results_k = pd.read_csv('./data/df_results_k.csv')
df_results_s = pd.read_csv('./data/df_results_s.csv')
df_results_sae = pd.read_csv('./data/df_results_sae.csv')
df_results_unsupervised = pd.read_csv('./data/df_results_unsupervised.csv')

# %%
df_results_all = pd.DataFrame()

# %%
df_results_all = pd.read_csv('./data/df_results.csv')

# %%
df_results_all.style.background_gradient(subset=['Trainingszeit'], cmap='RdYlGn_r') \
                            .background_gradient(subset=['Vorhersagezeit'], cmap='RdYlGn_r') \
                            .background_gradient(subset=['Recall'], cmap='RdYlGn') \
                            .background_gradient(subset=['Precision'], cmap='RdYlGn') \
                            .background_gradient(subset=['F1 Score'], cmap='RdYlGn') \
                            .background_gradient(subset=['Genauigkeit'], cmap='RdYlGn') \
                            .format({'Trainingszeit': '{:.2f}s', 'Vorhersagezeit': '{:.3f}s', 'Recall': '{:.2%}'
                                     , 'Precision': '{:.2%}', 'F1 Score': '{:.2%}', 'Genauigkeit': '{:.2%}'})
# Out:
# <style type="text/css">
# #T_c8409_row0_col2 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_c8409_row0_col3, #T_c8409_row1_col2, #T_c8409_row2_col3, #T_c8409_row5_col4, #T_c8409_row5_col5, #T_c8409_row5_col7, #T_c8409_row6_col4, #T_c8409_row6_col5, #T_c8409_row6_col7, #T_c8409_row7_col4, #T_c8409_row7_col5, #T_c8409_row7_col7, #T_c8409_row8_col4, #T_c8409_row8_col5, #T_c8409_row8_col7, #T_c8409_row9_col4, #T_c8409_row9_col5, #T_c8409_row9_col7, #T_c8409_row10_col4, #T_c8409_row10_col5, #T_c8409_row10_col7, #T_c8409_row11_col4, #T_c8409_row11_col5, #T_c8409_row11_col7, #T_c8409_row14_col6, #T_c8409_row16_col4, #T_c8409_row16_col5, #T_c8409_row16_col6, #T_c8409_row16_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c8409_row0_col4 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_c8409_row0_col5, #T_c8409_row0_col7 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_c8409_row0_col6 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_c8409_row1_col3, #T_c8409_row11_col2, #T_c8409_row12_col2, #T_c8409_row13_col5, #T_c8409_row13_col6, #T_c8409_row13_col7, #T_c8409_row15_col4, #T_c8409_row15_col5, #T_c8409_row15_col6, #T_c8409_row15_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c8409_row1_col4, #T_c8409_row1_col5, #T_c8409_row1_col7 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_c8409_row1_col6 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_c8409_row2_col2, #T_c8409_row4_col4, #T_c8409_row4_col5, #T_c8409_row4_col7 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_c8409_row2_col4, #T_c8409_row2_col5, #T_c8409_row2_col7, #T_c8409_row5_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_c8409_row2_col6 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_c8409_row3_col2, #T_c8409_row13_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_c8409_row3_col3, #T_c8409_row4_col3 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_c8409_row3_col4, #T_c8409_row3_col5, #T_c8409_row3_col7 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_c8409_row3_col6 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_c8409_row4_col2, #T_c8409_row13_col2, #T_c8409_row14_col2 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_c8409_row4_col6 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_c8409_row5_col2 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_c8409_row5_col6, #T_c8409_row6_col6, #T_c8409_row7_col6, #T_c8409_row8_col6, #T_c8409_row9_col6, #T_c8409_row10_col6, #T_c8409_row11_col6 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_c8409_row6_col2 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_c8409_row6_col3 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_c8409_row7_col2 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_c8409_row7_col3 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_c8409_row8_col2 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_c8409_row8_col3 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_c8409_row9_col2 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_c8409_row9_col3 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_c8409_row10_col2 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_c8409_row10_col3 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_c8409_row11_col3, #T_c8409_row12_col3 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_c8409_row12_col4 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_c8409_row12_col5 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_c8409_row12_col6 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_c8409_row12_col7 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_c8409_row13_col4 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_c8409_row14_col3, #T_c8409_row14_col4 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_c8409_row14_col5, #T_c8409_row14_col7, #T_c8409_row15_col3 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_c8409_row15_col2, #T_c8409_row16_col2 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_c8409_row16_col3 {
#   background-color: #9bd469;
#   color: #000000;
# }
# </style>
# <table id="T_c8409">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8409_level0_col0" class="col_heading level0 col0" >Modell</th>
#       <th id="T_c8409_level0_col1" class="col_heading level0 col1" >Parameter</th>
#       <th id="T_c8409_level0_col2" class="col_heading level0 col2" >Trainingszeit</th>
#       <th id="T_c8409_level0_col3" class="col_heading level0 col3" >Vorhersagezeit</th>
#       <th id="T_c8409_level0_col4" class="col_heading level0 col4" >Genauigkeit</th>
#       <th id="T_c8409_level0_col5" class="col_heading level0 col5" >Recall</th>
#       <th id="T_c8409_level0_col6" class="col_heading level0 col6" >Precision</th>
#       <th id="T_c8409_level0_col7" class="col_heading level0 col7" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8409_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8409_row0_col0" class="data row0 col0" >Logistische Regression</td>
#       <td id="T_c8409_row0_col1" class="data row0 col1" >{'max_iter': 5000, 'solver': 'newton-cg'}</td>
#       <td id="T_c8409_row0_col2" class="data row0 col2" >19.61s</td>
#       <td id="T_c8409_row0_col3" class="data row0 col3" >0.006s</td>
#       <td id="T_c8409_row0_col4" class="data row0 col4" >91.35%</td>
#       <td id="T_c8409_row0_col5" class="data row0 col5" >91.35%</td>
#       <td id="T_c8409_row0_col6" class="data row0 col6" >91.38%</td>
#       <td id="T_c8409_row0_col7" class="data row0 col7" >91.25%</td>
#     </tr>
#     <tr>
#       <th id="T_c8409_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8409_row1_col0" class="data row1 col0" >k-NN</td>
#       <td id="T_c8409_row1_col1" class="data row1 col1" >{'leaf_size': 10, 'n_neighbors': 7}</td>
#       <td id="T_c8409_row1_col2" class="data row1 col2" >0.02s</td>
#       <td id="T_c8409_row1_col3" class="data row1 col3" >18.996s</td>
#       <td id="T_c8409_row1_col4" class="data row1 col4" >93.19%</td>
#       <td id="T_c8409_row1_col5" class="data row1 col5" >93.19%</td>
#       <td id="T_c8409_row1_col6" class="data row1 col6" >93.22%</td>
#       <td id="T_c8409_row1_col7" class="data row1 col7" >93.20%</td>
#     </tr>
#     <tr>
#       <th id="T_c8409_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8409_row2_col0" class="data row2 col0" >Entscheidungsbaum</td>
#       <td id="T_c8409_row2_col1" class="data row2 col1" >{'max_depth': 13, 'min_samples_leaf': 7, 'min_samples_split': 5}</td>
#       <td id="T_c8409_row2_col2" class="data row2 col2" >3.85s</td>
#       <td id="T_c8409_row2_col3" class="data row2 col3" >0.010s</td>
#       <td id="T_c8409_row2_col4" class="data row2 col4" >93.65%</td>
#       <td id="T_c8409_row2_col5" class="data row2 col5" >93.65%</td>
#       <td id="T_c8409_row2_col6" class="data row2 col6" >93.70%</td>
#       <td id="T_c8409_row2_col7" class="data row2 col7" >93.67%</td>
#     </tr>
#     <tr>
#       <th id="T_c8409_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8409_row3_col0" class="data row3 col0" >Extra Trees</td>
#       <td id="T_c8409_row3_col1" class="data row3 col1" >{'max_depth': 13, 'n_estimators': 200}</td>
#       <td id="T_c8409_row3_col2" class="data row3 col2" >39.94s</td>
#       <td id="T_c8409_row3_col3" class="data row3 col3" >0.822s</td>
#       <td id="T_c8409_row3_col4" class="data row3 col4" >91.84%</td>
#       <td id="T_c8409_row3_col5" class="data row3 col5" >91.84%</td>
#       <td id="T_c8409_row3_col6" class="data row3 col6" >92.20%</td>
#       <td id="T_c8409_row3_col7" class="data row3 col7" >91.66%</td>
#     </tr>
#     <tr>
#       <th id="T_c8409_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8409_row4_col0" class="data row4 col0" >Random Forest</td>
#       <td id="T_c8409_row4_col1" class="data row4 col1" >{'max_depth': 13, 'n_estimators': 200}</td>
#       <td id="T_c8409_row4_col2" class="data row4 col2" >83.53s</td>
#       <td id="T_c8409_row4_col3" class="data row4 col3"

# %%
df_results_all = pd.read_csv('./data/df_results.csv')

# %%
df_results_all.style.background_gradient(subset=['Trainingszeit'], cmap='RdYlGn_r') \
                            .background_gradient(subset=['Vorhersagezeit'], cmap='RdYlGn_r') \
                            .background_gradient(subset=['Recall'], cmap='RdYlGn') \
                            .background_gradient(subset=['Precision'], cmap='RdYlGn') \
                            .background_gradient(subset=['F1 Score'], cmap='RdYlGn') \
                            .background_gradient(subset=['Genauigkeit'], cmap='RdYlGn') \
                            .format({'Trainingszeit': '{:.2f}s', 'Vorhersagezeit': '{:.3f}s', 'Recall': '{:.2%}'
                                     , 'Precision': '{:.2%}', 'F1 Score': '{:.2%}', 'Genauigkeit': '{:.2%}'})
# Out:
# <style type="text/css">
# #T_ce954_row0_col2 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_ce954_row0_col3, #T_ce954_row5_col2, #T_ce954_row6_col2, #T_ce954_row7_col5, #T_ce954_row7_col6, #T_ce954_row7_col7, #T_ce954_row9_col4, #T_ce954_row9_col5, #T_ce954_row9_col6, #T_ce954_row9_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ce954_row0_col4, #T_ce954_row0_col5, #T_ce954_row0_col7, #T_ce954_row1_col4, #T_ce954_row1_col5, #T_ce954_row1_col7, #T_ce954_row2_col4, #T_ce954_row2_col5, #T_ce954_row2_col7, #T_ce954_row3_col4, #T_ce954_row3_col5, #T_ce954_row3_col7, #T_ce954_row4_col4, #T_ce954_row4_col5, #T_ce954_row4_col7, #T_ce954_row5_col4, #T_ce954_row5_col5, #T_ce954_row5_col7, #T_ce954_row7_col2, #T_ce954_row7_col3, #T_ce954_row8_col2, #T_ce954_row8_col6, #T_ce954_row10_col4, #T_ce954_row10_col5, #T_ce954_row10_col6, #T_ce954_row10_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ce954_row0_col6, #T_ce954_row1_col6, #T_ce954_row2_col6, #T_ce954_row3_col6, #T_ce954_row4_col6, #T_ce954_row5_col6 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_ce954_row1_col2 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_ce954_row1_col3 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_ce954_row2_col2 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_ce954_row2_col3 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_ce954_row3_col2 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_ce954_row3_col3 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_ce954_row4_col2 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_ce954_row4_col3 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_ce954_row5_col3, #T_ce954_row6_col3, #T_ce954_row6_col7 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_ce954_row6_col4 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_ce954_row6_col5 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_ce954_row6_col6 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_ce954_row7_col4 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_ce954_row8_col3 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_ce954_row8_col4 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_ce954_row8_col5, #T_ce954_row8_col7 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_ce954_row9_col2, #T_ce954_row10_col2 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_ce954_row9_col3 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_ce954_row10_col3 {
#   background-color: #fdb163;
#   color: #000000;
# }
# </style>
# <table id="T_ce954">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce954_level0_col0" class="col_heading level0 col0" >Modell</th>
#       <th id="T_ce954_level0_col1" class="col_heading level0 col1" >Parameter</th>
#       <th id="T_ce954_level0_col2" class="col_heading level0 col2" >Trainingszeit</th>
#       <th id="T_ce954_level0_col3" class="col_heading level0 col3" >Vorhersagezeit</th>
#       <th id="T_ce954_level0_col4" class="col_heading level0 col4" >Genauigkeit</th>
#       <th id="T_ce954_level0_col5" class="col_heading level0 col5" >Recall</th>
#       <th id="T_ce954_level0_col6" class="col_heading level0 col6" >Precision</th>
#       <th id="T_ce954_level0_col7" class="col_heading level0 col7" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce954_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce954_row0_col0" class="data row0 col0" >LSTM_3</td>
#       <td id="T_ce954_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_ce954_row0_col2" class="data row0 col2" >312.50s</td>
#       <td id="T_ce954_row0_col3" class="data row0 col3" >7.393s</td>
#       <td id="T_ce954_row0_col4" class="data row0 col4" >94.37%</td>
#       <td id="T_ce954_row0_col5" class="data row0 col5" >94.37%</td>
#       <td id="T_ce954_row0_col6" class="data row0 col6" >94.42%</td>
#       <td id="T_ce954_row0_col7" class="data row0 col7" >94.38%</td>
#     </tr>
#     <tr>
#       <th id="T_ce954_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce954_row1_col0" class="data row1 col0" >GRU_3</td>
#       <td id="T_ce954_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_ce954_row1_col2" class="data row1 col2" >255.39s</td>
#       <td id="T_ce954_row1_col3" class="data row1 col3" >5.973s</td>
#       <td id="T_ce954_row1_col4" class="data row1 col4" >94.45%</td>
#       <td id="T_ce954_row1_col5" class="data row1 col5" >94.45%</td>
#       <td id="T_ce954_row1_col6" class="data row1 col6" >94.45%</td>
#       <td id="T_ce954_row1_col7" class="data row1 col7" >94.45%</td>
#     </tr>
#     <tr>
#       <th id="T_ce954_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce954_row2_col0" class="data row2 col0" >Autoencoder_11</td>
#       <td id="T_ce954_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_ce954_row2_col2" class="data row2 col2" >147.38s</td>
#       <td id="T_ce954_row2_col3" class="data row2 col3" >4.302s</td>
#       <td id="T_ce954_row2_col4" class="data row2 col4" >94.31%</td>
#       <td id="T_ce954_row2_col5" class="data row2 col5" >94.31%</td>
#       <td id="T_ce954_row2_col6" class="data row2 col6" >94.37%</td>
#       <td id="T_ce954_row2_col7" class="data row2 col7" >94.33%</td>
#     </tr>
#     <tr>
#       <th id="T_ce954_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce954_row3_col0" class="data row3 col0" >ConvolutionalAutoencoder_6</td>
#       <td id="T_ce954_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_ce954_row3_col2" class="data row3 col2" >138.51s</td>
#       <td id="T_ce954_row3_col3" class="data row3 col3" >3.287s</td>
#       <td id="T_ce954_row3_col4" class="data row3 col4" >94.34%</td>
#       <td id="T_ce954_row3_col5" class="data row3 col5" >94.34%</td>
#       <td id="T_ce954_row3_col6" class="data row3 col6" >94.33%</td>
#       <td id="T_ce954_row3_col7" class="data row3 col7" >94.33%</td>
#     </tr>
#     <tr>
#       <th id="T_ce954_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce954_row4_col0" class="data row4 col0" >SparseAutoencoder_6</td>
#       <td id="T_ce954_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_ce954_row4_col2" class="data row4 col2" >172.92s</td>
#       <td id="T_ce954_row4_col3" class="data row4 col3" >4.105s</td>
#       <td id="T_ce954_row4_col4" class="data row4 col4" >94.23%</td>
#       <td id="T_ce954_row4_col5" class="data row4 col5" >94.23%</td>
#       <td id="T_ce954_row4_col6" class="data row4 col6" >94.23%</td>
#       <td id="T_ce954_row4_col7" class="data row4 col7" >94.23%</td>
#     </tr>
#     <tr>
#       <th id="T_ce954_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce954_row5_col0" class="data row5 col0" >SAE_Class</td>
#       <td id="T_ce954_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_ce954_row5_col2" class="data row5 col2" >831.80s</td>
#       <td id="T_ce954_row5_col3" class="data row5 col3" >3.886s</td>
#       <td id="T_ce954_row5_col4" class="data row5 col4" >94.26%</td>
#       <td id="T_ce954_row5_col5" class="data row5 col5" >94.26%</td>
#       <td id="T_ce954_row5_col6" class="data row5 col6" >94.33%</td>
#       <td id="T_ce954_row5_col7" class="data row5 col7" >94.28%</td>
#     </tr>
#     <tr>
#       <th id="T_ce954_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce954_row6_col0" class="data row6 col0" >SAE_Decode</td>
#       <td id="T_ce954_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_ce954_row6_col2" class="data row6 col2" >831.80s</td>
#       <td id="T_ce954_row6_col3" class="data row6 col3" >3.886s</td>
#       <td id="T_ce954_row6_col4" class="data row6 col4" >58.64%</td>
#       <td id="T_ce954_row6_col5" class="data row6 col5" >58.64%</td>
#       <td id="T_ce954_row6_col6" class="data row6 col6" >49.30%</td>
#       <td id="T_ce954_row6_col7" class="data row6 col7" >50.92%</td>
#     </tr>
#     <tr>
#       <th id="T_ce954_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce954_row7_col0" class="data row7 col0" >sparse_autoe

# %%
df_results = df_results.sort_values(by='Accuracy', ascending=False)

plt.figure(figsize=(10, 6))
accuracy_plot = sns.barplot(x='Model', y='Accuracy', hue='Model', data=df_results, palette=sns.color_palette("RdYlGn", n_colors=len(df_results))[::-1])
plt.title('Accuracy')

for i, p in enumerate(accuracy_plot.patches):
    accuracy_plot.annotate(f'{df_results["Accuracy"].values[i]:.3f}', 
                            (p.get_x() + p.get_width() / 2., p.get_height()), 
                            ha='center', va='center', xytext=(0, 10), 
                            textcoords='offset points')


sm = plt.cm.ScalarMappable(cmap=plt.get_cmap("RdYlGn"))
sm.set_array(df_results['Accuracy'])
cbar = plt.colorbar(sm, orientation='vertical', ax=plt.gca())
cbar.set_label('Accuracy')

plt.show()

# %%
df_results = df_results.sort_values(by='Training Time', ascending=False)

plt.figure(figsize=(10, 6))
accuracy_plot = sns.barplot(x='Model', y='Training Time', hue='Model', data=df_results, palette=sns.color_palette("RdYlGn", n_colors=len(df_results)))
plt.title('Benötigte Trainingszeit ')
plt.yscale('log')
plt.ylabel('Logarithmische Trainingszeit')
for i, p in enumerate(accuracy_plot.patches):
    accuracy_plot.annotate(f'{df_results["Training Time"].values[i]:.3f} s', 
                            (p.get_x() + p.get_width() / 2., p.get_height()), 
                            ha='center', va='center', xytext=(0, 10), 
                            textcoords='offset points')


sm = plt.cm.ScalarMappable(cmap=plt.get_cmap("RdYlGn").reversed())
sm.set_array(df_results['Training Time'])
cbar = plt.colorbar(sm, orientation='vertical', ax=plt.gca())
cbar.set_label('Trainingszeit')
plt.show()

# %%
df_results = df_results.sort_values(by='Prediction Time', ascending=False)

plt.figure(figsize=(10, 6))
accuracy_plot = sns.barplot(x='Model', y='Prediction Time', data=df_results, palette=sns.color_palette("RdYlGn", n_colors=len(df_results)))
plt.title('Dauer bis Vorhersage')
plt.yscale('log')
for i, p in enumerate(accuracy_plot.patches):
    accuracy_plot.annotate(f'{df_results["Prediction Time"].values[i]:.3f} s', 
                            (p.get_x() + p.get_width() / 2., p.get_height()), 
                            ha='center', va='center', xytext=(0, 10), 
                            textcoords='offset points')
   


sm = plt.cm.ScalarMappable(cmap=plt.get_cmap("RdYlGn").reversed())
sm.set_array(df_results['Prediction Time'])
cbar = plt.colorbar(sm, orientation='vertical', ax=plt.gca())
plt.show()

# %% [markdown]
# ## Creditcard

# %%
df_credit_train = pd.read_csv('./data/creditcard.csv')
df_credit_train.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7        V8        V9       V10       V11       V12       V13       V14       V15       V16       V17       V18       V19       V20       V21       V22       V23       V24       V25       V26       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0

# %%
df_credit_train.shape
# Out:
# (284807, 31)

# %%
df_credit_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df_credit_train.columns = map(str.lower, df_credit_train.columns)
df_credit_train.rename(columns={'class': 'label'}, inplace=True)

df_credit_train.head(5)
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7        v8        v9       v10       v11       v12       v13       v14       v15       v16       v17       v18       v19       v20       v21       v22       v23       v24       v25       v26       v27       v28  amount  label
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0

# %%
start_time = pd.to_datetime('2013-09-01')
df_credit_train['time'] = start_time + pd.to_timedelta(df_credit_train['time'], unit='s')

print(df_credit_train['time'])
# Out:
# 0        2013-09-01 00:00:00
# 1        2013-09-01 00:00:00
# 2        2013-09-01 00:00:01
# 3        2013-09-01 00:00:01
# 4        2013-09-01 00:00:02
#                  ...
# 284802   2013-09-02 23:59:46
# 284803   2013-09-02 23:59:47
# 284804   2013-09-02 23:59:48
# 284805   2013-09-02 23:59:48
# 284806   2013-09-02 23:59:52
# Name: time, Length: 284807, dtype: datetime64[ns]

# %%
df_credit_train.head(5)
# Out:
#                  time        v1        v2        v3        v4        v5        v6        v7        v8        v9       v10       v11       v12       v13       v14       v15       v16       v17       v18       v19       v20       v21       v22       v23       v24       v25       v26       v27       v28  amount  label
# 0 2013-09-01 00:00:00 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1 2013-09-01 00:00:00  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 2013-09-01 00:00:01 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3 2013-09-01 00:00:01 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 2013-09-01 00:00:02 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0

# %%
284806/2
# Out:
# 142403.0

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df_credit_train.plot(legend=False, ax=ax)
plt.show()

# %%
first_timestamp = df_credit_train['time'].min()
last_timestamp = df_credit_train['time'].max()

# %%
X = df_credit_train.iloc[:,:-1]
y = df_credit_train.iloc[:,-1]

# %%
X.columns
# Out:
# Index(['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
#        'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
#        'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount'],
#       dtype='object')

# %%
def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length + 1):
        sequence = data[i:i + sequence_length]
        sequences.append(sequence)
    return np.array(sequences)

# %%
sequence_length = 12
X_sequences = create_sequences(X.values, sequence_length)
#y_sequences = y[sequence_length - 1:]

# %% [markdown]
# ### Testing

# %%
import random as rn

# load the dataset
df = pd.read_csv('./data/creditcard.csv')


TRAINING_SAMPLE = 200000
VALIDATE_SIZE = 0.2

# %%
df.columns = map(str.lower, df.columns)
df.rename(columns={'class': 'label'}, inplace=True)

# print first 5 rows to get an initial impression of the data we're dealing with
df.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7        v8        v9       v10       v11       v12       v13       v14       v15       v16       v17       v18       v19       v20       v21       v22       v23       v24       v25       v26       v27       v28  amount  label
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0

# %%
df['log10_amount'] = np.log10(df.amount + 0.00001)

# %%
df.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7        v8        v9       v10       v11       v12       v13       v14       v15       v16       v17       v18       v19       v20       v21       v22       v23       v24       v25       v26       v27       v28  amount  label  log10_amount
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0      2.174990
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0      0.429754
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0      2.578249
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0      2.091667
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0      1.845036

# %%
# manual parameter 
RATIO_TO_FRAUD = 15

# dropping redundant columns
df = df.drop(['time', 'amount'], axis=1)

# splitting by class
fraud = df[df.label == 1]
clean = df[df.label == 0]

# undersample clean transactions
clean_undersampled = clean.sample(
    int(len(fraud) * RATIO_TO_FRAUD)
)

# concatenate with fraud transactions into a single dataframe
visualisation_initial = pd.concat([fraud, clean_undersampled])
column_names = list(visualisation_initial.drop('label', axis=1).columns)

# isolate features from labels 
features, labels = visualisation_initial.drop('label', axis=1).values, \
                   visualisation_initial.label.values

# %%
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

# %%
def tsne_scatter(features, labels, dimensions=2):
    if dimensions not in (2, 3):
        raise ValueError('tsne_scatter can only plot in 2d or 3d (What are you? An alien that can visualise >3d?). Make sure the "dimensions" argument is in (2, 3)')

    # t-SNE dimensionality reduction
    features_embedded = TSNE(n_components=dimensions).fit_transform(features)
    
    # initialising the plot
    fig, ax = plt.subplots(figsize=(8,8))
    
    # counting dimensions
    if dimensions == 3: ax = fig.add_subplot(111, projection='3d')

    # plotting data
    ax.scatter(
        *zip(*features_embedded[np.where(labels==1)]),
        marker='o',
        color='r',
        s=2,
        alpha=0.7,
        label='Fraud'
    )
    ax.scatter(
        *zip(*features_embedded[np.where(labels==0)]),
        marker='o',
        color='g',
        s=2,
        alpha=0.3,
        label='Clean'
    )

# %%
tsne_scatter(features, labels, dimensions=2)
