# %% [markdown]
# # Table of Contents
# 1. [Unsupervised Learning with Auto-Encoders](#1)
# 1. [Preprocessing](#2)
# 1. [Visualising clusters with t-SNE](#3)
# 1. [Train/Validate/Test split](#4)
# 1. [Normalising & Standardising](#5)
# 1. [Training the auto-encoder](#6)
# 1. [Reconstructions](#7)
# 1. [Setting a threshold for classification](#8)
# 1. [Latent Space ](#9)
# 1. [Conclusion](#10)

# %% [markdown]
# <a id="1"></a> <br>
# # Unsupervised Learning with Auto-Encoders
#
# If you are interested in an introduction to auto-encoders, head over to [Julien Despois' article](https://hackernoon.com/latent-space-visualization-deep-learning-bits-2-bd09a46920df).
# If a more technical breakdown is what you are looking for, check out [Lilian Weng's blog post](https://lilianweng.github.io/lil-log/2018/08/12/from-autoencoder-to-beta-vae.html) from which the below image is sourced.
# It illustrates the functioning of an auto-encoder for MNIST images, but the concept is the same.
# ![image.png](attachment:image.png)

# %% [markdown]
# The idea is quite straightforward:
# 1. Due to the **bottleneck architecture** of the neural network, it is forced to learn a **condensed representation** from which to reproduce the original input.
# 2. We feed it **only normal transactions**, which it will learn to reproduce with high fidelity.
# 3. As a consequence, if a **fraud transaction is sufficiently distinct** from normal transactions, the auto-encoder will have trouble reproducing it with its learned weights, and the subsequent **reconstruction loss will be high**.
# 4. Anything above a specific loss (treshold) will be **flagged as anomalous** and thus labeled as fraud.
#
# <a id="2"></a> <br>
# # Preprocessing
#
# ## Import Libraries & set Random Seeds

# %%
# read & manipulate data
import pandas as pd 
import numpy as np
import tensorflow as tf

# visualisations
import matplotlib.pyplot as plt
import seaborn as sns

# misc
import random as rn

# load the dataset
df = pd.read_csv('./data/creditcard.csv')

# manual parameters
RANDOM_SEED = 42
TRAINING_SAMPLE = 200000
VALIDATE_SIZE = 0.2

# setting random seeds for libraries to ensure reproducibility
np.random.seed(RANDOM_SEED)
rn.seed(RANDOM_SEED)

# %% [markdown]
# ## Renaming columns

# %%
# let's quickly convert the columns to lower case and rename the Class column 
# so as to not cause syntax errors
df.columns = map(str.lower, df.columns)
df.rename(columns={'class': 'label'}, inplace=True)

# print first 5 rows to get an initial impression of the data we're dealing with
df.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9  ...       v21       v22       v23       v24       v25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         v26       v27       v28  amount  label
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Calculated field: log10(amount)
#
# Turn the amount feature into a normally distributed log equivalent.

# %%
# add a negligible amount to avoid taking the log of 0
df['log10_amount'] = np.log10(df.amount + 0.00001)

# %%
# keep the label field at the back
df = df[
    [col for col in df if col not in ['label', 'log10_amount']] + 
    ['log10_amount', 'label']
]

# %% [markdown]
# <a id="3"></a> <br>
# # Visualising clusters with t-SNE
# *t-Distributed Stochastic Neighbor Embedding (t-SNE)*
#
# From the [sklearn documentation](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html): <br>
# > t-SNE [1] is a tool to visualize high-dimensional data. It converts similarities between data points to joint probabilities and tries to minimize the Kullback-Leibler divergence between the joint probabilities of the low-dimensional embedding and the high-dimensional data. t-SNE has a cost function that is not convex, i.e. with different initializations we can get different results.
#
# In plain English, most certainly oversimplifying matters: **t-SNE is a dimensionality reduction technique used for visualisations** of complex datasets.
# It **maps clusters in high-dimensional data** to **a two- or three dimensional plane** so we can get an idea of how easy it will be to **discriminate between classes**.
# It does this by trying to keep the distance between data points in lower dimensions proportional to the probability that these data points are neighbours in the higher dimensions.
#
# A more elaborate [introduction](https://www.datacamp.com/community/tutorials/introduction-t-sne) is available on DataCamp.

# %% [markdown]
# ## Undersampling the non-fraud
# To keep the computation time low, let's feed t-SNE only a small subsample (undersampling the clean transactions).

# %%
# manual parameter 
RATIO_TO_FRAUD = 15

# dropping redundant columns
df = df.drop(['time', 'amount'], axis=1)

# splitting by class
fraud = df[df.label == 1]
clean = df[df.label == 0]

# undersample clean transactions
clean_undersampled = clean.sample(
    int(len(fraud) * RATIO_TO_FRAUD),
    random_state=RANDOM_SEED
)

# concatenate with fraud transactions into a single dataframe
visualisation_initial = pd.concat([fraud, clean_undersampled])
column_names = list(visualisation_initial.drop('label', axis=1).columns)

# isolate features from labels 
features, labels = visualisation_initial.drop('label', axis=1).values, \
                   visualisation_initial.label.values

# %%
print(f"""The non-fraud dataset has been undersampled from {len(clean):,} to {len(clean_undersampled):,}.
This represents a ratio of {RATIO_TO_FRAUD}:1 to fraud.""")
# Out:
# The non-fraud dataset has been undersampled from 284,315 to 7,380.
# This represents a ratio of 15:1 to fraud.

# %% [markdown]
# ## t-SNE output

# %%
from sklearn.manifold import TSNE

def tsne_scatter(features, labels, dimensions=2, save_as='graph.png'):
    if dimensions not in (2, 3):
        raise ValueError('tsne_scatter can only plot in 2d or 3d (What are you? An alien that can visualise >3d?). Make sure the "dimensions" argument is in (2, 3)')

    # t-SNE dimensionality reduction
    features_embedded = TSNE(n_components=dimensions, random_state=RANDOM_SEED).fit_transform(features)
    
    # initialising the plot
    fig, ax = plt.subplots(figsize=(8,8))
    
    # counting dimensions
    if dimensions == 3: ax = fig.add_subplot(111, projection='3d')

    # plotting data
    ax.scatter(
        *zip(*features_embedded[np.where(labels==1)]),
        marker='o',
        color='r',
        s=2,
        alpha=0.7,
        label='Fraud'
    )
    ax.scatter(
        *zip(*features_embedded[np.where(labels==0)]),
        marker='o',
        color='g',
        s=2,
        alpha=0.3,
        label='Clean'
    )

    # storing it to be displayed later
    plt.legend(loc='best')
    plt.savefig(save_as);
    plt.show;

# %%
tsne_scatter(features, labels, dimensions=2, save_as='tsne_initial_2d.png')
# Out:
# <div id='3361be26-9ec1-4728-8483-8cd398adc6e3'></div>

# %% [markdown]
# Some clusters are apparent, but a minority of fraud transactions remains sneaky, sneaky.

# %% [markdown]
# <a id="4"></a> <br>
# # Train/Validate/Test split
# Our auto-encoder will **only train on transactions that were normal**.
# What's left over will be combined with the fraud set to form our test sample.
#
# We will be doing something akin to the below:
# ![image.png](attachment:image.png)
#
#
# 1. Training: only non-fraud
#     * Split into:
#         1. Actual training of our autoencoder
#         2. Validation of the neural network's ability to generalize
# 2. Testing : mix of fraud and non-fraud
#     * Treated like new data
#     * Attempt to locate outliers
#         1. Compute reconstruction loss
#         2. Apply threshold

# %%
print(f"""Shape of the datasets:
    clean (rows, cols) = {clean.shape}
    fraud (rows, cols) = {fraud.shape}""")
# Out:
# Shape of the datasets:
#     clean (rows, cols) = (284315, 30)
#     fraud (rows, cols) = (492, 30)

# %%
# shuffle our training set
clean = clean.sample(frac=1).reset_index(drop=True)

# training set: exlusively non-fraud transactions
X_train = clean.iloc[:TRAINING_SAMPLE].drop('label', axis=1)

# testing  set: the remaining non-fraud + all the fraud 
X_test = pd.concat([clean.iloc[TRAINING_SAMPLE:], fraud]).sample(frac=1)

# %%
print(f"""Our testing set is composed as follows:

{X_test.label.value_counts()}""")
# Out:
# Our testing set is composed as follows:
#
# label
# 0    84315
# 1      492
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# train // validate - no labels since they're all clean anyway
X_train, X_validate = train_test_split(X_train, 
                                       test_size=VALIDATE_SIZE, 
                                       random_state=RANDOM_SEED)

# manually splitting the labels from the test df
X_test, y_test = X_test.drop('label', axis=1).values, X_test.label.values

# %% [markdown]
# ## Summary

# %%
print(f"""Shape of the datasets:
    training (rows, cols) = {X_train.shape}
    validate (rows, cols) = {X_validate.shape}
    holdout  (rows, cols) = {X_test.shape}""")
# Out:
# Shape of the datasets:
#     training (rows, cols) = (160000, 29)
#     validate (rows, cols) = (40000, 29)
#     holdout  (rows, cols) = (84807, 29)

# %% [markdown]
# <a id="5"></a> <br>
# # Normalising & Standardising
#
# ## Why
# In an [excellent article by Jeremy Jordan](https://www.jeremyjordan.me/batch-normalization/), it is explained why making sure your data is normally distributed can **help stochastic gradient descent converge** more effectively.
# In a nutshell:
# ![image.png](attachment:image.png)
#
#
# ## When
# At what point in the data processing do we apply standardisation/normalisation? <br>
# An [excellent answer was provided on StackOverflow](https://stackoverflow.com/questions/49444262/normalize-data-before-or-after-split-of-training-and-testing-data).
#
# > Don't forget that **testing data points represent real-world data**. Feature normalization (or data standardization) of the explanatory (or predictor) variables is a technique used to center and normalise the data by subtracting the mean and dividing by the variance. **If you take the mean and variance of the whole dataset you'll be introducing future information into the training explanatory variables** (i.e. the mean and variance).
# >
# > Therefore, you should **perform feature normalisation over the training data**. Then **perform normalisation on testing **instances as well, but this time **using the mean and variance of training** explanatory variables. In this way, we can test and evaluate whether our model can generalize well to new, unseen data points.
# >
# > <span style="font-size:10px">[Answer by [Giorgos Myrianthous](https://stackoverflow.com/users/7131757/giorgos-myrianthous)]</span>

# %% [markdown]
# ## Building our pipeline

# %%
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn.pipeline import Pipeline

# configure our pipeline
pipeline = Pipeline([('normalizer', Normalizer()),
                     ('scaler', MinMaxScaler())])

# %% [markdown]
# ## Fitting the pipeline

# %%
# get normalization parameters by fitting to the training data
pipeline.fit(X_train)
# Out:
# Pipeline(steps=[('normalizer', Normalizer()), ('scaler', MinMaxScaler())])

# %% [markdown]
# ## Applying transformations with acquired parameters

# %%
# transform the training and validation data with these parameters
X_train_transformed = pipeline.transform(X_train)
X_validate_transformed = pipeline.transform(X_validate)

# %% [markdown]
# ## Before & After

# %%
g = sns.PairGrid(X_train.iloc[:,:3].sample(600, random_state=RANDOM_SEED))
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Before:')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)
# Out:
# <div id='96ba45a9-a2ed-436a-a419-6962d9a6babb'></div>

# %%
g = sns.PairGrid(pd.DataFrame(X_train_transformed, columns=column_names).iloc[:,:3].sample(600, random_state=RANDOM_SEED))
plt.subplots_adjust(top=0.9)
g.fig.suptitle('After:')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)

# %% [markdown]
# We can tell the data is slightly more **uniform and proportionally distributed**. <br>
# The ranges were also shrunk to fit **between 0 and 1**.

# %% [markdown]
# <a id="6"></a> <br>
# # Training the auto-encoder

# %% [markdown]
# ## TensorBoard
# As documented in [this kernel by Aurelio Agundez](https://www.kaggle.com/aagundez/using-tensorboard-in-kaggle-kernels), TensorBoard requires a running kernel, so its output will only be available in an editor session.
# Fork this notebook if you wish to interact with it.

# %% [markdown]
# ## Architecture of our model
# Keras has become the standard high-level API within Tensorflow. No surprise, it's awesome.
# Check out their [blog post on the topic of autoencoders](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, GRU, Dropout
from keras import layers
import keras 
from numpy import array
import tensorflow as tf
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix

# %%
# data dimensions // hyperparameters 
input_dim = X_train_transformed.shape[1]
BATCH_SIZE = 256
EPOCHS = 100

# %%
class AnomalyDetector(Model):
    def __init__(self, name="AnomalyDetector"):
        super(AnomalyDetector, self).__init__(name=name)
        self.encoder = tf.keras.Sequential([
            layers.Dense(256, activation="relu"),
            layers.Dense(128, activation="relu")],
            name="encoder")
        
        self.decoder = tf.keras.Sequential([
            layers.Dense(128, activation="relu"),
            layers.Dense(input_dim, activation="sigmoid")],
            name="decoder")

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

model_autoencoder = AnomalyDetector(name="Autoencoder")
opt = keras.optimizers.Adam(learning_rate=0.001)

# %%
model_autoencoder.compile(optimizer=opt, 
                    loss="mse",
                    metrics=["acc"])

# %%
history = model_autoencoder.fit(
    X_train_transformed, X_train_transformed,
    shuffle=True,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_validate_transformed, X_validate_transformed)
)
# Out:
# Epoch 1/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.0030 - acc: 0.7228 - val_loss: 1.9917e-04 - val_acc: 0.9108
# Epoch 2/100
# 625/625 [==============================] - 2s 3ms/step - loss: 1.4997e-04 - acc: 0.9221 - val_loss: 1.0737e-04 - val_acc: 0.9211
# Epoch 3/100
# 625/625 [==============================] - 2s 3ms/step - loss: 9.6112e-05 - acc: 0.9291 - val_loss: 8.7164e-05 - val_acc: 0.9323
# Epoch 4/100
# 625/625 [==============================] - 2s 3ms/step - loss: 8.5766e-05 - acc: 0.9296 - val_loss: 8.6445e-05 - val_acc: 0.9208
# Epoch 5/100
# 625/625 [==============================] - 2s 3ms/step - loss: 8.2505e-05 - acc: 0.9301 - val_loss: 7.7439e-05 - val_acc: 0.9365
# Epoch 6/100
# 625/625 [==============================] - 2s 3ms/step - loss: 7.9267e-05 - acc: 0.9306 - val_loss: 7.3806e-05 - val_acc: 0.9355
# Epoch 7/100
# 625/625 [==============================] - 2s 3ms/step - loss: 7.6153e-05 - acc: 0.9322 - val_loss: 7.8508e-05 - val_acc: 0.9297
# Epoch 8/100
# 625/625 [==============================] - 2s 3ms/step - loss: 7.4481e-05 - acc: 0.9335 - val_loss: 7.4919e-05 - val_acc: 0.9288
# Epoch 9/100
# 625/625 [==============================] - 2s 3ms/step - loss: 7.2475e-05 - acc: 0.9328 - val_loss: 6.6300e-05 - val_acc: 0.9343
# Epoch 10/100
# 625/625 [==============================] - 2s 3ms/step - loss: 7.1745e-05 - acc: 0.9330 - val_loss: 6.8623e-05 - val_acc: 0.9345
# Epoch 11/100
# 625/625 [==============================] - 2s 3ms/step - loss: 7.0402e-05 - acc: 0.9337 - val_loss: 6.8346e-05 - val_acc: 0.9286
# Epoch 12/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.7970e-05 - acc: 0.9347 - val_loss: 6.6936e-05 - val_acc: 0.9321
# Epoch 13/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.6923e-05 - acc: 0.9331 - val_loss: 6.4077e-05 - val_acc: 0.9390
# Epoch 14/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.5107e-05 - acc: 0.9308 - val_loss: 6.0316e-05 - val_acc: 0.9282
# Epoch 15/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.4759e-05 - acc: 0.9305 - val_loss: 5.9851e-05 - val_acc: 0.9277
# Epoch 16/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.4424e-05 - acc: 0.9302 - val_loss: 6.9382e-05 - val_acc: 0.9328
# Epoch 17/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.3981e-05 - acc: 0.9305 - val_loss: 6.6895e-05 - val_acc: 0.9277
# Epoch 18/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.3467e-05 - acc: 0.9305 - val_loss: 6.2333e-05 - val_acc: 0.9253
# Epoch 19/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.3439e-05 - acc: 0.9304 - val_loss: 6.8016e-05 - val_acc: 0.9303
# Epoch 20/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.3049e-05 - acc: 0.9308 - val_loss: 6.0756e-05 - val_acc: 0.9242
# Epoch 21/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.2562e-05 - acc: 0.9301 - val_loss: 6.1968e-05 - val_acc: 0.9348
# Epoch 22/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.1688e-05 - acc: 0.9299 - val_loss: 5.8953e-05 - val_acc: 0.9272
# Epoch 23/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.1785e-05 - acc: 0.9287 - val_loss: 6.5970e-05 - val_acc: 0.9282
# Epoch 24/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.0994e-05 - acc: 0.9288 - val_loss: 6.0243e-05 - val_acc: 0.9247
# Epoch 25/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.0145e-05 - acc: 0.9279 - val_loss: 6.0881e-05 - val_acc: 0.9293
# Epoch 26/100
# 625/625 [==============================] - 2s 3ms/step - loss: 6.0126e-05 - acc: 0.9275 - val_loss: 6.0044e-05 - val_acc: 0.9264
# Epoch 27/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.9903e-05 - acc: 0.9274 - val_loss: 6.0676e-05 - val_acc: 0.9204
# Epoch 28/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.9765e-05 - acc: 0.9276 - val_loss: 5.8357e-05 - val_acc: 0.9239
# Epoch 29/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.9557e-05 - acc: 0.9267 - val_loss: 6.2167e-05 - val_acc: 0.9227
# Epoch 30/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.9249e-05 - acc: 0.9274 - val_loss: 6.6973e-05 - val_acc: 0.9232
# Epoch 31/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.8214e-05 - acc: 0.9279 - val_loss: 6.0753e-05 - val_acc: 0.9281
# Epoch 32/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.5983e-05 - acc: 0.9295 - val_loss: 5.3857e-05 - val_acc: 0.9272
# Epoch 33/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.5565e-05 - acc: 0.9292 - val_loss: 5.9166e-05 - val_acc: 0.9322
# Epoch 34/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.5208e-05 - acc: 0.9296 - val_loss: 5.3604e-05 - val_acc: 0.9301
# Epoch 35/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.4430e-05 - acc: 0.9302 - val_loss: 5.4181e-05 - val_acc: 0.9269
# Epoch 36/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.4389e-05 - acc: 0.9301 - val_loss: 5.6873e-05 - val_acc: 0.9279
# Epoch 37/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.4746e-05 - acc: 0.9304 - val_loss: 5.0670e-05 - val_acc: 0.9302
# Epoch 38/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.4178e-05 - acc: 0.9309 - val_loss: 5.3865e-05 - val_acc: 0.9350
# Epoch 39/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.3940e-05 - acc: 0.9308 - val_loss: 5.7537e-05 - val_acc: 0.9297
# Epoch 40/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.3901e-05 - acc: 0.9311 - val_loss: 5.2590e-05 - val_acc: 0.9278
# Epoch 41/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.3964e-05 - acc: 0.9304 - val_loss: 5.5045e-05 - val_acc: 0.9381
# Epoch 42/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.3584e-05 - acc: 0.9313 - val_loss: 5.4420e-05 - val_acc: 0.9341
# Epoch 43/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.3458e-05 - acc: 0.9311 - val_loss: 5.3912e-05 - val_acc: 0.9289
# Epoch 44/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.3057e-05 - acc: 0.9308 - val_loss: 5.9010e-05 - val_acc: 0.9324
# Epoch 45/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.2791e-05 - acc: 0.9306 - val_loss: 5.0041e-05 - val_acc: 0.9327
# Epoch 46/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.2421e-05 - acc: 0.9314 - val_loss: 5.4267e-05 - val_acc: 0.9287
# Epoch 47/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.1835e-05 - acc: 0.9307 - val_loss: 4.9764e-05 - val_acc: 0.9245
# Epoch 48/100
# 625/625 [==============================] - 2s 3ms/step - loss: 5.0613e-05 - acc: 0.9294 - val_loss: 4.6940e-05 - val_acc: 0.9286
# Epoch 49/100
# 625/625 [==============================] - 2s 2ms/step - loss: 5.0445e-05 - acc: 0.9285 - val_loss: 4.9265e-05 - val_acc: 0.9316
# Epoch 50/100
# 625/625 [==============================] - 2s 2ms/step - loss: 4.9263e-05 - acc: 0.9285 - val_loss: 4.8992e-05 - val_acc: 0.9376
# Epoch 51/100
# 625/625 [==============================] - 2s 2ms/step - loss: 4.8206e-05 - acc: 0.9281 - val_loss: 4.7348e-05 - val_acc: 0.9342
# Epoch 52/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.7763e-05 - acc: 0.9303 - val_loss: 4.6303e-05 - val_acc: 0.9301
# Epoch 53/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.6929e-05 - acc: 0.9315 - val_loss: 4.5277e-05 - val_acc: 0.9388
# Epoch 54/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.5948e-05 - acc: 0.9328 - val_loss: 4.3522e-05 - val_acc: 0.9342
# Epoch 55/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.5966e-05 - acc: 0.9333 - val_loss: 4.4599e-05 - val_acc: 0.9355
# Epoch 56/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.5374e-05 - acc: 0.9337 - val_loss: 4.2443e-05 - val_acc: 0.9346
# Epoch 57/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.5184e-05 - acc: 0.9350 - val_loss: 4.6554e-05 - val_acc: 0.9365
# Epoch 58/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.5285e-05 - acc: 0.9347 - val_loss: 4.5706e-05 - val_acc: 0.9386
# Epoch 59/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.5142e-05 - acc: 0.9347 - val_loss: 4.4699e-05 - val_acc: 0.9419
# Epoch 60/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.4860e-05 - acc: 0.9351 - val_loss: 4.4076e-05 - val_acc: 0.9399
# Epoch 61/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.4839e-05 - acc: 0.9348 - val_loss: 4.6044e-05 - val_acc: 0.9353
# Epoch 62/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.4483e-05 - acc: 0.9356 - val_loss: 4.5393e-05 - val_acc: 0.9338
# Epoch 63/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.3575e-05 - acc: 0.9371 - val_loss: 4.5380e-05 - val_acc: 0.9399
# Epoch 64/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.3143e-05 - acc: 0.9378 - val_loss: 4.3622e-05 - val_acc: 0.9380
# Epoch 65/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.3001e-05 - acc: 0.9379 - val_loss: 4.6082e-05 - val_acc: 0.9406
# Epoch 66/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.2190e-05 - acc: 0.9392 - val_loss: 4.0454e-05 - val_acc: 0.9428
# Epoch 67/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.1944e-05 - acc: 0.9388 - val_loss: 4.1191e-05 - val_acc: 0.9401
# Epoch 68/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.1586e-05 - acc: 0.9395 - val_loss: 4.3259e-05 - val_acc: 0.9363
# Epoch 69/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.1511e-05 - acc: 0.9388 - val_loss: 4.3175e-05 - val_acc: 0.9362
# Epoch 70/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.1528e-05 - acc: 0.9388 - val_loss: 3.8940e-05 - val_acc: 0.9377
# Epoch 71/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.1104e-05 - acc: 0.9391 - val_loss: 4.3266e-05 - val_acc: 0.9380
# Epoch 72/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.1316e-05 - acc: 0.9390 - val_loss: 4.1466e-05 - val_acc: 0.9378
# Epoch 73/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.0745e-05 - acc: 0.9391 - val_loss: 4.1587e-05 - val_acc: 0.9411
# Epoch 74/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.0891e-05 - acc: 0.9395 - val_loss: 3.9468e-05 - val_acc: 0.9432
# Epoch 75/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.1090e-05 - acc: 0.9396 - val_loss: 3.9861e-05 - val_acc: 0.9413
# Epoch 76/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.0535e-05 - acc: 0.9395 - val_loss: 4.3457e-05 - val_acc: 0.9413
# Epoch 77/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.0763e-05 - acc: 0.9395 - val_loss: 4.4836e-05 - val_acc: 0.9366
# Epoch 78/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.0284e-05 - acc: 0.9399 - val_loss: 3.9397e-05 - val_acc: 0.9408
# Epoch 79/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.0067e-05 - acc: 0.9397 - val_loss: 4.5036e-05 - val_acc: 0.9382
# Epoch 80/100
# 625/625 [==============================] - 2s 3ms/step - loss: 4.0446e-05 - acc: 0.9402 - val_loss: 4.3164e-05 - val_acc: 0.9413
# Epoch 81/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.9652e-05 - acc: 0.9400 - val_loss: 3.9192e-05 - val_acc: 0.9423
# Epoch 82/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.9201e-05 - acc: 0.9403 - val_loss: 4.0286e-05 - val_acc: 0.9391
# Epoch 83/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.8807e-05 - acc: 0.9407 - val_loss: 4.0406e-05 - val_acc: 0.9409
# Epoch 84/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.8352e-05 - acc: 0.9409 - val_loss: 4.1698e-05 - val_acc: 0.9409
# Epoch 85/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.8510e-05 - acc: 0.9406 - val_loss: 4.0929e-05 - val_acc: 0.9366
# Epoch 86/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.7817e-05 - acc: 0.9410 - val_loss: 4.1033e-05 - val_acc: 0.9421
# Epoch 87/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.8036e-05 - acc: 0.9408 - val_loss: 4.0651e-05 - val_acc: 0.9390
# Epoch 88/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.7791e-05 - acc: 0.9409 - val_loss: 3.7094e-05 - val_acc: 0.9433
# Epoch 89/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.7435e-05 - acc: 0.9409 - val_loss: 3.9084e-05 - val_acc: 0.9364
# Epoch 90/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.7472e-05 - acc: 0.9410 - val_loss: 3.4396e-05 - val_acc: 0.9410
# Epoch 91/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.7513e-05 - acc: 0.9414 - val_loss: 3.7691e-05 - val_acc: 0.9392
# Epoch 92/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.7031e-05 - acc: 0.9419 - val_loss: 4.0558e-05 - val_acc: 0.9370
# Epoch 93/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.7273e-05 - acc: 0.9418 - val_loss: 3.7455e-05 - val_acc: 0.9414
# Epoch 94/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.6640e-05 - acc: 0.9426 - val_loss: 3.6943e-05 - val_acc: 0.9426
# Epoch 95/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.6274e-05 - acc: 0.9419 - val_loss: 3.7399e-05 - val_acc: 0.9413
# Epoch 96/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5452e-05 - acc: 0.9426 - val_loss: 3.4080e-05 - val_acc: 0.9414
# Epoch 97/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5814e-05 - acc: 0.9431 - val_loss: 3.8350e-05 - val_acc: 0.9434
# Epoch 98/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5514e-05 - acc: 0.9434 - val_loss: 3.7210e-05 - val_acc: 0.9423
# Epoch 99/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5617e-05 - acc: 0.9432 - val_loss: 3.7728e-05 - val_acc: 0.9380
# Epoch 100/100
# 625/625 [==============================] - 2s 3ms/step - loss: 3.5391e-05 - acc: 0.9432 - val_loss: 3.5836e-05 - val_acc: 0.9393

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = model_autoencoder.predict(X_test_transformed)
# Out:
#   48/2651 [..............................] - ETA: 2s
# c:\Users\Alexej\miniconda3\envs\simple-htr-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but Normalizer was fitted with feature names
#   warnings.warn(
# 2651/2651 [==============================] - 3s 1ms/step

# %%
# calculating the mean squared error reconstruction loss per row in the numpy array
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
clean = mse[y_test==0]
fraud = mse[y_test==1]

fig, ax = plt.subplots(figsize=(6,6))

ax.hist(clean, bins=50, density=True, label="clean", alpha=.6, color="green")
ax.hist(fraud, bins=50, density=True, label="fraud", alpha=.6, color="red")

plt.title("(Normalized) Distribution of the Reconstruction Loss")
plt.legend()
plt.show()
# Out:
# <div id='2baf41e4-0d57-4eb5-9982-bfb0bb74bd01'></div>

# %%
# Helper function to calculate the accuracy
def evaluate_model(model, X, y_true, print_output=True, number_of_outputs=1):
    if number_of_outputs == 1:
        y_pred = model.predict(X)
    else:
        _, y_pred = model.predict(X)
        
    y_pred_classes = y_pred.argmax(axis=-1)
    accuracy = accuracy_score(y_true, y_pred_classes)
    recall = recall_score(y_true, y_pred_classes, average='weighted')
    precision = precision_score(y_true, y_pred_classes, average='weighted')
    f1 = f1_score(y_true, y_pred_classes, average='weighted')
    
    end_predict = time.time()
    
    if print_output:
        print("Modell:",model.name)
        print("Genauigkeit:", accuracy)
        print("Recall:", recall)
        print("Precision:", precision)
        print("F1 Score:", f1)
        
    return accuracy, recall, precision, f1, end_predict

# %%
# https://keras.io/layers/core/
autoencoder = tf.keras.models.Sequential([
    
    # deconstruct / encode
    tf.keras.layers.Dense(input_dim, activation='elu', input_shape=(input_dim, )), 
    tf.keras.layers.Dense(16, activation='elu'),
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(4, activation='elu'),
    tf.keras.layers.Dense(2, activation='elu'),
    
    # reconstruction / decode
    tf.keras.layers.Dense(4, activation='elu'),
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(16, activation='elu'),
    tf.keras.layers.Dense(input_dim, activation='elu')
    
])

# https://keras.io/api/models/model_training_apis/
autoencoder.compile(optimizer="adam", 
                    loss="mse",
                    metrics=["acc"])

# print an overview of our model
autoencoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 29)                870
#
#  dense_1 (Dense)             (None, 16)                480
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 4)                 36
#
#  dense_4 (Dense)             (None, 2)                 10
#
#  dense_5 (Dense)             (None, 4)                 12
#
#  dense_6 (Dense)             (None, 8)                 40
#
#  dense_7 (Dense)             (None, 16)                144
#
#  dense_8 (Dense)             (None, 29)                493
#
# =================================================================
# Total params: 2,221
# Trainable params: 2,221
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred = autoencoder.predict(X_test_transformed)
y_pred_classes = y_pred.argmax(axis=-1)
accuracy = accuracy_score(y_test, y_pred_classes)
print(accuracy) # accuracy
# Out:
# 2651/2651 [==============================] - 3s 1ms/step
# 0.1757520016036412

# %%
encoded_data = model_autoencoder.encoder(X_test_transformed).numpy()
decoded_data = model_autoencoder.decoder(encoded_data).numpy()

# %%
total_subplots = 16
selected_features = rn.sample(range(X_test_transformed.shape[0]), total_subplots)

plt.figure(figsize=(20, 10))
for idx, feature_idx in enumerate(selected_features):
    plt.subplot(4, 4, idx + 1)
    plt.plot(X_test_transformed[idx, 0], 'b')
    plt.plot(decoded_data[idx, 0], 'r', linewidth=0.5)
    plt.fill_between(np.arange(29), decoded_data[idx, 0], X_test_transformed[idx, 0], color='lightcoral', alpha=0.7)
    plt.title(f'Feature {feature_idx + 1}')
    plt.legend(labels=["Input", "Reconstruction", "Error"])

plt.tight_layout()
plt.savefig("feature")
plt.show()
# Out:
# <div id='e0b353ef-a480-4fc4-9a56-c1e4acd5a987'></div>

# %% [markdown]
# ## Callbacks
#
# * Continue as long as the model is reducing the training loss.
# * Save only the weights for the model with the lowest validation loss, though.
# * Get graphical insights with Tensorboard.

# %% [markdown]
# ## Training

# %%
history = autoencoder.fit(
    X_train_transformed, X_train_transformed,
    shuffle=True,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_validate_transformed, X_validate_transformed)
)
# Out:
# Epoch 1/100
# 625/625 [==============================] - 5s 4ms/step - loss: 0.0308 - acc: 0.2236 - val_loss: 0.0172 - val_acc: 0.2510
# Epoch 2/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0166 - acc: 0.2475 - val_loss: 0.0155 - val_acc: 0.2640
# Epoch 3/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0148 - acc: 0.3198 - val_loss: 0.0146 - val_acc: 0.3255
# Epoch 4/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0144 - acc: 0.3357 - val_loss: 0.0142 - val_acc: 0.3247
# Epoch 5/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0140 - acc: 0.3282 - val_loss: 0.0139 - val_acc: 0.3235
# Epoch 6/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0138 - acc: 0.3258 - val_loss: 0.0138 - val_acc: 0.3286
# Epoch 7/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0137 - acc: 0.3351 - val_loss: 0.0137 - val_acc: 0.3372
# Epoch 8/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0136 - acc: 0.3476 - val_loss: 0.0135 - val_acc: 0.3495
# Epoch 9/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0132 - acc: 0.3587 - val_loss: 0.0129 - val_acc: 0.3498
# Epoch 10/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0125 - acc: 0.3696 - val_loss: 0.0123 - val_acc: 0.3654
# Epoch 11/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0122 - acc: 0.3740 - val_loss: 0.0121 - val_acc: 0.3673
# Epoch 12/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0120 - acc: 0.3690 - val_loss: 0.0120 - val_acc: 0.3660
# Epoch 13/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0120 - acc: 0.3633 - val_loss: 0.0120 - val_acc: 0.3567
# Epoch 14/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0119 - acc: 0.3603 - val_loss: 0.0119 - val_acc: 0.3533
# Epoch 15/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0119 - acc: 0.3575 - val_loss: 0.0119 - val_acc: 0.3507
# Epoch 16/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0118 - acc: 0.3556 - val_loss: 0.0118 - val_acc: 0.3488
# Epoch 17/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0118 - acc: 0.3539 - val_loss: 0.0118 - val_acc: 0.3431
# Epoch 18/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0117 - acc: 0.3528 - val_loss: 0.0117 - val_acc: 0.3461
# Epoch 19/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0117 - acc: 0.3514 - val_loss: 0.0117 - val_acc: 0.3492
# Epoch 20/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.0117 - acc: 0.3508 - val_loss: 0.0117 - val_acc: 0.3495
# Epoch 21/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0116 - acc: 0.3505 - val_loss: 0.0116 - val_acc: 0.3475
# Epoch 22/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0115 - acc: 0.3506 - val_loss: 0.0115 - val_acc: 0.3527
# Epoch 23/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0115 - acc: 0.3518 - val_loss: 0.0115 - val_acc: 0.3485
# Epoch 24/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0114 - acc: 0.3522 - val_loss: 0.0114 - val_acc: 0.3494
# Epoch 25/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0113 - acc: 0.3539 - val_loss: 0.0112 - val_acc: 0.3547
# Epoch 26/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0112 - acc: 0.3609 - val_loss: 0.0111 - val_acc: 0.3690
# Epoch 27/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0111 - acc: 0.3696 - val_loss: 0.0111 - val_acc: 0.3675
# Epoch 28/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0110 - acc: 0.3722 - val_loss: 0.0110 - val_acc: 0.3712
# Epoch 29/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0109 - acc: 0.3731 - val_loss: 0.0110 - val_acc: 0.3709
# Epoch 30/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0109 - acc: 0.3716 - val_loss: 0.0109 - val_acc: 0.3726
# Epoch 31/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0109 - acc: 0.3720 - val_loss: 0.0109 - val_acc: 0.3667
# Epoch 32/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0108 - acc: 0.3722 - val_loss: 0.0109 - val_acc: 0.3674
# Epoch 33/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0108 - acc: 0.3732 - val_loss: 0.0108 - val_acc: 0.3718
# Epoch 34/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0108 - acc: 0.3735 - val_loss: 0.0108 - val_acc: 0.3703
# Epoch 35/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0107 - acc: 0.3758 - val_loss: 0.0108 - val_acc: 0.3751
# Epoch 36/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0107 - acc: 0.3779 - val_loss: 0.0107 - val_acc: 0.3754
# Epoch 37/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0107 - acc: 0.3799 - val_loss: 0.0107 - val_acc: 0.3741
# Epoch 38/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0106 - acc: 0.3825 - val_loss: 0.0106 - val_acc: 0.3842
# Epoch 39/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0106 - acc: 0.3853 - val_loss: 0.0106 - val_acc: 0.3882
# Epoch 40/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0105 - acc: 0.3881 - val_loss: 0.0105 - val_acc: 0.3851
# Epoch 41/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0105 - acc: 0.3926 - val_loss: 0.0105 - val_acc: 0.3841
# Epoch 42/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0104 - acc: 0.3951 - val_loss: 0.0104 - val_acc: 0.3963
# Epoch 43/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0104 - acc: 0.3975 - val_loss: 0.0104 - val_acc: 0.3959
# Epoch 44/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0104 - acc: 0.4004 - val_loss: 0.0104 - val_acc: 0.3900
# Epoch 45/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0103 - acc: 0.4020 - val_loss: 0.0103 - val_acc: 0.4022
# Epoch 46/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0103 - acc: 0.4059 - val_loss: 0.0103 - val_acc: 0.4064
# Epoch 47/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0103 - acc: 0.4079 - val_loss: 0.0103 - val_acc: 0.4020
# Epoch 48/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0102 - acc: 0.4099 - val_loss: 0.0102 - val_acc: 0.4087
# Epoch 49/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0102 - acc: 0.4123 - val_loss: 0.0102 - val_acc: 0.4110
# Epoch 50/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0101 - acc: 0.4133 - val_loss: 0.0102 - val_acc: 0.4119
# Epoch 51/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0101 - acc: 0.4144 - val_loss: 0.0101 - val_acc: 0.4109
# Epoch 52/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0101 - acc: 0.4164 - val_loss: 0.0101 - val_acc: 0.4191
# Epoch 53/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0100 - acc: 0.4176 - val_loss: 0.0100 - val_acc: 0.4185
# Epoch 54/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0100 - acc: 0.4194 - val_loss: 0.0100 - val_acc: 0.4186
# Epoch 55/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0100 - acc: 0.4212 - val_loss: 0.0100 - val_acc: 0.4078
# Epoch 56/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0099 - acc: 0.4222 - val_loss: 0.0099 - val_acc: 0.4191
# Epoch 57/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0099 - acc: 0.4236 - val_loss: 0.0099 - val_acc: 0.4237
# Epoch 58/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0099 - acc: 0.4251 - val_loss: 0.0099 - val_acc: 0.4243
# Epoch 59/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0098 - acc: 0.4263 - val_loss: 0.0098 - val_acc: 0.4245
# Epoch 60/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0098 - acc: 0.4268 - val_loss: 0.0098 - val_acc: 0.4256
# Epoch 61/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0098 - acc: 0.4271 - val_loss: 0.0098 - val_acc: 0.4243
# Epoch 62/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0098 - acc: 0.4274 - val_loss: 0.0098 - val_acc: 0.4254
# Epoch 63/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0098 - acc: 0.4276 - val_loss: 0.0098 - val_acc: 0.4236
# Epoch 64/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0097 - acc: 0.4278 - val_loss: 0.0098 - val_acc: 0.4236
# Epoch 65/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0097 - acc: 0.4275 - val_loss: 0.0097 - val_acc: 0.4275
# Epoch 66/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0097 - acc: 0.4276 - val_loss: 0.0097 - val_acc: 0.4228
# Epoch 67/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0097 - acc: 0.4280 - val_loss: 0.0097 - val_acc: 0.4239
# Epoch 68/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0097 - acc: 0.4282 - val_loss: 0.0097 - val_acc: 0.4238
# Epoch 69/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0097 - acc: 0.4277 - val_loss: 0.0097 - val_acc: 0.4254
# Epoch 70/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0096 - acc: 0.4279 - val_loss: 0.0097 - val_acc: 0.4240
# Epoch 71/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0096 - acc: 0.4281 - val_loss: 0.0096 - val_acc: 0.4262
# Epoch 72/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0096 - acc: 0.4275 - val_loss: 0.0096 - val_acc: 0.4279
# Epoch 73/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0096 - acc: 0.4282 - val_loss: 0.0096 - val_acc: 0.4234
# Epoch 74/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0096 - acc: 0.4283 - val_loss: 0.0096 - val_acc: 0.4247
# Epoch 75/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0096 - acc: 0.4279 - val_loss: 0.0096 - val_acc: 0.4248
# Epoch 76/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0096 - acc: 0.4280 - val_loss: 0.0096 - val_acc: 0.4257
# Epoch 77/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0096 - acc: 0.4282 - val_loss: 0.0096 - val_acc: 0.4228
# Epoch 78/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0096 - acc: 0.4275 - val_loss: 0.0096 - val_acc: 0.4231
# Epoch 79/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0095 - acc: 0.4282 - val_loss: 0.0096 - val_acc: 0.4199
# Epoch 80/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0095 - acc: 0.4279 - val_loss: 0.0095 - val_acc: 0.4232
# Epoch 81/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0095 - acc: 0.4279 - val_loss: 0.0095 - val_acc: 0.4236
# Epoch 82/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0095 - acc: 0.4283 - val_loss: 0.0095 - val_acc: 0.4212
# Epoch 83/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0095 - acc: 0.4289 - val_loss: 0.0095 - val_acc: 0.4235
# Epoch 84/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0095 - acc: 0.4277 - val_loss: 0.0095 - val_acc: 0.4218
# Epoch 85/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0095 - acc: 0.4285 - val_loss: 0.0095 - val_acc: 0.4216
# Epoch 86/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0095 - acc: 0.4287 - val_loss: 0.0095 - val_acc: 0.4265
# Epoch 87/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0095 - acc: 0.4286 - val_loss: 0.0095 - val_acc: 0.4222
# Epoch 88/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0095 - acc: 0.4285 - val_loss: 0.0095 - val_acc: 0.4281
# Epoch 89/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0094 - acc: 0.4289 - val_loss: 0.0095 - val_acc: 0.4243
# Epoch 90/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4296 - val_loss: 0.0094 - val_acc: 0.4299
# Epoch 91/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4293 - val_loss: 0.0094 - val_acc: 0.4261
# Epoch 92/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0094 - acc: 0.4301 - val_loss: 0.0094 - val_acc: 0.4278
# Epoch 93/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0094 - acc: 0.4301 - val_loss: 0.0094 - val_acc: 0.4258
# Epoch 94/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4300 - val_loss: 0.0094 - val_acc: 0.4252
# Epoch 95/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4300 - val_loss: 0.0094 - val_acc: 0.4270
# Epoch 96/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4311 - val_loss: 0.0094 - val_acc: 0.4253
# Epoch 97/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4308 - val_loss: 0.0094 - val_acc: 0.4274
# Epoch 98/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4317 - val_loss: 0.0094 - val_acc: 0.4257
# Epoch 99/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4311 - val_loss: 0.0094 - val_acc: 0.4291
# Epoch 100/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0094 - acc: 0.4318 - val_loss: 0.0094 - val_acc: 0.4291

# %% [markdown]
# <a id="7"></a> <br>
# # Reconstructions
#
# We **apply the transformation pipeline to our test set**. <br>
# Then, we **pass the data through the trained autoencoder**.

# %%
# transform the test set with the pipeline fitted to the training set
X_test_transformed = pipeline.transform(X_test)

# pass the transformed test set through the autoencoder to get the reconstructed result
reconstructions = autoencoder.predict(X_test_transformed)
# Out:
#    1/2651 [..............................] - ETA: 5:01
# c:\Users\Alexej\miniconda3\envs\simple-htr-gpu\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but Normalizer was fitted with feature names
#   warnings.warn(
# 2651/2651 [==============================] - 4s 1ms/step

# %% [markdown]
# **Calculate the reconstruction loss** for every transaction and draw a sample.

# %%
# calculating the mean squared error reconstruction loss per row in the numpy array
mse = np.mean(np.power(X_test_transformed - reconstructions, 2), axis=1)

# %%
clean = mse[y_test==0]
fraud = mse[y_test==1]

fig, ax = plt.subplots(figsize=(6,6))

ax.hist(clean, bins=50, density=True, label="clean", alpha=.6, color="green")
ax.hist(fraud, bins=50, density=True, label="fraud", alpha=.6, color="red")

plt.title("(Normalized) Distribution of the Reconstruction Loss")
plt.legend()
plt.show()
# Out:
# <div id='ff27866d-7579-4014-a31d-9fb9ba2b6ad5'></div>

# %%
clean = mse[y_test==0]
fraud = mse[y_test==1]

fig, ax = plt.subplots(figsize=(6,6))

ax.hist(clean, bins=50, density=True, label="clean", alpha=.6, color="green")
ax.hist(fraud, bins=50, density=True, label="fraud", alpha=.6, color="red")

plt.title("(Normalized) Distribution of the Reconstruction Loss")
plt.legend()
plt.show()
# Out:
# <div id='9c1ad9f7-b231-487b-bf3f-24a1092c5b66'></div>

# %% [markdown]
# Very promising! Although some transactions seem to fool the autoencoder, the fraudulent transactions clearly have a distinguishing element in their data that sets them apart from clean ones.

# %% [markdown]
# <a id="8"></a> <br>
# # Setting a threshold for classification
#
# ## Unsupervised
# Normally, in an unsupervised solution, this is where the story would end. We would **set a threshold that limits the amount of false positives** to a manageable degree, **and captures the most anomalous data points**.
#
# ### Percentiles
# We could set this threshold by taking the top x% of the dataset and considering it anomalous.
#
# ### MAD
# We could also use a **modified Z-score using the Median Absolute Deviation to define outliers** on our reconstruction data. Here is a [good blog post on the topic](https://medium.com/james-blogs/outliers-make-us-go-mad-univariate-outlier-detection-b3a72f1ea8c7) by João Rodrigues, illustrating why this algorithm is more robust and scalable than the percentiles method.

# %%
THRESHOLD = 3

def mad_score(points):
    """https://www.itl.nist.gov/div898/handbook/eda/section3/eda35h.htm """
    m = np.median(points)
    ad = np.abs(points - m)
    mad = np.median(ad)
    
    return 0.6745 * ad / mad

z_scores = mad_score(mse)
outliers = z_scores > THRESHOLD

# %%
print(f"Detected {np.sum(outliers):,} outliers in a total of {np.size(z_scores):,} transactions [{np.sum(outliers)/np.size(z_scores):.2%}].")
# Out:
# Detected 1,640 outliers in a total of 84,807 transactions [1.93%].

# %% [markdown]
# ## Supervised
# We know the labels, so we can verify our results.
#
# ### Classification Matrix on MAD outliers
# A closer look:

# %%
from sklearn.metrics import (confusion_matrix, 
                             precision_recall_curve)

# get (mis)classification
cm = confusion_matrix(y_test, outliers)

# true/false positives/negatives
(tn, fp, 
 fn, tp) = cm.flatten()

# %%
print(f"""The classifications using the MAD method with threshold={THRESHOLD} are as follows:
{cm}

% of transactions labeled as fraud that were correct (precision): {tp}/({fp}+{tp}) = {tp/(fp+tp):.2%}
% of fraudulent transactions were caught succesfully (recall):    {tp}/({fn}+{tp}) = {tp/(fn+tp):.2%}""")
# Out:
# The classifications using the MAD method with threshold=3 are as follows:
# [[83043  1272]
#  [  124   368]]
#
# % of transactions labeled as fraud that were correct (precision): 368/(1272+368) = 22.44%
# % of fraudulent transactions were caught succesfully (recall):    368/(124+368) = 74.80%

# %% [markdown]
# ### Asymmetric error cost
# In the real world, we can expect **different costs associated with reporting a false positive versus reporting a false negative**. Missing a fraud case is likely to be much more costly than wrongly flagging a transaction as one. In [another kernel](https://www.kaggle.com/robinteuwens/fraud-detection-as-a-cost-optimization-problem/comments), I discuss an approach to determining these costs for this dataset in depth.
#
# ### Recall & Precision
# Generally speaking, you will have to prioritise what you find more important. This dilemma is commonly called the **"recall vs precision" trade-off**.
# If you want to increase recall, **adjust the MAD's Z-Score threshold** downwards, if you want recover precision, increase it.

# %%
clean = z_scores[y_test==0]
fraud = z_scores[y_test==1]

fig, ax = plt.subplots(figsize=(6,6))

ax.hist(clean, bins=50, density=True, label="clean", alpha=.6, color="green")
ax.hist(fraud, bins=50, density=True, label="fraud", alpha=.6, color="red")

plt.title("Distribution of the modified z-scores")
plt.legend()
plt.savefig("test2")
plt.show()
# Out:
# <div id='37b2df3d-d506-4ae3-8ce3-f3b40aca6b5c'></div>

# %% [markdown]
# <a id="9"></a> <br>
# # Latent Space
# It is always interesting to look at the **compressed representation** our neural network devised.
#
# ## Encoder
# Let's build the encoder that gets us to the bottleneck. We take the layers from our autoencoder.

# %%
encoder = tf.keras.models.Sequential(autoencoder.layers[:5])
encoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 29)                870
#
#  dense_1 (Dense)             (None, 16)                480
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 4)                 36
#
#  dense_4 (Dense)             (None, 2)                 10
#
# =================================================================
# Total params: 1,532
# Trainable params: 1,532
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Undersampling
# Consistent with the previous t-sne visualisation, let's undersample the clean transactions.

# %%
# taking all the fraud, undersampling clean
fraud = X_test_transformed[y_test==1]
clean = X_test_transformed[y_test==0][:len(fraud) * RATIO_TO_FRAUD, ]

# combining arrays & building labels
features = np.append(fraud, clean, axis=0)
labels = np.append(np.ones(len(fraud)),
                   np.zeros(len(clean)))

# getting latent space representation
latent_representation = encoder.predict(features)

print(f'Clean transactions downsampled from {len(X_test_transformed[y_test==0]):,} to {len(clean):,}.')
print('Shape of latent representation:', latent_representation.shape)
# Out:
# 246/246 [==============================] - 0s 933us/step
# Clean transactions downsampled from 84,315 to 7,380.
# Shape of latent representation: (7872, 2)

# %% [markdown]
# ## Visualising the Latent Space

# %%
X = latent_representation[:,0]
y = latent_representation[:,1]

# plotting
plt.subplots(figsize=(8, 8))
plt.scatter(X[labels==0], y[labels==0], s=1, c='g', alpha=0.3, label='Clean')
plt.scatter(X[labels==1], y[labels==1], s=2, c='r', alpha=0.7, label='Fraud')

# labeling
plt.legend(loc='best')
plt.title('Latent Space Representation')

# saving & displaying
plt.savefig('latent_representation_2d')
plt.show()
# Out:
# <div id='e9c7e294-9ccb-4c82-8d37-e6cee51bfe0b'></div>

# %% [markdown]
# Although there is no perfectly distinct cluster, **most of the fradulent transactions appear to be neatly grouped together**.
# This is in line with the hope/idea that both **classes would occupy distinct areas in latent space**, due to the **encoder's weights not being calibrated to cope with fraudulent transactions**.
# ![image.png](attachment:image.png)

# %% [markdown]
# <a id="10"></a> <br>
# # Conclusion
# We could already tell from our misclassifications that the network was not able to generalize perfectly. However, we must not forget that **our model was trained never having seen a single fraud case!** In that regard, its performance is decent. It illustrates the power of **autoencoders as anomaly detection tools**.
#
# To improve its performance, perhaps we need to:
# * improve the model architecture
# * diversify the training data more, with a broader sample of clean transactions
# * augment the data with different, additional features - the data itself might not be good enough to distinguish between classes perfectly (i.e. fraudsters are disguising themselves well enough to always go undetected using these data points, no matter the algorithm).
